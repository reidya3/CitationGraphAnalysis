# %%
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %% [markdown]
# ## Initialise spark session

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
  .appName('Scholars Data Preparation')\
  .getOrCreate()

# %% [markdown]
# ## Let's create our dataframes

# %%
df_dcu = spark.read.csv("data/Scholar/dcu-scholars.csv", header=True)

# %%
df_dcu
# Out:
# DataFrame[_c0: string, Researcher: string, Position: string]

# %%
df_dcu.limit(10).toPandas()
# Out:
#   _c0          Researcher                                           Position
# 0   0     Michael Scriney                  Insight Centre for Data Analytics
# 1   1  Malika Bendechache  School of Computing, Dublin City University (DCU)
# 2   2   Marija Bezbradica  Lecturer, School of Computing, Dublin City Uni...
# 3   3         Rob Brennan  Assistant Professor, School of Computing, Dubl...
# 4   4     Annalina Caputo  Assistant Professor, Dublin City University, A...
# 5   5          Long Cheng   Professor, North China Electric Power University
# 6   6         Paul Clarke  Associate Professor at Dublin City University ...
# 7   7        Martin Crane        School of Computing, Dublin City University
# 8   8        Charlie Daly                       Lecturer in Computer Science
# 9   9         Brian Davis  Assistant Professor, School of Computing, Dubl...

# %%
df_dcu.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- Researcher: string (nullable = true)
#  |-- Position: string (nullable = true)

# %%
df_dcu = df_dcu.drop("_c0")

# %%
df_dcu.limit(10).toPandas()
# Out:
#            Researcher                                           Position
# 0     Michael Scriney                  Insight Centre for Data Analytics
# 1  Malika Bendechache  School of Computing, Dublin City University (DCU)
# 2   Marija Bezbradica  Lecturer, School of Computing, Dublin City Uni...
# 3         Rob Brennan  Assistant Professor, School of Computing, Dubl...
# 4     Annalina Caputo  Assistant Professor, Dublin City University, A...
# 5          Long Cheng   Professor, North China Electric Power University
# 6         Paul Clarke  Associate Professor at Dublin City University ...
# 7        Martin Crane        School of Computing, Dublin City University
# 8        Charlie Daly                       Lecturer in Computer Science
# 9         Brian Davis  Assistant Professor, School of Computing, Dubl...

# %%
df_dcu.printSchema()
# Out:
# root
#  |-- Researcher: string (nullable = true)
#  |-- Position: string (nullable = true)

# %%
df_art = spark.read.csv("data/Scholar/final.csv", header=True)

# %%
df_art.limit(10).toPandas()
# Out:
#                                                Title Citation  \
# 0    Efficient cube construction for smart city data       10
# 1          Generating cubes from smart city web data        7
# 2  Automating Data Mart Construction from Semi-st...        6
# 3       Predicting customer churn for insurance data        4
# 4  Attention Based Video Summaries of Live Online...        3
# 5  Constructing data marts from web sources using...        2
# 6  Integrating online data for smart city data marts        2
# 7  Identification of movement categories and asso...        1
# 8  Representative Sample Extraction from Web Data...        1
# 9  Using Artificial Intelligence to Automate Meat...  Unknown
#
#                                           Conference                Publisher  \
# 0                                            Unknown             CEUR-WS. org
# 1  Proceedings of the Australasian Computer Scien...                      ACM
# 2                                            Unknown  Oxford University Press
# 3  International Conference on Big Data Analytics...           Springer, Cham
# 4  "AAAI-2021 Workshop on AI Education: ""Imagini...                  Unknown
# 5                                            Unknown                  Unknown
# 6      British International Conference on Databases           Springer, Cham
# 7                                            Unknown                Routledge
# 8  International Conference on Database and Exper...           Springer, Cham
# 9                                            Unknown                  Unknown
#
#                                              Journal  Date  \
# 0                                            Unknown  2016
# 1                                            Unknown  2017
# 2                               The Computer Journal  2018
# 3                                            Unknown  2020
# 4                                            Unknown  2021
# 5                                            Unknown  2018
# 6                                            Unknown  2017
# 7  International Journal of Performance Analysis ...  2021
# 8                                            Unknown  2019
# 9                          Journal of Animal Science  2021
#
#                                              Authors        AuthorDCU
# 0                     Michael Scriney, Mark Roantree  Michael Scriney
# 1  Michael Scriney, Martin F O'Connor, Mark Roantree  Michael Scriney
# 2  Michael Scriney, Suzanne McCarthy, Andrew McCa...  Michael Scriney
# 3        Michael Scriney, Dongyun Nie, Mark Roantree  Michael Scriney
# 4  Hyowon Lee, Mingming Liu, Hamza Riaz, Navaneet...  Michael Scriney
# 5                                    Michael Scriney  Michael Scriney
# 6  Michael Scriney, Martin F O'Connor, Mark Roantree  Michael Scriney
# 7  Aidan J Brady, Michael Scriney, Niall M Moyna,...  Michael Scriney
# 8  Michael Scriney, Congcong Xing, Andrew McCarre...  Michael Scriney
# 9  Satya Prakash, Donagh P Berry, Mark Roantree, ...  Michael Scriney

# %%
df_art.toPandas()
# Out:
#                                                   Title Citation  \
# 0       Efficient cube construction for smart city data       10
# 1             Generating cubes from smart city web data        7
# 2     Automating Data Mart Construction from Semi-st...        6
# 3          Predicting customer churn for insurance data        4
# 4     Attention Based Video Summaries of Live Online...        3
# ...                                                 ...      ...
# 4838  Evaluating Automatic-Structure Annotation for ...  Unknown
# 4839  Contextual Bitext-Derived Paraphrases in Autom...  Unknown
# 4840  A Suite of Linguistic Tools for Use with the P...  Unknown
# 4841  The Creation and Evaluation of an Irish Langua...  Unknown
# 4842  TransBooster: Wrapper Technology for Wide-Cove...  Unknown
#
#                                              Conference  \
# 0                                               Unknown
# 1     Proceedings of the Australasian Computer Scien...
# 2                                               Unknown
# 3     International Conference on Big Data Analytics...
# 4     "AAAI-2021 Workshop on AI Education: ""Imagini...
# ...                                                 ...
# 4838                                            Unknown
# 4839                                            Unknown
# 4840                                            Unknown
# 4841                                            Unknown
# 4842                                            Unknown
#
#                     Publisher               Journal     Date  \
# 0                CEUR-WS. org               Unknown     2016
# 1                         ACM               Unknown     2017
# 2     Oxford University Press  The Computer Journal     2018
# 3              Springer, Cham               Unknown     2020
# 4                     Unknown               Unknown     2021
# ...                       ...                   ...      ...
# 4838                  Unknown               Unknown  Unknown
# 4839                  Unknown               Unknown  Unknown
# 4840                  Unknown               Unknown  Unknown
# 4841                  Unknown               Unknown  Unknown
# 4842                  Unknown               Unknown  Unknown
#
#                                                 Authors        AuthorDCU
# 0                        Michael Scriney, Mark Roantree  Michael Scriney
# 1     Michael Scriney, Martin F O'Connor, Mark Roantree  Michael Scriney
# 2     Michael Scriney, Suzanne McCarthy, Andrew McCa...  Michael Scriney
# 3           Michael Scriney, Dongyun Nie, Mark Roantree  Michael Scriney
# 4     Hyowon Lee, Mingming Liu, Hamza Riaz, Navaneet...  Michael Scriney
# ...                                                 ...              ...
# 4838  Aoife Cahill, Mairead McCarthy, Josef Van Gena...         Andy Way
# 4839  Karolina Owczarzak, Declan Groves, Josef Van G...         Andy Way
# 4840  Aoife Cahill, Mairead McCarthy, Ruth O'Donovan...         Andy Way
# 4841                           Bríd de Lóndra, Andy Way         Andy Way
# 4842  Bart Mellebeek, Karolina Owczarzak, Josef Van ...         Andy Way
#
# [4843 rows x 8 columns]

# %%
df_art.printSchema()
# Out:
# root
#  |-- Title: string (nullable = true)
#  |-- Citation: string (nullable = true)
#  |-- Conference: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#  |-- Journal: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Authors: string (nullable = true)
#  |-- AuthorDCU: string (nullable = true)

# %%
df_art.count()
# Out:
# 4843

# %% [markdown]
# ## Let's check for the presence of nulls and duplicate values

# %%
cols = df_art.columns
for i in range(len(cols)):
    print(df_art.filter(df_art[cols[i]].isNull()).count())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# Thankfully, we have no nulls present in any of our dataframe columns. This allows us to continue working through our dataframe.

# %%
if df_art.count() > df_art.dropDuplicates(['Title']).count():
    print('NOTE: Data has duplicates!')
# Out:
# NOTE: Data has duplicates!

# %% [markdown]
# There is duplicates to be found in our dataframe. This is not surprising to the two of us. The reason we filtered on the column 'title' was that if a paper appeared on a scholars list of published articles and a fellow dcu staff member also contributed to this paper we presumed this paper would also appear on their list of published works. There would be differences in all columns bar the last column "AuthorDCU" as this was the unique identifier as to which page this paper was scraped off.

# %% [markdown]
# ## Now we have done some initial background checks on our data we can begin some simple analysis using PySpark

# %%
# let's check the author with the most published pieces on their scholar profile
df_art.groupBy('AuthorDCU').count().collect()
# Out:
# [Row(AuthorDCU='Monica Ward', count=45),
#  Row(AuthorDCU='Alan F Smeaton', count=796),
#  Row(AuthorDCU='Suzanne Little', count=102),
#  Row(AuthorDCU='Geoff Hamilton', count=84),
#  Row(AuthorDCU='Long Cheng', count=63),
#  Row(AuthorDCU='David Sinclair', count=41),
#  Row(AuthorDCU='Paul M.Clarke', count=116),
#  Row(AuthorDCU='Andy Way', count=512),
#  Row(AuthorDCU='Jennifer Foster', count=100),
#  Row(AuthorDCU='Yvette Graham', count=78),
#  Row(AuthorDCU='Brian Davis', count=93),
#  Row(AuthorDCU=' UK “Cambridge …"', count=1),
#  Row(AuthorDCU='Rob Brennan', count=140),
#  Row(AuthorDCU='Musfira Jilani', count=24),
#  Row(AuthorDCU='John McKenna', count=14),
#  Row(AuthorDCU='Michael Scriney', count=18),
#  Row(AuthorDCU='Silvana Togneri Mac Mahon', count=34),
#  Row(AuthorDCU='Marija Bezbradica', count=46),
#  Row(AuthorDCU='Andrew McCarren', count=48),
#  Row(AuthorDCU='Malika Bendechache', count=32),
#  Row(AuthorDCU='Heather J. Ruskin', count=198),
#  Row(AuthorDCU='Donal Fitzpatrick', count=44),
#  Row(AuthorDCU='Ray Walshe', count=73),
#  Row(AuthorDCU='Tomas Ward', count=299),
#  Row(AuthorDCU='Alistair Sutherland', count=80),
#  Row(AuthorDCU='Cathal Gurrin', count=414),
#  Row(AuthorDCU='Mark Roantree', count=151),
#  Row(AuthorDCU='Graham Healy', count=59),
#  Row(AuthorDCU='Charlie Daly', count=22),
#  Row(AuthorDCU="Padraig O'leary, Noel Carroll, Paul M Clarke, Ita Richardson", count=1),
#  Row(AuthorDCU='Annalina Caputo', count=72),
#  Row(AuthorDCU='Martin Crane', count=109),
#  Row(AuthorDCU='Alessandra Mileo', count=109),
#  Row(AuthorDCU='Jagadeeswaran Thangaraj', count=11),
#  Row(AuthorDCU='Murat Yilmaz', count=91),
#  Row(AuthorDCU='Gareth Jones', count=610),
#  Row(AuthorDCU="Darragh O'Brien", count=29),
#  Row(AuthorDCU='Dimitar Shterionov', count=44),
#  Row(AuthorDCU='Irina Tal', count=40)]

# %% [markdown]
# We can see that Alan Smeaton has the largest number of published pieces with 798 and Gareth Jones is in second with 610. There seems to be a couple of faulty values here not originally in the data: "Padraig O'leary, Noel Carroll, Paul Clarke, Ita Richardson" and "UK â€œCambridge â€¦". We will replace the first value mentioned with "Paul M.Clarke" as we see this name is featured in the list of authors shown.

# %%
from pyspark.sql.functions import when
df_art = df_art.withColumn("AuthorDCU", when(df_art.AuthorDCU == "Padraig O'leary, Noel Carroll, Paul M Clarke, Ita Richardson","Paul M.Clarke") \
      .otherwise(df_art.AuthorDCU))

# %%
df_art.groupBy('AuthorDCU').count().collect()
# Out:
# [Row(AuthorDCU='Monica Ward', count=45),
#  Row(AuthorDCU='Alan F Smeaton', count=796),
#  Row(AuthorDCU='Suzanne Little', count=102),
#  Row(AuthorDCU='Geoff Hamilton', count=84),
#  Row(AuthorDCU='Long Cheng', count=63),
#  Row(AuthorDCU='David Sinclair', count=41),
#  Row(AuthorDCU='Paul M.Clarke', count=117),
#  Row(AuthorDCU='Andy Way', count=512),
#  Row(AuthorDCU='Jennifer Foster', count=100),
#  Row(AuthorDCU='Yvette Graham', count=78),
#  Row(AuthorDCU='Brian Davis', count=93),
#  Row(AuthorDCU=' UK “Cambridge …"', count=1),
#  Row(AuthorDCU='Rob Brennan', count=140),
#  Row(AuthorDCU='Musfira Jilani', count=24),
#  Row(AuthorDCU='John McKenna', count=14),
#  Row(AuthorDCU='Michael Scriney', count=18),
#  Row(AuthorDCU='Silvana Togneri Mac Mahon', count=34),
#  Row(AuthorDCU='Marija Bezbradica', count=46),
#  Row(AuthorDCU='Andrew McCarren', count=48),
#  Row(AuthorDCU='Malika Bendechache', count=32),
#  Row(AuthorDCU='Heather J. Ruskin', count=198),
#  Row(AuthorDCU='Donal Fitzpatrick', count=44),
#  Row(AuthorDCU='Ray Walshe', count=73),
#  Row(AuthorDCU='Tomas Ward', count=299),
#  Row(AuthorDCU='Alistair Sutherland', count=80),
#  Row(AuthorDCU='Cathal Gurrin', count=414),
#  Row(AuthorDCU='Mark Roantree', count=151),
#  Row(AuthorDCU='Graham Healy', count=59),
#  Row(AuthorDCU='Charlie Daly', count=22),
#  Row(AuthorDCU='Annalina Caputo', count=72),
#  Row(AuthorDCU='Martin Crane', count=109),
#  Row(AuthorDCU='Alessandra Mileo', count=109),
#  Row(AuthorDCU='Jagadeeswaran Thangaraj', count=11),
#  Row(AuthorDCU='Murat Yilmaz', count=91),
#  Row(AuthorDCU='Gareth Jones', count=610),
#  Row(AuthorDCU="Darragh O'Brien", count=29),
#  Row(AuthorDCU='Dimitar Shterionov', count=44),
#  Row(AuthorDCU='Irina Tal', count=40)]

# %%
df_art = df_art.filter(df_art.AuthorDCU != ' UK “Cambridge …"')

# %%
df_art.groupBy('AuthorDCU').count().collect()
# Out:
# [Row(AuthorDCU='Monica Ward', count=45),
#  Row(AuthorDCU='Alan F Smeaton', count=796),
#  Row(AuthorDCU='Suzanne Little', count=102),
#  Row(AuthorDCU='Geoff Hamilton', count=84),
#  Row(AuthorDCU='Long Cheng', count=63),
#  Row(AuthorDCU='David Sinclair', count=41),
#  Row(AuthorDCU='Paul M.Clarke', count=117),
#  Row(AuthorDCU='Andy Way', count=512),
#  Row(AuthorDCU='Jennifer Foster', count=100),
#  Row(AuthorDCU='Yvette Graham', count=78),
#  Row(AuthorDCU='Brian Davis', count=93),
#  Row(AuthorDCU='Rob Brennan', count=140),
#  Row(AuthorDCU='Musfira Jilani', count=24),
#  Row(AuthorDCU='John McKenna', count=14),
#  Row(AuthorDCU='Michael Scriney', count=18),
#  Row(AuthorDCU='Silvana Togneri Mac Mahon', count=34),
#  Row(AuthorDCU='Marija Bezbradica', count=46),
#  Row(AuthorDCU='Andrew McCarren', count=48),
#  Row(AuthorDCU='Malika Bendechache', count=32),
#  Row(AuthorDCU='Heather J. Ruskin', count=198),
#  Row(AuthorDCU='Donal Fitzpatrick', count=44),
#  Row(AuthorDCU='Ray Walshe', count=73),
#  Row(AuthorDCU='Tomas Ward', count=299),
#  Row(AuthorDCU='Alistair Sutherland', count=80),
#  Row(AuthorDCU='Cathal Gurrin', count=414),
#  Row(AuthorDCU='Mark Roantree', count=151),
#  Row(AuthorDCU='Graham Healy', count=59),
#  Row(AuthorDCU='Charlie Daly', count=22),
#  Row(AuthorDCU='Annalina Caputo', count=72),
#  Row(AuthorDCU='Martin Crane', count=109),
#  Row(AuthorDCU='Alessandra Mileo', count=109),
#  Row(AuthorDCU='Jagadeeswaran Thangaraj', count=11),
#  Row(AuthorDCU='Murat Yilmaz', count=91),
#  Row(AuthorDCU='Gareth Jones', count=610),
#  Row(AuthorDCU="Darragh O'Brien", count=29),
#  Row(AuthorDCU='Dimitar Shterionov', count=44),
#  Row(AuthorDCU='Irina Tal', count=40)]

# %% [markdown]
# Now, our faulty values are either replaced or removed.

# %% [markdown]
# ## Let's do the same for year

# %%
df_art.groupBy('Date').count().collect()
# Out:
# [Row(Date='1987', count=4),
#  Row(Date='2016', count=274),
#  Row(Date='2020', count=272),
#  Row(Date='2012', count=234),
#  Row(Date='1988', count=4),
#  Row(Date='2019', count=272),
#  Row(Date='2017', count=269),
#  Row(Date='2014', count=239),
#  Row(Date='1984', count=2),
#  Row(Date='2013', count=234),
#  Row(Date='1982', count=3),
#  Row(Date='85', count=1),
#  Row(Date='2005', count=142),
#  Row(Date='2000', count=47),
#  Row(Date='1981', count=2),
#  Row(Date='1978', count=1),
#  Row(Date='2002', count=72),
#  Row(Date='2018', count=247),
#  Row(Date='2009', count=223),
#  Row(Date='1995', count=31),
#  Row(Date='2006', count=211),
#  Row(Date='Unknown', count=240),
#  Row(Date='1976', count=1),
#  Row(Date='2004', count=148),
#  Row(Date='2011', count=205),
#  Row(Date='1989', count=2),
#  Row(Date='1992', count=19),
#  Row(Date='2022', count=2),
#  Row(Date='2008', count=191),
#  Row(Date='1999', count=51),
#  Row(Date='1963', count=1),
#  Row(Date='1994', count=24),
#  Row(Date='1997', count=34),
#  Row(Date='2007', count=170),
#  Row(Date='1996', count=26),
#  Row(Date='1983', count=1),
#  Row(Date='1980', count=1),
#  Row(Date='2021', count=246),
#  Row(Date='1986', count=3),
#  Row(Date='2015', count=198),
#  Row(Date='1998', count=31),
#  Row(Date='1993', count=17),
#  Row(Date='2001', count=76),
#  Row(Date='2010', count=260),
#  Row(Date='1990', count=5),
#  Row(Date='2003', count=91),
#  Row(Date='1991', count=15)]

# %% [markdown]
# Again, we have some slightly unreasonable / incorrect figures. These include 1963 and '85 which is presumably a slag term for 1985. It is highly unlikely that a member of the DCU staff has papers going back as far as 1963 as the next year to this is 1976 which seems slightly more plausible. 2022 also seems a particularly unusual value to have considering it is still 2021. We will filter our dataframe further and remove rows with these values.

# %%
df_art = df_art.filter(df_art.Date != '85')

# %%
df_art = df_art.filter(df_art.Date != '1963')

# %%
df_art = df_art.filter(df_art.Date != '2022')

# %%
df_art = df_art.filter(df_art.Date != '1976')
df_art = df_art.filter(df_art.Date != '1978')

# %%
df_art.groupBy('Date').count().collect()
# Out:
# [Row(Date='1987', count=4),
#  Row(Date='2016', count=274),
#  Row(Date='2020', count=272),
#  Row(Date='2012', count=234),
#  Row(Date='1988', count=4),
#  Row(Date='2019', count=272),
#  Row(Date='2017', count=269),
#  Row(Date='2014', count=239),
#  Row(Date='1984', count=2),
#  Row(Date='2013', count=234),
#  Row(Date='1982', count=3),
#  Row(Date='2005', count=142),
#  Row(Date='2000', count=47),
#  Row(Date='1981', count=2),
#  Row(Date='2002', count=72),
#  Row(Date='2018', count=247),
#  Row(Date='2009', count=223),
#  Row(Date='1995', count=31),
#  Row(Date='2006', count=211),
#  Row(Date='Unknown', count=240),
#  Row(Date='2004', count=148),
#  Row(Date='2011', count=205),
#  Row(Date='1989', count=2),
#  Row(Date='1992', count=19),
#  Row(Date='2008', count=191),
#  Row(Date='1999', count=51),
#  Row(Date='1994', count=24),
#  Row(Date='1997', count=34),
#  Row(Date='2007', count=170),
#  Row(Date='1996', count=26),
#  Row(Date='1983', count=1),
#  Row(Date='1980', count=1),
#  Row(Date='2021', count=246),
#  Row(Date='1986', count=3),
#  Row(Date='2015', count=198),
#  Row(Date='1998', count=31),
#  Row(Date='1993', count=17),
#  Row(Date='2001', count=76),
#  Row(Date='2010', count=260),
#  Row(Date='1990', count=5),
#  Row(Date='2003', count=91),
#  Row(Date='1991', count=15)]

# %% [markdown]
# This seems more realistic. We are happy to continue processing our data as a result.

# %%
df_art.count()
# Out:
# 4836

# %%
df_art.groupBy('Citation').count().collect()
# Out:
# [Row(Citation='7', count=138),
#  Row(Citation='51', count=10),
#  Row(Citation='718', count=2),
#  Row(Citation='169', count=1),
#  Row(Citation='205', count=1),
#  Row(Citation='15', count=56),
#  Row(Citation='383', count=1),
#  Row(Citation='54', count=11),
#  Row(Citation='200', count=1),
#  Row(Citation='11', count=91),
#  Row(Citation='101', count=1),
#  Row(Citation='433', count=1),
#  Row(Citation='138', count=2),
#  Row(Citation='29', count=9),
#  Row(Citation='42', count=11),
#  Row(Citation='112', count=2),
#  Row(Citation='73', count=2),
#  Row(Citation='64', count=5),
#  Row(Citation='3', count=280),
#  Row(Citation='30', count=12),
#  Row(Citation='113', count=2),
#  Row(Citation='34', count=18),
#  Row(Citation='133', count=1),
#  Row(Citation='425', count=1),
#  Row(Citation='59', count=5),
#  Row(Citation='139', count=1),
#  Row(Citation='146', count=1),
#  Row(Citation='8', count=122),
#  Row(Citation='160', count=1),
#  Row(Citation='22', count=35),
#  Row(Citation='28', count=17),
#  Row(Citation='203', count=1),
#  Row(Citation='199', count=1),
#  Row(Citation='85', count=2),
#  Row(Citation='16', count=70),
#  Row(Citation='35', count=15),
#  Row(Citation='52', count=7),
#  Row(Citation='183', count=1),
#  Row(Citation='71', count=6),
#  Row(Citation='98', count=2),
#  Row(Citation='99', count=3),
#  Row(Citation='47', count=10),
#  Row(Citation='110', count=4),
#  Row(Citation=' may be modeled by means of functional dependencies (FD). They have been extended to …"', count=1),
#  Row(Citation='179', count=1),
#  Row(Citation='284', count=1),
#  Row(Citation='327', count=1),
#  Row(Citation='96', count=4),
#  Row(Citation='484', count=1),
#  Row(Citation='804', count=1),
#  Row(Citation='43', count=5),
#  Row(Citation='5', count=206),
#  Row(Citation='31', count=12),
#  Row(Citation='18', count=39),
#  Row(Citation='70', count=4),
#  Row(Citation='27', count=21),
#  Row(Citation='61', count=10),
#  Row(Citation='75', count=7),
#  Row(Citation='166', count=1),
#  Row(Citation='17', count=48),
#  Row(Citation='126', count=2),
#  Row(Citation='131', count=2),
#  Row(Citation='26', count=31),
#  Row(Citation='120', count=1),
#  Row(Citation='46', count=10),
#  Row(Citation='130', count=2),
#  Row(Citation='207', count=1),
#  Row(Citation='164', count=1),
#  Row(Citation='78', count=4),
#  Row(Citation='328', count=1),
#  Row(Citation='77', count=6),
#  Row(Citation='89', count=2),
#  Row(Citation='6', count=185),
#  Row(Citation='118', count=1),
#  Row(Citation='Unknown', count=1247),
#  Row(Citation='246', count=1),
#  Row(Citation='68', count=2),
#  Row(Citation='104', count=1),
#  Row(Citation='413', count=1),
#  Row(Citation='60', count=1),
#  Row(Citation='19', count=41),
#  Row(Citation='578', count=1),
#  Row(Citation='335', count=1),
#  Row(Citation='23', count=41),
#  Row(Citation='41', count=16),
#  Row(Citation='280', count=1),
#  Row(Citation='102', count=4),
#  Row(Citation='55', count=7),
#  Row(Citation='111', count=3),
#  Row(Citation='507', count=1),
#  Row(Citation='167', count=1),
#  Row(Citation='95', count=3),
#  Row(Citation='93', count=4),
#  Row(Citation='103', count=3),
#  Row(Citation='40', count=4),
#  Row(Citation='38', count=16),
#  Row(Citation='25', count=30),
#  Row(Citation='189', count=1),
#  Row(Citation='135', count=2),
#  Row(Citation='156', count=1),
#  Row(Citation='44', count=6),
#  Row(Citation='144', count=3),
#  Row(Citation='82', count=1),
#  Row(Citation='115', count=1),
#  Row(Citation='53', count=9),
#  Row(Citation='245', count=1),
#  Row(Citation='92', count=5),
#  Row(Citation='294', count=1),
#  Row(Citation='108', count=3),
#  Row(Citation='117', count=4),
#  Row(Citation='247', count=1),
#  Row(Citation='86', count=2),
#  Row(Citation='58', count=4),
#  Row(Citation='81', count=4),
#  Row(Citation='33', count=17),
#  Row(Citation='242', count=2),
#  Row(Citation='213', count=1),
#  Row(Citation='269', count=1),
#  Row(Citation='178', count=1),
#  Row(Citation='48', count=12),
#  Row(Citation='153', count=1),
#  Row(Citation='148', count=2),
#  Row(Citation='173', count=2),
#  Row(Citation='159', count=2),
#  Row(Citation='97', count=5),
#  Row(Citation='427', count=1),
#  Row(Citation='67', count=7),
#  Row(Citation='158', count=2),
#  Row(Citation='106', count=4),
#  Row(Citation='84', count=1),
#  Row(Citation='143', count=2),
#  Row(Citation='564', count=1),
#  Row(Citation='79', count=2),
#  Row(Citation='9', count=140),
#  Row(Citation='24', count=25),
#  Row(Citation='212', count=1),
#  Row(Citation='32', count=21),
#  Row(Citation='116', count=1),
#  Row(Citation='299', count=2),
#  Row(Citation='88', count=1),
#  Row(Citation='1', count=397),
#  Row(Citation='105', count=1),
#  Row(Citation='20', count=28),
#  Row(Citation='56', count=6),
#  Row(Citation='127', count=1),
#  Row(Citation='36', count=23),
#  Row(Citation='211', count=1),
#  Row(Citation='10', count=107),
#  Row(Citation='37', count=15),
#  Row(Citation='165', count=2),
#  Row(Citation='49', count=4),
#  Row(Citation='63', count=6),
#  Row(Citation='181', count=1),
#  Row(Citation='65', count=10),
#  Row(Citation='265', count=1),
#  Row(Citation='4', count=225),
#  Row(Citation='121', count=2),
#  Row(Citation='39', count=16),
#  Row(Citation='62', count=6),
#  Row(Citation='12', count=107),
#  Row(Citation='339', count=1),
#  Row(Citation='109', count=2),
#  Row(Citation='123', count=1),
#  Row(Citation='13', count=61),
#  Row(Citation='21', count=33),
#  Row(Citation='14', count=66),
#  Row(Citation='182', count=1),
#  Row(Citation='66', count=5),
#  Row(Citation='91', count=2),
#  Row(Citation='175', count=2),
#  Row(Citation='94', count=1),
#  Row(Citation='74', count=9),
#  Row(Citation='72', count=8),
#  Row(Citation='129', count=1),
#  Row(Citation='1546', count=1),
#  Row(Citation='76', count=2),
#  Row(Citation='2', count=334),
#  Row(Citation='460', count=1),
#  Row(Citation='80', count=2),
#  Row(Citation='1409', count=1),
#  Row(Citation='50', count=10),
#  Row(Citation='330', count=1),
#  Row(Citation='45', count=10),
#  Row(Citation='57', count=11)]

# %%
df_art = df_art.filter(df_art.Citation != ' may be modeled by means of functional dependencies (FD). They have been extended to â€¦"')

# %%
df_art.groupBy('Journal').count().collect()
# Out:
# [Row(Journal='International Journal of Performance Analysis in Sport', count=4),
#  Row(Journal='The Journal of Logic and Algebraic Programming', count=1),
#  Row(Journal='Artificial intelligence in medicine', count=1),
#  Row(Journal='Proceedings of AICS 2018 -Irish Conference on Artificial Intelligence and Cognitive Science', count=1),
#  Row(Journal='IEEE transactions on Education', count=1),
#  Row(Journal='NTCIR-14 Conference', count=1),
#  Row(Journal='Information technology: research and development', count=1),
#  Row(Journal='Int. J. Asian Lang. Process.', count=1),
#  Row(Journal='Automation in Construction', count=1),
#  Row(Journal='arXiv preprint arXiv:2104.13473', count=2),
#  Row(Journal='IConference 2016 Proceedings', count=1),
#  Row(Journal='IEEE multimedia', count=1),
#  Row(Journal='ICVS, Bielefeld', count=1),
#  Row(Journal='Journal of Computational Science', count=5),
#  Row(Journal='arXiv preprint arXiv:1906.09833', count=1),
#  Row(Journal='Proceedings of the 2019 International Society of Behavioral Nutrition and Physical Activity Annual Meeting.', count=1),
#  Row(Journal='arXiv preprint arXiv:1009.3798', count=1),
#  Row(Journal='Multicon Lecture Notes', count=1),
#  Row(Journal='Logical Methods in Computer Science', count=1),
#  Row(Journal='EURASIP Journal on Image and Video Processing', count=1),
#  Row(Journal='arXiv preprint arXiv:1605.06770', count=1),
#  Row(Journal='Proceedings of IADIS International Conference WWW/Internet', count=1),
#  Row(Journal='IEEE MultiMedia', count=2),
#  Row(Journal='Journal of Software Engineering and Applications', count=1),
#  Row(Journal='American Journal of Sports Science', count=2),
#  Row(Journal='International Journal of Modern Physics C', count=7),
#  Row(Journal='Keynote presentation at Infotech Oulu International Workshop on Information Retrieval, Oulu, Finland', count=1),
#  Row(Journal='Medical and Biological Engineering and Computing', count=1),
#  Row(Journal='Proceedings of Translating and the Computer', count=3),
#  Row(Journal='ITE Transactions on Media Technology and Applications', count=2),
#  Row(Journal='Poster presented at the Memories for Life Colloquium 2006, British Library Conference Centre', count=1),
#  Row(Journal='ADVANCES IN INFORMATION RETRIEVAL, ECIR 2017', count=1),
#  Row(Journal='Situational Awareness for Assistive Technologies', count=1),
#  Row(Journal='Technical Report', count=1),
#  Row(Journal='IEEE transactions on information technology in biomedicine', count=1),
#  Row(Journal='Cerebral cortex', count=1),
#  Row(Journal='arXiv preprint arXiv:2008.11257', count=1),
#  Row(Journal='Cluster Computing', count=1),
#  Row(Journal='LNCS/LNAI', count=1),
#  Row(Journal='Proc. of The 3rd International Workshop on Information Retrieval with Asian Languages, 1998', count=1),
#  Row(Journal='Information Extraction A Multidisciplinary Approach to an Emerging Information Technology', count=1),
#  Row(Journal='International Journal of Computers in Healthcare 1', count=1),
#  Row(Journal='arXiv preprint arXiv:2107.11098', count=1),
#  Row(Journal='arXiv preprint arXiv:2010.10350', count=1),
#  Row(Journal='LTA 2016-Proceedings of the 1st Workshop on Lifelogging Tools and Applications, co-located with ACM Multimedia 2016', count=1),
#  Row(Journal='Information Processing & Management', count=5),
#  Row(Journal='Journal of statistical physics', count=2),
#  Row(Journal='International Journal of Computer Games Technology', count=1),
#  Row(Journal='IEEE Robotics & Automation Magazine', count=1),
#  Row(Journal='arXiv preprint arXiv:2012.15641', count=1),
#  Row(Journal='Journal of information science', count=1),
#  Row(Journal='Systems, Software and Services Process Improvement: 26th European Conference, EuroSPI 2019, Edinburgh, UK, September 18–20, 2019, Proceedings', count=2),
#  Row(Journal='Irish Medicines Board Medical Devices Newsletter', count=1),
#  Row(Journal='International Conference on Solid State Ionics. Applications: Fuel Cells. Baden–Baden. July. p', count=1),
#  Row(Journal='International Conference on Logic Programming (ICLP), Technical Communications', count=1),
#  Row(Journal='Proceedings of EMAIL-08: the AAAI Workshop on Enhanced Messaging', count=1),
#  Row(Journal='Information retrieval', count=4),
#  Row(Journal='IEEE Transactions on Circuits and Systems for Video Technology', count=1),
#  Row(Journal='CONGRESS PROCEEDINGS', count=1),
#  Row(Journal='ACM Transactions on Modeling and Computer Simulation-TOMACS', count=1),
#  Row(Journal='LANGUAGE', count=1),
#  Row(Journal='2nd International Workshop on Managing Ubiquitous Communications and Services, Dublin, Ireland', count=1),
#  Row(Journal='IET Software', count=7),
#  Row(Journal='Proceedings of the International Conference on Software Engineering Applied to Networking & Parallel/Distributed Computing. Reims, France', count=1),
#  Row(Journal='Khresmoi project deliverable D', count=2),
#  Row(Journal='Open Educational Resources and Social Networks: Colearning and professional development', count=1),
#  Row(Journal='JOURNAL OF COMPUTATIONAL BIOLOGY', count=1),
#  Row(Journal='Journal of Research (NIST JRES)-NIST', count=1),
#  Row(Journal="The Engineer's Journal", count=1),
#  Row(Journal='The 23~(rd) International Conference on Computational Linguistics Proceedings of the Main Conference (Volume 1)', count=1),
#  Row(Journal='Contemporary Clinical Trials Communications', count=1),
#  Row(Journal='Journal of biomechanics', count=1),
#  Row(Journal='ACM Transactions on Knowledge Discovery from Data (TKDD)', count=1),
#  Row(Journal='TEANGA, the Journal of the Irish Association for Applied Linguistics', count=1),
#  Row(Journal='Project Networking Session at ESWC', count=1),
#  Row(Journal='Journal of Educational Computing Research', count=1),
#  Row(Journal='communication présentée au 5e workshop JEM (Joining Educational Mathematics, eContentPlus Thematic Network), Paris (France), En ligne http://chezdom. net/wp-content/uploads/2008/11/jem112008-dom-don. pdf, consulté le', count=1),
#  Row(Journal='People and Computers XXII Culture, Creativity, Interaction 22', count=1),
#  Row(Journal='arXiv preprint arXiv:1312.1913', count=1),
#  Row(Journal='CW Reports', count=1),
#  Row(Journal='Science', count=1),
#  Row(Journal='Süleyman Demirel Üniversitesi Fen Bilimleri Enstitüsü Dergisi', count=2),
#  Row(Journal='7th ICML Workshop on Automated Machine Learning (AutoML 2020)', count=1),
#  Row(Journal='Chemical Design Automation News', count=1),
#  Row(Journal='Proceedings of ACM International Conference on Web Search and Data Mining. ACM', count=1),
#  Row(Journal='ACM SIGMOD Record', count=5),
#  Row(Journal='International Journal of Wavelets, Multiresolution and Information Processing', count=1),
#  Row(Journal='Interdisciplinary Sciences: Computational Life Sciences', count=1),
#  Row(Journal='Simulation modelling practice and theory', count=4),
#  Row(Journal='Irish HCI conference 2013', count=1),
#  Row(Journal='DNA METHYLATION–FROM GENOMICS TO TECHNOLOGY', count=1),
#  Row(Journal='Journal of the American Society for Information Science and Technology', count=2),
#  Row(Journal='arXiv preprint arXiv:2005.00283', count=1),
#  Row(Journal='Digital Scholarship in the Humanities', count=1),
#  Row(Journal='arXiv preprint arXiv:2010.12728', count=1),
#  Row(Journal='Software Quality Professional', count=3),
#  Row(Journal='CAA 2002 International Conference, University of Loughborough, Retrieved from http://caaconference. com', count=1),
#  Row(Journal='International Conference on Computers Helping People with Special Needs, Doctoral Consortium', count=1),
#  Row(Journal='Ecological Informatics', count=1),
#  Row(Journal='Center On Disabilities Technology And Persons With Disabilities Conference, California State University, Northridge', count=1),
#  Row(Journal='arXiv preprint arXiv:1906.06147', count=1),
#  Row(Journal='Contemporary Psychoanalysis', count=1),
#  Row(Journal='20th Annual BCS-IRSG Colloquium on IR 20', count=2),
#  Row(Journal='PLOS ONE', count=1),
#  Row(Journal='Journal of Engineering and Applied Sciences', count=1),
#  Row(Journal='Theory and Practice of Logic Programming', count=4),
#  Row(Journal='Journal of Computational Biology', count=1),
#  Row(Journal='Memory', count=1),
#  Row(Journal='Proceedings of The IASTED Technology Conferences (International Conference on Computational Bioscience). Cambridge, Massachusetts', count=2),
#  Row(Journal='Universal dependencies', count=1),
#  Row(Journal='Proceedings of the 24th international conference of the European federation for medical informatics', count=1),
#  Row(Journal='Sensors', count=8),
#  Row(Journal='Bury St. Edmunds, UK: Thames Valley Test Company', count=1),
#  Row(Journal='Machine translation', count=5),
#  Row(Journal='Language resources and evaluation', count=2),
#  Row(Journal='IEEE/ACM transactions on computational biology and bioinformatics', count=1),
#  Row(Journal='Information Sciences', count=2),
#  Row(Journal='arXiv preprint arXiv:2104.04497', count=1),
#  Row(Journal='Summary report of the series of joint NSF-EU working groups on future directions for digital library research', count=1),
#  Row(Journal='Pattern Analysis & Applications', count=1),
#  Row(Journal='Information', count=2),
#  Row(Journal='ERCIM News', count=23),
#  Row(Journal='International journal of cardiology', count=1),
#  Row(Journal='Universal access in HCI: towards an information society for all', count=1),
#  Row(Journal='Proceedings of the 2nd International Conference on Computer-Human Interaction Research and Applications-Volume 1: CHIRA', count=1),
#  Row(Journal='The Semantic Web', count=1),
#  Row(Journal='arXiv preprint arXiv:1512.03860', count=1),
#  Row(Journal='Journal of Wireless Mobile Networks, Ubiquitous Computing, and Dependable Applications', count=1),
#  Row(Journal='arXiv preprint arXiv:1906.10047', count=1),
#  Row(Journal='Selecting Models from Data: Artificial Intelligence and Statistics IV', count=1),
#  Row(Journal='Procesamiento del Lenguaje Natural', count=1),
#  Row(Journal='16th European Conference on Technology-Enhanced Learning (EC-TEL), Bozen-Bolzano, Italy (online), September 2021', count=2),
#  Row(Journal='EVALITA. Evaluation of NLP and Speech Tools for Italian', count=2),
#  Row(Journal='Journal of Universal Computer Science', count=5),
#  Row(Journal='Academy of Management Proceedings', count=1),
#  Row(Journal='International journal of Web engineering and technology', count=2),
#  Row(Journal='Proceedings of the Workshop on Sentiment Analysis where AI meets Psychology (SAAIP 2011)}', count=1),
#  Row(Journal='The Journal of Strength & Conditioning Research', count=5),
#  Row(Journal='arXiv preprint arXiv:2109.06105', count=1),
#  Row(Journal='Press Start', count=1),
#  Row(Journal='Applied Computer Translation', count=1),
#  Row(Journal='Proc First International Conference on Pervasive Computing, Zurich, Switzerland', count=1),
#  Row(Journal='research@ ua', count=1),
#  Row(Journal='IET Conference Proceedings', count=1),
#  Row(Journal='Information and Computation', count=1),
#  Row(Journal='Logic Programming and Nonmonotonic Reasoning: 15th International Conference, LPNMR 2019, Philadelphia, PA, USA, June 3-7, 2019, Proceedings', count=1),
#  Row(Journal='Proceedings of the Conference on Recent Advances in Natural Language Processing (RANLP 21), Online', count=1),
#  Row(Journal='arXiv preprint arXiv:2102.00980', count=1),
#  Row(Journal='Communications of SIWN', count=1),
#  Row(Journal='Journal of Internet Services and Information Security', count=1),
#  Row(Journal='Saber', count=1),
#  Row(Journal='Online Review', count=1),
#  Row(Journal='Recent Advances in Computer Science and Communications', count=1),
#  Row(Journal='The Elements of Big Data Value', count=1),
#  Row(Journal='arXiv preprint arXiv:1704.04347', count=1),
#  Row(Journal='Proceedings of the BCS Information Retrieval Specialist Group Colloquium on Information Retrieval Research', count=1),
#  Row(Journal='arXiv preprint arXiv:2005.12138', count=2),
#  Row(Journal="Multimedia Data Base Management Systems' Workshop at the 2nd ACM International Conference on Multimedia", count=1),
#  Row(Journal='Annexe Thesis Digitisation Project 2017 Block 16', count=1),
#  Row(Journal='Journal of Theoretical Biology', count=1),
#  Row(Journal='Proceedings of the 19th Annual BCS-IRSG Colloquium on IR Research 19', count=1),
#  Row(Journal='Future Generation Computer Systems', count=4),
#  Row(Journal='Multimedia tools and applications', count=1),
#  Row(Journal='Poster presented at the Memories for Life Colloquium', count=1),
#  Row(Journal='RDF Stream Processing Workshop (ESWC2015)', count=1),
#  Row(Journal='Information retrieval: new systems and current research: proceedings of the 16th Research Colloquium of the British Computer Society Information Retrieval Specialist Group, Drymen, 1994', count=1),
#  Row(Journal='Thames Valley Test Company, Edmonds', count=1),
#  Row(Journal='SpringerPlus', count=1),
#  Row(Journal='Future Internet', count=1),
#  Row(Journal='International Journal on Digital Libraries', count=5),
#  Row(Journal='Image and video retrieval', count=1),
#  Row(Journal='Paladyn, Journal of Behavioral Robotics', count=3),
#  Row(Journal='Open Computer Science', count=1),
#  Row(Journal='The Irish Journal of Psychology', count=1),
#  Row(Journal='IEEE International Conference Proceedings on Pervasive Computing, Zurich, Switzerland (August 2002)', count=1),
#  Row(Journal='IET Image Processing', count=1),
#  Row(Journal='Journal of Network and Systems Management', count=1),
#  Row(Journal='Advanced Visual Interfaces AVI, Workshop on Gender &amp; Interaction, Real &amp; virtual women in a male world', count=1),
#  Row(Journal='IEEE Transactions on Intelligent Transportation Systems', count=1),
#  Row(Journal='arXiv preprint arXiv:2107.12930', count=1),
#  Row(Journal='Third International Valentin Turchin Workshop on Metacomputation', count=1),
#  Row(Journal='Neuroimage', count=2),
#  Row(Journal='Proceedings of the 7th IASTED International Conference', count=1),
#  Row(Journal="Proceedings of the Evaluators' Forum", count=1),
#  Row(Journal='arXiv preprint arXiv:1811.05909', count=1),
#  Row(Journal='MT-Summit VIII, Santiago de Compostela, Spain', count=1),
#  Row(Journal='arXiv preprint arXiv:2004.11471', count=1),
#  Row(Journal='arXiv preprint arXiv:2108.11347', count=1),
#  Row(Journal='Cognitive Computation', count=3),
#  Row(Journal='International Journal of Advanced Computer Science and Applications', count=2),
#  Row(Journal='Fuzzy sets and systems', count=1),
#  Row(Journal='Behaviour & Information Technology', count=1),
#  Row(Journal='The New Review of Document and Text Management', count=1),
#  Row(Journal='Workshop on Matching and Meaning-Automated Development, Evolution and Interpretation of Ontologies', count=1),
#  Row(Journal='Localisation Focus-The International Journal of Localisation', count=1),
#  Row(Journal='Rheumatology', count=2),
#  Row(Journal='Shlomo Geva, Jaap Kamps, Ralf Schenkel, Andrew Trotman', count=1),
#  Row(Journal='arXiv preprint arXiv:2007.00461', count=1),
#  Row(Journal='Annual Review of Information Science and Technology (ARIST)', count=1),
#  Row(Journal='arXiv preprint arXiv:2111.00314', count=1),
#  Row(Journal='arXiv preprint arXiv:2011.14190', count=1),
#  Row(Journal='Theory in Biosciences', count=8),
#  Row(Journal='DE LINGÜÍSTICA COMPUTACIONAL Y DE CORPUS', count=1),
#  Row(Journal='Program', count=1),
#  Row(Journal='JMIR rehabilitation and assistive technologies', count=1),
#  Row(Journal='Proceedings of the Workshop on Matching and Meaning', count=1),
#  Row(Journal='arXiv preprint arXiv:2107.01982', count=1),
#  Row(Journal='Assistive technologies', count=1),
#  Row(Journal='Journal of non-crystalline solids', count=1),
#  Row(Journal='Proceedings Workshop on Securité de la Communication sur Internet (SECI 2002)', count=1),
#  Row(Journal='Proceedings of ICLP Workshop on Specification, Analysis and Validation for Emerging technologies in computational logic', count=1),
#  Row(Journal='Journal of the Association for Information Science and Technology', count=1),
#  Row(Journal='arXiv preprint arXiv:1808.10432', count=1),
#  Row(Journal='J. Exp. Theor. Artif. Intell.', count=1),
#  Row(Journal='Prague Bulletin of Mathematical Linguistics', count=4),
#  Row(Journal='International Journal of Theoretical and Applied Finance', count=2),
#  Row(Journal='Garyounis University Press. Journal of Science and Its Applications', count=2),
#  Row(Journal='Association for Computational Linguistics (ed.). Proceedings of the First Conference on Machine Translation (WMT16). Stroudsburg: The Association for Computational Linguistics', count=1),
#  Row(Journal='Bioinformatics Research and Development', count=1),
#  Row(Journal='SIGIR Forum', count=1),
#  Row(Journal='Proceedings of the Third International Workshop in Artificial Intelligence and Statistics', count=1),
#  Row(Journal='Maintaining the links: language, identity and the land', count=1),
#  Row(Journal='SMEC2016 Organising Committee', count=1),
#  Row(Journal='arXiv preprint arXiv:1905.10486', count=1),
#  Row(Journal='arXiv preprint arXiv:2109.08122', count=1),
#  Row(Journal='5th Irish Workshop on Formal Methods 5', count=1),
#  Row(Journal='Proceedings of the 7th East European Conference on Advances in Databases and Information Systems (ADBIS)', count=1),
#  Row(Journal='Open Colorectal Cancer J', count=1),
#  Row(Journal='Image Analysis and Recognition', count=1),
#  Row(Journal='International Journal of Modeling and Optimization', count=1),
#  Row(Journal='Interaktive Kulturen: Workshop-Band: Proceedings der Workshops der Mensch & Computer 2010-10. Fachübergreifende Konferenz für Interaktive und Kooperative Medien, DeLFI 2010-die 8. E-Learning Fachtagung Informatik der Gesellschaft für Informatik eV und der Entertainment Interfaces 2010', count=1),
#  Row(Journal='IEEE Access', count=3),
#  Row(Journal='IEEE Transactions on Multimedia', count=3),
#  Row(Journal='Bury St. Edmunds, England: Thames Valley Test Company', count=1),
#  Row(Journal='Physica A: Statistical Mechanics and its applications', count=2),
#  Row(Journal='日経コンピュ-タ', count=1),
#  Row(Journal='iHCI 2008—Irish Human Computer Interaction Conference', count=1),
#  Row(Journal='CALL for widening participation: short papers from EUROCALL 2020', count=1),
#  Row(Journal='arXiv preprint arXiv:1607.02229', count=1),
#  Row(Journal='Achieving Human-Level Intelligence through Integrated Systems and Research: Papers from the AAAI 2004 Fall Symposium', count=1),
#  Row(Journal='Proceedings of the 15th Portuguese Conference on Artificial Intelligence', count=1),
#  Row(Journal='International Journal of Human Capital and Information Technology Professionals (IJHCITP)', count=1),
#  Row(Journal='International Journal of Web Information Systems', count=1),
#  Row(Journal='EICIM News, Special Edition on the Sensor Web', count=1),
#  Row(Journal='ELCVIA: electronic letters on computer vision and image analysis', count=1),
#  Row(Journal='Journees ATALA, Corpus annotes pour la syntaxe, Actes,(Proceedings ATALA Workshop-Treebanks), l’Universite Paris', count=1),
#  Row(Journal='Proceedings of the tenth Biennial Conference of the Association for Machine Translation in the Americas (AMTA), San Diego, CA', count=1),
#  Row(Journal='COMPUTER', count=1),
#  Row(Journal='Proceedings of the 1st Workshop on the Multilingual Semantic Web, CEUR', count=1),
#  Row(Journal='IEEE Transactions on Automation Science and Engineering', count=2),
#  Row(Journal='SEMANTiCS 2016', count=1),
#  Row(Journal='Fundamenta Informaticae', count=1),
#  Row(Journal='ERCIM News,(63)', count=2),
#  Row(Journal='Language Resources and Evaluation', count=2),
#  Row(Journal='Information Retrieval Journal', count=4),
#  Row(Journal='Applied optics', count=1),
#  Row(Journal='Biological Psychiatry', count=1),
#  Row(Journal='International Journal on Asian Language Processing', count=1),
#  Row(Journal='BMC bioinformatics', count=3),
#  Row(Journal='Journal of theoretical biology', count=3),
#  Row(Journal='Investigating Virtual Reality as a Tool for Visual Lifelog Exploration', count=1),
#  Row(Journal='Proceedings of IJCAI-03 Workshop for Nonmonotonic Reasoning, Action and Change', count=1),
#  Row(Journal='AAAI spring symp. on intelligent multimedia knowledge management', count=1),
#  Row(Journal='Journal of Documentation', count=2),
#  Row(Journal='ERCIM NEWS Special: Supercomputing at Work [Электронный ресурс]', count=1),
#  Row(Journal='arXiv preprint arXiv:1708.07223', count=1),
#  Row(Journal='Biomedical Instrumentation & Technology', count=2),
#  Row(Journal='Semantic Multimedia', count=1),
#  Row(Journal='IEEE Transactions on Vehicular Technology', count=1),
#  Row(Journal='UMBC Faculty Collection', count=1),
#  Row(Journal='Physica B: Condensed Matter', count=1),
#  Row(Journal='Sports biomechanics', count=1),
#  Row(Journal='IEEE Communications Magazine', count=7),
#  Row(Journal='arXiv preprint arXiv:2010.02823', count=1),
#  Row(Journal='Multimedia Tools and Applications', count=7),
#  Row(Journal='IEICE transactions on communications', count=11),
#  Row(Journal='AAAI Symposium on Cross-Language Text and Speech Retrieval. American Association for Artificial Intelligence', count=1),
#  Row(Journal='Scientific Reports', count=2),
#  Row(Journal='arXiv preprint arXiv:1607.01835', count=1),
#  Row(Journal='International Journal of Semantic Computing', count=1),
#  Row(Journal='Irish Machine Vision & Image Processing Conference', count=1),
#  Row(Journal='Intelligent Systems Technologies and Applications: Volume 2', count=1),
#  Row(Journal='World Wide Web', count=1),
#  Row(Journal='CLEF', count=1),
#  Row(Journal='Applied Artificial Intelligence an International Journal', count=1),
#  Row(Journal='Journal of Software: Evolution and Process', count=10),
#  Row(Journal='IEEE Transactions on Software Engineering', count=3),
#  Row(Journal='arXiv preprint arXiv:2109.07954', count=2),
#  Row(Journal='Trans. Mach. Learn. Data Min.', count=1),
#  Row(Journal='Health Informatics Journal', count=2),
#  Row(Journal='Proceedings of TREC-2001', count=1),
#  Row(Journal='ENRICH 2013 Conference Proceedings', count=1),
#  Row(Journal='Human–Computer Interaction', count=1),
#  Row(Journal='Galway, Ireland', count=1),
#  Row(Journal='IET Control Theory and Applications', count=1),
#  Row(Journal='Advances in Complex Systems', count=4),
#  Row(Journal='6th ACM SIGMM workshop on multimedia', count=2),
#  Row(Journal='IEEE Internet of Things Journal', count=1),
#  Row(Journal='Journal de Physique', count=1),
#  Row(Journal='Proceedings of the NTCIR-15 Conference', count=2),
#  Row(Journal='MediaEval 2013', count=2),
#  Row(Journal='Journal of Computer Research and Development', count=1),
#  Row(Journal='Aids', count=1),
#  Row(Journal='JMIR mHealth and uHealth', count=2),
#  Row(Journal='Methods of Information in Medicine', count=1),
#  Row(Journal='novática', count=1),
#  Row(Journal='Proceedings of AICS Conference. Trinity College, Dublin', count=1),
#  Row(Journal='IEEE Transactions on Computers', count=1),
#  Row(Journal='Journal on Technology & Persons with Disabilities', count=2),
#  Row(Journal='arXiv preprint arXiv:2005.02693', count=1),
#  Row(Journal='Journal of High Energy Physics', count=1),
#  Row(Journal='Procesamiento del lenguaje natural', count=1),
#  Row(Journal='IEEE/ACM Transactions on Networking', count=1),
#  Row(Journal='Physica A', count=1),
#  Row(Journal='PARIS Inalco du 4 au 8 juillet 2016', count=1),
#  Row(Journal='IJCoL. Italian Journal of Computational Linguistics', count=1),
#  Row(Journal='Systems, Software and Services Process Improvement: 27th European Conference, EuroSPI 2020, Düsseldorf, Germany, September 9–11, 2020, Proceedings', count=1),
#  Row(Journal='Science of Computer Programming', count=1),
#  Row(Journal='Australasian Language Technology Association Workshop 2012', count=1),
#  Row(Journal='Second International Workshop on Adaptive Information Retrieval (AIR)', count=2),
#  Row(Journal='ACM Sigmod Record', count=1),
#  Row(Journal='ERCIM NEWS', count=1),
#  Row(Journal='Journal of neural engineering', count=1),
#  Row(Journal='ACM Transactions on Modeling and Computer Simulation (TOMACS)', count=1),
#  Row(Journal='XRDS: Crossroads, The ACM Magazine for Students', count=2),
#  Row(Journal='Microarrays', count=3),
#  Row(Journal='arXiv preprint arXiv:2003.12103', count=1),
#  Row(Journal='Urban development', count=1),
#  Row(Journal='Proceedings of the 6th European Conference on Artificial Life (ECAL-01)', count=1),
#  Row(Journal='Mathematical Proceedings of the Royal Irish Academy', count=1),
#  Row(Journal='Journal of neuroscience methods', count=1),
#  Row(Journal='CLEF 2013 Online Working Notes', count=1),
#  Row(Journal='IEEE Transactions on Big Data', count=1),
#  Row(Journal='Journal of biomedical informatics', count=1),
#  Row(Journal="Proceedings of the Final Workshop on Multimedia Information Retrieval (Miro'95)", count=1),
#  Row(Journal='计算机集成制造系统', count=1),
#  Row(Journal='PloS one', count=5),
#  Row(Journal='Engineering Proceedings', count=2),
#  Row(Journal='Journal of Informatics in Education', count=1),
#  Row(Journal='SemSearch', count=1),
#  Row(Journal='Foundations and Trends® in Information Retrieval', count=2),
#  Row(Journal='The What, Who, Where, When, Why and How of Context-Awareness', count=1),
#  Row(Journal='Submitted for publication', count=1),
#  Row(Journal='Energy Policy', count=1),
#  Row(Journal='Third Workshop on Post-Editing Technology and Practice', count=1),
#  Row(Journal='2014 TREC Video Retrieval Evaluation, (TRECVid) 10-12 November 2014', count=1),
#  Row(Journal='5th Scandinavian Workshop on Applied Eye Tracking SWAET 2010', count=1),
#  Row(Journal='arXiv preprint arXiv:1810.06195', count=1),
#  Row(Journal='The Computer Journal', count=10),
#  Row(Journal='Software: Practice and Experience', count=2),
#  Row(Journal='European Research Consortium for Informatics and Mathematics News Journal (ERCIM’04) Disponível em Disponível: http://www. computing. dcu. ie/~ nking/ercim04. pdf. Acessado em', count=1),
#  Row(Journal='Science and Engineering Ethics', count=1),
#  Row(Journal='Entropy', count=1),
#  Row(Journal='Unknown', count=3387),
#  Row(Journal='Simulation Modelling Practice and Theory', count=4),
#  Row(Journal='In Proceedings of MT Summit VII Workshop on Machine Translation for Cross Language Information Retrieval', count=1),
#  Row(Journal='MRC 2010', count=1),
#  Row(Journal='Procedia Chemistry', count=1),
#  Row(Journal='Physica A: Statistical Mechanics and its Applications', count=26),
#  Row(Journal='Proceedings of the Association for Information Science and Technology', count=1),
#  Row(Journal='Measuring Behavior 2014', count=1),
#  Row(Journal='DCU Press', count=1),
#  Row(Journal='Foundations and Trends in Information Retrieval', count=2),
#  Row(Journal='Proceedings FLOC workshop Probabilistic Logic Programming', count=1),
#  Row(Journal='Computer Assisted language learning', count=1),
#  Row(Journal='Poster presented at the International Society on Oxygen Transport to Tissues (ISOTT) Conference (London)', count=1),
#  Row(Journal='Online Information Review', count=3),
#  Row(Journal='Larson, MA; Hicks, SA; Constantin, MG (ed.), MediaEval 2019: Multimedia Benchmark Workshop Working Notes Proceedings of the MediaEval 2019 Workshop Sophia Antipolis, France, 27-30 October 2019', count=1),
#  Row(Journal='arXiv preprint arXiv:1909.03750', count=2),
#  Row(Journal='The International Journal of Multimedia & Its Applications', count=1),
#  Row(Journal='Emerging Paradigms in Informatics, Systems and Communication', count=1),
#  Row(Journal='Proceedings of MTML', count=1),
#  Row(Journal='MethodsX', count=3),
#  Row(Journal='The Prague Bulletin of Mathematical Linguistics', count=6),
#  Row(Journal='FRONTIERS IN ARTIFICIAL INTELLIGENCE AND APPLICATIONS', count=1),
#  Row(Journal='European Journal of Information Systems', count=1),
#  Row(Journal='Prague, Czech Republic', count=1),
#  Row(Journal='Computer-IEEE Computer Magazine', count=1),
#  Row(Journal='Journal of Web Semantics', count=1),
#  Row(Journal='arXiv preprint arXiv:1902.05624', count=1),
#  Row(Journal='arXiv preprint arXiv:2008.02936', count=1),
#  Row(Journal='EPiC Series in Computing', count=1),
#  Row(Journal='Medical Physics International', count=1),
#  Row(Journal='AIP Conference Proceedings', count=1),
#  Row(Journal='Journal of Economics, Management and Trade', count=2),
#  Row(Journal='CEUR workshop proceedings', count=1),
#  Row(Journal='Journal of Computer Science and technology', count=1),
#  Row(Journal='Journal of Physics: Condensed Matter', count=1),
#  Row(Journal='Fourth International Valentin Turchin Workshop on Metacomputa-tion//Proceedings of the Fourth International Valentin Turchin Workshop on Metacomputation. Pereslavl-Zalessky, Russia, June 29–July 3, 2014/Edited by AV Klimov and SA Romamenko.—Pereslavl Zalessky: Publishing House “University of Pereslavl”, 2014, 256 p.—ISBN 978-5-901795-31-6', count=1),
#  Row(Journal='International journal of intelligent systems', count=1),
#  Row(Journal='Journal of Cancer', count=1),
#  Row(Journal='Journal of Digital Information Management', count=1),
#  Row(Journal='Proceedings of the 11th International Conference of the CLEF Association (CLEF 2020), Thessaloniki, Greece, LNCS Lecture Notes in Computer Science', count=1),
#  Row(Journal='Fourth International Valentin Turchin Workshop on Metacomputation. Proceedings', count=1),
#  Row(Journal='Journal of Telemedicine and Telecare', count=1),
#  Row(Journal='arXiv preprint arXiv:2010.15296', count=1),
#  Row(Journal='Proceedings of TREC-5, NIST Special Publication', count=1),
#  Row(Journal='Techn. Rep', count=1),
#  Row(Journal='IFAC Proceedings Volumes', count=2),
#  Row(Journal='Second International Conference and Exhibition on the Practical Application of Java, Manchester, UK', count=1),
#  Row(Journal='CEUR Workshop Proceedings', count=3),
#  Row(Journal='Signal Processing: Image Communication', count=1),
#  Row(Journal='IEEE Transactions on Very Large Scale Integration (VLSI) Systems', count=1),
#  Row(Journal='Proceedings of TRECVID', count=2),
#  Row(Journal='Hermes', count=1),
#  Row(Journal='IEEE Systems Journal', count=1),
#  Row(Journal='ACM Computing Surveys', count=2),
#  Row(Journal='arXiv preprint arXiv:1811.03039', count=1),
#  Row(Journal='SEKT project deliverable D', count=1),
#  Row(Journal='Novática: Revista de la Asociación de Técnicos de Informática', count=1),
#  Row(Journal='arXiv preprint arXiv:2009.09984', count=1),
#  Row(Journal='Journal of Visual Communication and Image Representation', count=1),
#  Row(Journal='G3: Genes, Genomes, Genetics', count=2),
#  Row(Journal='arXiv preprint arXiv:1405.0720', count=1),
#  Row(Journal='arXiv preprint arXiv:2102.00287', count=1),
#  Row(Journal='Journal of Sports Sciences', count=1),
#  Row(Journal='Proc. of ACM MM', count=1),
#  Row(Journal='Medicine & Science in Sports & Exercise', count=3),
#  Row(Journal='Evaluating video search, video event detection, localization and hyperlinking', count=1),
#  Row(Journal='Irish Journal of Medical Science', count=1),
#  Row(Journal='Baltic J. Modern Computing', count=1),
#  Row(Journal='Web Semantics: Science, Services and Agents on the World Wide Web', count=1),
#  Row(Journal='Localisation Focus', count=2),
#  Row(Journal='ACM SIGSOFT Software Engineering Notes', count=5),
#  Row(Journal='IPSJ Transactions', count=1),
#  Row(Journal='1st international workshop on multimedia annotation and retrieval enabled by Shared Ontologies', count=1),
#  Row(Journal='arXiv preprint arXiv:2109.03571', count=1),
#  Row(Journal='challenge', count=1),
#  Row(Journal='Journal of Parallel and Distributed Computing', count=4),
#  Row(Journal='International Journal of Parallel Programming', count=1),
#  Row(Journal='Journal of Artificial Intelligence Research', count=1),
#  Row(Journal='情報処理学会研究報告情報学基礎 (FI)', count=1),
#  Row(Journal='IEE Proceedings-Science, Measurement and Technology', count=1),
#  Row(Journal='BioMed research international', count=1),
#  Row(Journal='International Journal of Psychology & Psychological Therapy', count=1),
#  Row(Journal='Data & Knowledge Engineering', count=1),
#  Row(Journal='Neurocomputing', count=6),
#  Row(Journal='Ict Express', count=1),
#  Row(Journal='Computational Linguistics in the Netherlands Journal', count=1),
#  Row(Journal='2018 TREC Video Retrieval Evaluation, TRECVID 2018, 2018 TREC Video Retrieval Evaluation, TRECVID 2018, 13 November 2018 through 15 November 2018', count=1),
#  Row(Journal='American journal of preventive medicine', count=2),
#  Row(Journal='Journal of Next Generation Information Technology', count=1),
#  Row(Journal='Cooperative Information Systems:... International Conference, CoopIS..., Proceedings', count=1),
#  Row(Journal='Zeitschrift für Physik B Condensed Matter', count=1),
#  Row(Journal='Proceedings of the Second Workshop on Applications of Natural Language to Databases (NLDB’96)', count=1),
#  Row(Journal='Multimedia, Hypermedia, and Virtual Reality Models, Systems, and Applications', count=1),
#  Row(Journal='Journal of neuroengineering and rehabilitation', count=1),
#  Row(Journal='IEEE network', count=1),
#  Row(Journal='Journal of ICT Standardization', count=4),
#  Row(Journal='arXiv preprint arXiv:2005.10583', count=1),
#  Row(Journal='SAE International Journal of Passenger Cars-Electronic and Electrical Systems', count=1),
#  Row(Journal='Proceedings of the 13th machine translation summit', count=1),
#  Row(Journal='Digital', count=2),
#  Row(Journal='arXiv preprint arXiv:2010.11307', count=1),
#  Row(Journal='Sport Sciences for Health', count=1),
#  Row(Journal='Journal of sports science & medicine', count=1),
#  Row(Journal='Research on Language and Computation', count=2),
#  Row(Journal='Computación y Sistemas', count=2),
#  Row(Journal='Information Security Journal: A Global Perspective', count=3),
#  Row(Journal='Center for Atomic-scale Materials Design (CAMD), Department of Physics, Technical University of Denmark, DK-2800 Kgs. Lyngby, Denmark', count=1),
#  Row(Journal='Journal of Digital information', count=1),
#  Row(Journal='arXiv preprint arXiv:1806.07721', count=1),
#  Row(Journal='International Journal of Mobile Human Computer Interaction (IJMHCI)', count=4),
#  Row(Journal='Computer Vision and Image Understanding', count=3),
#  Row(Journal='ISPRS International Journal of Geo-Information', count=1),
#  Row(Journal='arXiv preprint arXiv:2011.03783', count=1),
#  Row(Journal='IMAI’07-5th International Conference on Intelligent Multimedia and Ambient Intelligence', count=1),
#  Row(Journal='Advances in Information Retrieval:... European Conference on IR Research, ECIR...: Proceedings', count=1),
#  Row(Journal='Progress in Gestural Interaction: Proceedings of Gesture Workshop’96, March 19th 1996, University of York, UK', count=1),
#  Row(Journal='International Journal of Game-Based Learning (IJGBL)', count=1),
#  Row(Journal='ECML-PKDD, Proceedings of the European conference on machine learning and principles and practice of knowledge discovery in databases, Bled', count=1),
#  Row(Journal='Expert Systems with Applications', count=1),
#  Row(Journal='International Journal of Modeling, Simulation, and Scientific Computing', count=1),
#  Row(Journal='Computer', count=2),
#  Row(Journal='IJACSA thesia. org', count=1),
#  Row(Journal='计算机研究与发展', count=2),
#  Row(Journal='Atherosclerosis (Supplements)(Component)', count=1),
#  Row(Journal='Journal of Network and Computer Applications', count=1),
#  Row(Journal='Proceedings of the Royal Irish Academy. Section A: Mathematical and Physical Sciences', count=1),
#  Row(Journal='Environmental Communication', count=1),
#  Row(Journal="Proceedings, the Irish Signals and Systems Conference 2004: ISSC 2004, Queen's University Belfast, Northern Ireland, 30th June-2nd July, 2004", count=1),
#  Row(Journal='Khresmoi public deliverable', count=2),
#  Row(Journal='Khresmoi Project', count=1),
#  Row(Journal='Intelligent Systems and Their Applications, IEEE', count=1),
#  Row(Journal='Image and Vision Computing', count=2),
#  Row(Journal='arXiv preprint arXiv:2004.14774', count=1),
#  Row(Journal='WBE 2004–IASTED International Conference on Web-Based Education', count=1),
#  Row(Journal='arXiv preprint arXiv:2106.02400', count=1),
#  Row(Journal='Journal of Business & Industrial Marketing', count=1),
#  Row(Journal='Assistive Technology', count=1),
#  Row(Journal='arXiv preprint arXiv:1909.05088', count=1),
#  Row(Journal='PLoS One', count=3),
#  Row(Journal='Annals of Mathematics and Artificial Intelligence', count=1),
#  Row(Journal='ACM SIGIR Forum', count=15),
#  Row(Journal='Proceedings on International Workshop on Web Information Systems Modeling (WISM)', count=1),
#  Row(Journal='ACM International Conference Proceeding Series', count=1),
#  Row(Journal='networks', count=1),
#  Row(Journal='Technologies for Interactive Digital Storytelling and Entertainment', count=1),
#  Row(Journal='Adaptive Multimedia Retrieval: User, Context, and Feedback', count=1),
#  Row(Journal='16th Research Colloquium of the British Computer Society Information Retrieval Specialist Group', count=1),
#  Row(Journal='New Techniques and Technologies for Statistics', count=1),
#  Row(Journal='Journal of Physics: Conference Series', count=2),
#  Row(Journal='Workshop on Interfaces of Intelligent Computer-Assisted Language Learning', count=1),
#  Row(Journal='International Journal of Multimedia Information Retrieval', count=2),
#  Row(Journal='Proceedings of NTCIR-13, Tokyo, Japan', count=1),
#  Row(Journal='The 29th Text Retrieval Conference (TREC 2020) notebook. NIST', count=1),
#  Row(Journal='Proceedings of the Third Joint EM+/CNGL Workshop “Bringing MT to the User: Research Meets Translators”, JEC', count=1),
#  Row(Journal='International Conference on Intelligent Text Processing and Computational Linguistics', count=1),
#  Row(Journal='Advances in Information Retrieval', count=5),
#  Row(Journal='LD4IE@ ISWC', count=2),
#  Row(Journal='Journal of Document and Text Management', count=1),
#  Row(Journal='Proceedings of 6th International Conference on Lexical Functional Grammar (LFG-2001)', count=1),
#  Row(Journal='Journal of network and systems management', count=2),
#  Row(Journal='Systems, Software and Services Process Improvement: 25th European Conference, EuroSPI 2018, Bilbao, Spain, September 5-7, 2018, Proceedings', count=1),
#  Row(Journal='Proceedings of The Fourth Text REtrieval Conference (TREC-4)', count=1),
#  Row(Journal='MartinMcGinnity Intelligent Systems Research Centre, University of Ulster', count=1),
#  Row(Journal='iConference 2014 Proceedings', count=1),
#  Row(Journal='arXiv preprint arXiv:2005.00308', count=2),
#  Row(Journal='Translation Spaces', count=2),
#  Row(Journal='The 10th Irish Conference on Artificial Intelligence and Cognitive Science', count=1),
#  Row(Journal='Proceedings of the Second Italian Conference on Computational Linguistics CLiC-it', count=1),
#  Row(Journal='PAMM: Proceedings in Applied Mathematics and Mechanics', count=4),
#  Row(Journal='ACM Transactions on Multimedia Computing, Communications, and Applications (TOMM)', count=5),
#  Row(Journal='ACM Transactions on Asian Language Information Processing (TALIP)', count=3),
#  Row(Journal='IPSJ Journal', count=1),
#  Row(Journal='Journal of neurology', count=1),
#  Row(Journal='Proc. LFG', count=1),
#  Row(Journal='BioMed Research International', count=2),
#  Row(Journal='LDQ@ ESWC', count=1),
#  Row(Journal='International Journal of Electronic Governance', count=1),
#  Row(Journal='Journal of Ambient Intelligence and Smart Environments', count=2),
#  Row(Journal='Machine Translation', count=19),
#  Row(Journal='Journal of Cases on Information Technology (JCIT)', count=1),
#  Row(Journal='4th Workshop on Managing the Evolution and Preservation of the Data Web (MEPDaW)', count=1),
#  Row(Journal='arXiv preprint arXiv:2104.04501', count=1),
#  Row(Journal='International Journal on Advances in Life Sciences', count=1),
#  Row(Journal='BMJ open', count=1),
#  Row(Journal='IEE Proceedings - Science, Measurement And Technology', count=1),
#  Row(Journal='RSC Adv.', count=1),
#  Row(Journal='arXiv preprint arXiv:2102.12245', count=1),
#  Row(Journal='Expert systems with applications', count=1),
#  Row(Journal='Computer Networks', count=3),
#  Row(Journal='Signal Processing and Machine Learning for Brain-Machine Interfaces', count=1),
#  Row(Journal='APS March Meeting Abstracts', count=2),
#  Row(Journal='Workshop Proceedings', count=1),
#  Row(Journal='Proceedings of the CAISE', count=1),
#  Row(Journal='Journal de physique', count=1),
#  Row(Journal='The Bloomsbury companion to language industry studies', count=1),
#  Row(Journal="6th International Conference of the CLEF Association (CLEF'15)", count=1),
#  Row(Journal='International Journal of Imaging Systems and Technology', count=1),
#  Row(Journal='arXiv preprint arXiv:2109.02543', count=1),
#  Row(Journal='Pamukkale Üniversitesi Mühendislik Bilimleri Dergisi', count=1),
#  Row(Journal='JDySES', count=2),
#  Row(Journal='arXiv preprint arXiv:1905.04243', count=2),
#  Row(Journal='International Conference on Smart Homes and Health Telematics', count=1),
#  Row(Journal='Journal of the Southern African Institute of Mining and Metallurgy', count=1),
#  Row(Journal='计算机科学技术学报', count=1),
#  Row(Journal='Personalized Digital Television', count=1),
#  Row(Journal='Visual Informatics: Bridging Research and Practice', count=1),
#  Row(Journal='Proceedings of the 16th International Conference on Near-InfraRed Spectroscopy', count=1),
#  Row(Journal='Proceedings of the First Symposium on Patent Information Processing (SPIP), Tokyo, Japan', count=1),
#  Row(Journal='arXiv preprint arXiv:1908.09532', count=1),
#  Row(Journal='Dublin: Dublin City University', count=1),
#  Row(Journal='arXiv e-prints', count=2),
#  Row(Journal='Proceedings of the Irish Machine Vision Conference', count=1),
#  Row(Journal='Cadernos de Informática', count=1),
#  Row(Journal='arXiv preprint physics/0607182', count=2),
#  Row(Journal='SN Computer Science', count=1),
#  Row(Journal='Proceedings of the 12th NTCIR Conference on Evaluation of Information Access…', count=1),
#  Row(Journal='Proceedings of HCI 2011 The 25th BCS Conference on Human Computer Interaction 25', count=1),
#  Row(Journal='Agile Workshop (action and interaction in volunteered geographic information)', count=1),
#  Row(Journal='Proceedings of HCI 2007 The 21st British HCI Group Annual Conference University of Lancaster, UK 21', count=1),
#  Row(Journal='International Journal of Digital Content Technology & its Applications', count=1),
#  Row(Journal='Obesity Reviews', count=1),
#  Row(Journal='The test of everyday attention.[Google Scholar]', count=1),
#  Row(Journal='IEEE Security & Privacy', count=3),
#  Row(Journal='Bulletin de linguistique appliquée et générale', count=1),
#  Row(Journal='Proceedings of WEPIR 2018', count=1),
#  Row(Journal='Nature methods', count=1),
#  Row(Journal='TRECVID Publications Home', count=1),
#  Row(Journal='International Multimedia Conference: Proceedings of the 14 th annual ACM international conference on Multimedia', count=1),
#  Row(Journal='European Journal of Open, Distance and E-learning', count=1),
#  Row(Journal='Presentation at Translating and the Computer', count=1),
#  Row(Journal='Applied Sciences', count=1),
#  Row(Journal='arXiv preprint arXiv:2108.09763', count=1),
#  Row(Journal='Computers in Human Behavior', count=2),
#  Row(Journal='For References', count=1),
#  Row(Journal='Philosophical Transactions of the Royal Society of London. Series A: Physical and Engineering Sciences', count=1),
#  Row(Journal='Johns Hopkins University', count=1),
#  Row(Journal='Information and Software Technology', count=6),
#  Row(Journal='arXiv preprint arXiv:1910.07395', count=1),
#  Row(Journal='Brain-Computer Interfaces', count=3),
#  Row(Journal='Information Retrieval', count=2),
#  Row(Journal='MEDICAL PHYSICS', count=1),
#  Row(Journal='Journal of Exercise Science & Fitness', count=1),
#  Row(Journal='OOIS’96: 1996 International Conference on Object Oriented Information Systems 16–18 December 1996, London Proceedings', count=1),
#  Row(Journal='Journal on Image and Video Processing', count=1),
#  Row(Journal='IPSJ Transactions on Computer Vision and Applications', count=1),
#  Row(Journal='Neural Computing and Applications', count=1),
#  Row(Journal='IEEE Intelligent Systems', count=2),
#  Row(Journal='CALL in a climate of change: adapting to turbulent global conditions–short papers from EUROCALL', count=2),
#  Row(Journal='Proceedings of the SIGIR Workshop on Mobile Personal Information Retrieval, Tampere, Finland', count=1),
#  Row(Journal='Khresmoi public deliverable D', count=1),
#  Row(Journal='AUSTRALIAN JOURNAL OF INFORMATION SYSTEMS', count=1),
#  Row(Journal='Inf. Process. Manage.', count=1),
#  Row(Journal='PROCEEDINGS-SPIE THE INTERNATIONAL SOCIETY FOR OPTICAL ENGINEERING', count=2),
#  Row(Journal='Interactive Video', count=1),
#  Row(Journal='LACUS Forum', count=2),
#  Row(Journal='Arxiv preprint arXiv:1001.0497', count=1),
#  Row(Journal='First Joint IEI/IEE Symposium on Telecommunications Systems Research, Dublin, Ireland', count=1),
#  Row(Journal='Chemical science', count=1),
#  Row(Journal='Education Matters Yearbook', count=1),
#  Row(Journal='Technology-Enhanced Learning for a Free, Safe, and Sustainable World: 16th European Conference on Technology Enhanced Learning, EC-TEL 2021, Bolzano, Italy, September 20–24, 2021, Proceedings', count=1),
#  Row(Journal='CALL communities and culture: Short papers from EUROCALL', count=1),
#  Row(Journal='Annals of physical and rehabilitation medicine', count=1),
#  Row(Journal='Proceedings of the NeMNLP’97, New Methods in Natural Language Processessing', count=1),
#  Row(Journal='Int J Adv Comput Sci Appl', count=1),
#  Row(Journal='Proceedings of the 6th International Workshop on Web Information Systems Modeling. Amsterdam, The Netherlands', count=1),
#  Row(Journal='Journal of the American Society for Information Science', count=1),
#  Row(Journal='Machine Translation Summit XIV, Main Conference Proceedings', count=1),
#  Row(Journal='IEEE Transactions on Services Computing', count=1),
#  Row(Journal='Computers in Biology and Medicine', count=6),
#  Row(Journal='ERCIM Workshop User Interfaces for All, Florence, Italy', count=1),
#  Row(Journal='Plos one', count=3),
#  Row(Journal='International Journal of Behavioral Nutrition and Physical Activity', count=2),
#  Row(Journal='The handbook of computational linguistics and natural language processing', count=1),
#  Row(Journal='Semantic Web', count=3),
#  Row(Journal='Computer Standards & Interfaces', count=8),
#  Row(Journal='ALLDATA 2016', count=1),
#  Row(Journal='Proceedings of the International AAAI Conference on Web and Social Media', count=1),
#  Row(Journal='Proceedings of the ESSLLI-2000 Student Session', count=1),
#  Row(Journal='MediaEval 2012', count=2),
#  Row(Journal='IEEE Open Journal of Signal Processing', count=1),
#  Row(Journal='Proceedings of the International Workshop on Security Analysis of Systems: Formalism and Tools', count=1),
#  Row(Journal='Information processing & management', count=4),
#  Row(Journal='Bioinformatics', count=1),
#  Row(Journal='Frontiers in Human Neuroscience', count=2),
#  Row(Journal='Proceedings of the 11th International Conference on Natural Language Processing, Goa, India', count=1),
#  Row(Journal='ACM SIGCSE Bulletin', count=4),
#  Row(Journal='Proceedings of the 16th machine translation summit (MTSummit 2017)', count=1),
#  Row(Journal='IET Computer Vision', count=1),
#  Row(Journal='HRB Open Research', count=1),
#  Row(Journal='arXiv preprint arXiv:2103.15953', count=1),
#  Row(Journal='MRS Online Proceedings Library (OPL)', count=2),
#  Row(Journal='LWA 2007 Lernen–Wissen–Adaption', count=1),
#  Row(Journal='Proceedings of the International Conference on Bioscience, Biochemistry and Bioinformatics 2011', count=1),
#  Row(Journal='Proceedings of the 2nd Workshop on the Specification, Analysis and Validation for Emerging Technologies', count=1),
#  Row(Journal='The IT&T', count=1),
#  Row(Journal='Irish Machine Vision and Image Processing Conference (IMVIP 2001)', count=1),
#  Row(Journal='Knowledge Management & E-Learning: An International Journal', count=1),
#  Row(Journal='Informatics', count=2),
#  Row(Journal='International Journal on Semantic Web and Information Systems (IJSWIS)', count=3),
#  Row(Journal='Computer Speech & Language', count=2),
#  Row(Journal='Proceedings International Conference on Semantics and Digital Media Technologies', count=1),
#  Row(Journal='Methods of information in medicine', count=2),
#  Row(Journal='arXiv preprint arXiv:2103.11089', count=1),
#  Row(Journal='arXiv preprint arXiv:1910.07938', count=1),
# ...
#  Row(Journal='Advances in Information Retrieval42nd European Conference on IR Research, ECIR 2020, Lisbon, Portugal, April 14–17, 2020, Proceedings, Part II', count=1),
#  Row(Journal='Canadian Business', count=1),
#  Row(Journal='arXiv preprint arXiv:1809.00699', count=1),
#  Row(Journal='arXiv preprint arXiv:1906.12068', count=1),
#  Row(Journal='Upgrade', count=1),
#  Row(Journal='Information Systems', count=1),
#  Row(Journal='An international research agenda for digital libraries: summary report of the series of joint NSF-EU Working Groups on Future Directions for Digital Libraries Research.[Web document]. Brussels', count=1),
#  Row(Journal='Physiological measurement', count=1),
#  Row(Journal='Journal of Higher Education Policy and Management', count=1),
#  Row(Journal='Third International Conference on Theoretical and Methodological Issues in Machine Translation', count=1),
#  Row(Journal='Lecture Notes in Computer Science', count=30),
#  Row(Journal='arXiv preprint arXiv:1403.2404', count=2),
#  Row(Journal='Artificial Intelligence Review', count=1),
#  Row(Journal='Workshop of the 33rd Annual International, ACM SIGIR Conference on Research and Developmentin Information Retrieval', count=1),
#  Row(Journal='Pilot and Feasibility Studies', count=1),
#  Row(Journal='Mobile and Ubiquitous Information Access', count=1),
#  Row(Journal='arXiv preprint arXiv:2007.04183', count=1),
#  Row(Journal='Proceedings of the 2020 on International Conference on Multimedia Retrieval, ICMR', count=1),
#  Row(Journal='Proc. of the First International Workshop on Verification and Program Transformation', count=1),
#  Row(Journal='Systems, Software and Services Process Improvement: 27th European Conference, EuroSPI 2020, Düsseldorf, Germany, September 9-11, 2020, Proceedings', count=2),
#  Row(Journal='Image and Video Retrieval', count=2),
#  Row(Journal='International Journal on Advances in Intelligent Systems', count=1),
#  Row(Journal='arXiv preprint physics/0607296', count=2),
#  Row(Journal='ESF Exploratory Workshop on The Internet of Things for a Sustainable Future, Vielsalm (Belgium), 9-13 May 2011', count=1),
#  Row(Journal='ALIGNED project deliverable', count=1),
#  Row(Journal='IEEE Transactions on Cloud Computing', count=1),
#  Row(Journal='Concurrency and Computation: Practice and Experience', count=1),
#  Row(Journal='Okada, A', count=1),
#  Row(Journal='Proceedings of the NIPS Probabilistic Programming Workshop', count=1),
#  Row(Journal='5th East-European Conference on Advances in Databases and Information Systems', count=1),
#  Row(Journal='Proceedings of Starting AI Researchers Symposium,(STAIRS 2002)', count=1),
#  Row(Journal='Research-publishing. net', count=1),
#  Row(Journal='Proceedings of Machine Translation Summit XIII, Xiamen, China', count=1),
#  Row(Journal='Machine Learning and Knowledge Extraction: 4th IFIP TC 5, TC 12, WG 8.4, WG 8.9, WG 12.9 International Cross-Domain Conference, CD-MAKE 2020, Dublin, Ireland, August 25-28, 2020, Proceedings', count=1),
#  Row(Journal='Commission on Electronic Voting, First Report on the Secrecy, Accuracy and Testing of the Chosen Electronic Voting System. The Independent Commission on Electronic Voting and Counting at Elections, Dublin, Appendix B', count=1),
#  Row(Journal='Social Network Analysis and Mining', count=1),
#  Row(Journal='IEEE Transactions on Broadcasting', count=3),
#  Row(Journal='Journal of Systems and Software', count=1),
#  Row(Journal='Multimedia Systems', count=4),
#  Row(Journal='Appetite', count=1),
#  Row(Journal='Proceedings of 21st Annual European Simulation and Modelling Conference', count=1),
#  Row(Journal='Review of scientific instruments', count=1),
#  Row(Journal='Computational intelligence and neuroscience', count=1),
#  Row(Journal='arXiv preprint arXiv:2003.13833', count=1),
#  Row(Journal='International Journal of Software Engineering and Knowledge Engineering', count=2),
#  Row(Journal='情報処理学会研究報告自然言語処理 (NL)', count=1),
#  Row(Journal='Information Retrieval: New Systems and Current Research: Proceedings of the 16th Research Colloquium of the British Computer Society Information Retrieval Specialist Group, Drymen, 1994', count=1),
#  Row(Journal='Annals of Physical and Rehabilitation Medicine', count=3),
#  Row(Journal='IEEE Engineering in Medicine and Biology Society. Conference Proceedings', count=1),
#  Row(Journal='J. Cell. Autom.', count=3),
#  Row(Journal='The 4th Annual Symposium on Document Analysis and Information Retrieval', count=1),
#  Row(Journal='EuroAsiaSPI2 Blue Book Series Selected Papers', count=1),
#  Row(Journal='Computer Animation and Virtual Worlds', count=1),
#  Row(Journal='ACM Transactions on Information Systems (TOIS)', count=1),
#  Row(Journal='IEEE Journal of Selected Topics in Signal Processing', count=1),
#  Row(Journal='International Multimedia Conference: Proceedings of the 15 th international conference on Multimedia', count=1),
#  Row(Journal='ACM Transactions on Internet Technology', count=1),
#  Row(Journal='Combining distributional semantic models and sense distribution for effective Italian word sense disambiguation', count=1),
#  Row(Journal='Smeation,“ACOnnectivity AnalySiS XLIKS 를 이용한 하이퍼텍스토 검색 시스템', count=1),
#  Row(Journal='Personal and Ubiquitous Computing', count=1),
#  Row(Journal='Computers and the Humanities', count=1),
#  Row(Journal='LNMR 2013', count=1),
#  Row(Journal='1st IFIP Conference on Artificial Intelligence Applications and Innovations (AIAI-04), Toulouse, France', count=1),
#  Row(Journal='Dublin City University', count=1),
#  Row(Journal='IMTA', count=1),
#  Row(Journal='International Journal of Document Analysis and Recognition (IJDAR)', count=2),
#  Row(Journal='European Psychiatry', count=1),
#  Row(Journal='Wiley Encyclopedia of Electrical and Electronics Engineering', count=1),
#  Row(Journal='IEEE Signal Processing Magazine', count=2),
#  Row(Journal='Proceedings of the LFG99 Conference, Manchester University', count=1),
#  Row(Journal='arXiv preprint arXiv:1607.02227', count=1),
#  Row(Journal='Proceedings of ED-MEDIA/ED-TELECOM', count=1),
#  Row(Journal='Proceedings of the Eighth International Conference on LFG', count=1),
#  Row(Journal='structure', count=1),
#  Row(Journal='arXiv preprint arXiv:2005.00800', count=1),
#  Row(Journal='arXiv preprint arXiv:1606.07869', count=1),
#  Row(Journal='Smart Homes And Beyond: Icost 2006, 4th International Conference on Smart Homes and Health Telematics', count=1),
#  Row(Journal='WorldCALL: Sustainability and computer-assisted language learning', count=1),
#  Row(Journal='ICLR 2020 Workshop on Bridging AI and Cognitive Science (BAICS)', count=1),
#  Row(Journal='JMIR', count=2),
#  Row(Journal='Italian Journal of Computational Linguistics', count=1),
#  Row(Journal='IEEE Transactions on Computer-Aided Design of Integrated Circuits and Systems', count=3),
#  Row(Journal='Advances in Nonlinear Speech Processing: International Conference on Non-Linear Speech Processing, NOLISP 2007 Paris, France, May 22-25, 2007 Revised Selected Papers', count=1),
#  Row(Journal='Language in Society', count=1),
#  Row(Journal='3rd Workshop of the Forum for Information Retrieval Evaluation, FIRE', count=1),
#  Row(Journal='arXiv preprint arXiv:2012.15635', count=1),
#  Row(Journal='Applied Energy', count=2),
#  Row(Journal='Database', count=1),
#  Row(Journal='Machine Vision and Applications', count=1),
#  Row(Journal='Proceedings of the 22nd Annual Colloquium on Information Retrieval Research', count=1),
#  Row(Journal='The 1st Workshop on Statistical Parsing of Morphologically Rich Languages, NAACL', count=1),
#  Row(Journal='Proceedings of the Second Workshop on Intelligent Virtual Agents', count=1),
#  Row(Journal='Frontiers in Blockchain', count=3),
#  Row(Journal='Analytical methods', count=1),
#  Row(Journal='Evaluation of Translation Technology', count=1),
#  Row(Journal='arXiv preprint arXiv:1906.07808', count=1),
#  Row(Journal='Dublin, Dublin City University', count=1),
#  Row(Journal='Scanning Imaging Technology: 2-3 April, 1987, The Hague, The Netherlands', count=1),
#  Row(Journal='Journal of sport rehabilitation', count=1),
#  Row(Journal='Calico Journal', count=1),
#  Row(Journal='LOT Occasional Series', count=1),
#  Row(Journal='Proceedings of the ITRN 2011', count=1),
#  Row(Journal='Joint NSF-EU DELOS Working Group Report', count=1),
#  Row(Journal='Information Systems Journal', count=1),
#  Row(Journal='arXiv preprint arXiv:2110.14936', count=1),
#  Row(Journal='Irish Journal of Occupational Therapy', count=1),
#  Row(Journal='ACM SIGMultimedia Records', count=3),
#  Row(Journal='Welcome to PLANET NEWS!', count=1),
#  Row(Journal='Proceedings of the 20th BCS-IRSG Colloquium, Grenoble, France', count=1),
#  Row(Journal='Advances in Multimedia Modeling', count=1),
#  Row(Journal='Journal of Computer and Information Technology', count=1),
#  Row(Journal='W3C', count=1),
#  Row(Journal='International journal of approximate reasoning', count=1),
#  Row(Journal='6th Annual Conference of the North American Association for Celtic Language Teachers', count=1),
#  Row(Journal='IEEE Transactions on Parallel and Distributed Systems', count=4),
#  Row(Journal='Proceedings of 3nd International Conference on Universal Access in Human-Computer Interaction (joint with HCI International 2005), Las Vegas, Nevada, USA', count=1),
#  Row(Journal='arXiv preprint arXiv:2009.01712', count=1),
#  Row(Journal='Proceedings of POLICY 2005', count=1),
#  Row(Journal='ACM Transactions on Asian and Low-Resource Language Information Processing (TALLIP)', count=2),
#  Row(Journal='Journal of Pharmaceutical and Biomedical Analysis', count=2),
#  Row(Journal='Natural Language Engineering', count=4),
#  Row(Journal='Feature Interactions in Telecommunications and Software Systems VI', count=1),
#  Row(Journal='Proc. of the IJCAI Workshop on Intelligent Systems for Assisted Cognition, to appear', count=1),
#  Row(Journal='New Review of Hypermedia and Multimedia', count=1),
#  Row(Journal='Proceedings of the TRECVID Workshop', count=1),
#  Row(Journal='The MIR/MDL Evaluation Project White Paper Collection (Edition# 2)', count=1),
#  Row(Journal='ReCALL', count=2),
#  Row(Journal='AAAI 2003 Symposium on Intelligent Multimedia Knowledge Management', count=1),
#  Row(Journal='Crossroads', count=1),
#  Row(Journal='The 2006 Federated Logic Conference', count=1),
#  Row(Journal='Sensors and Actuators A: Physical', count=1),
#  Row(Journal='processing', count=1),
#  Row(Journal='arXiv preprint arXiv:0908.0912', count=2),
#  Row(Journal='Skin Research & Technology Journal (Wiley)', count=1),
#  Row(Journal='CALL and complexity', count=1),
#  Row(Journal='Proc. 6th International Conference on Intelligence in Networks (ICIN 2000), Bordeaux', count=1),
#  Row(Journal='Irish Educational Technology User’s', count=1),
#  Row(Journal='International Journal of Infectious Diseases', count=1),
#  Row(Journal='ACM Transactions on Internet Technology (TOIT)', count=1),
#  Row(Journal='Centro', count=2),
#  Row(Journal='arXiv preprint arXiv:1712.07004', count=1),
#  Row(Journal='Procedia Computer Science', count=2),
#  Row(Journal='Physical Review A', count=2),
#  Row(Journal='Business Information Systems', count=1),
#  Row(Journal='Logic-Based Interpretation', count=2),
#  Row(Journal='International Journal of Advanced Computer Science and Applications (arXiv:2110.13489)', count=1),
#  Row(Journal='International Workshop New Frontiers in Mining Complex Patterns', count=1),
#  Row(Journal='Historical Methods: A Journal of Quantitative and Interdisciplinary History', count=1),
#  Row(Journal='18th International Conference on Knowledge Engineering and Knowledge Management', count=1),
#  Row(Journal='IEEE Network', count=1),
#  Row(Journal='The Fourteenth NTCIR Conference (NTCIR-14)', count=1),
#  Row(Journal='JOURNAL OF OBJECT TECHNOLOGY', count=1),
#  Row(Journal='Proc. of the Workshop on Practical Applications of Information Filtering', count=1),
#  Row(Journal='Analysing word meaning over time by exploiting temporal Random Indexing', count=1),
#  Row(Journal='Journal of Neuroscience Methods', count=1),
#  Row(Journal='Frontiers in human neuroscience', count=3),
#  Row(Journal='NIST SPECIAL PUBLICATION SP', count=1),
#  Row(Journal='IEEE MultiMedia (to appear, 2012)', count=1),
#  Row(Journal='International Journal of Scientific & Engineering Research', count=1),
#  Row(Journal='Journal of Animal Science', count=3),
#  Row(Journal='International Journal of Parallel, Emergent and Distributed Systems', count=1),
#  Row(Journal='F1000Research', count=2),
#  Row(Journal='IEEE Communications Letters', count=1),
#  Row(Journal='Proceedings of CALL Asia 2002', count=1),
#  Row(Journal='National Symposium of The Irish Research Council for Science, Engineering and Technology', count=1),
#  Row(Journal='Cliodynamics: The Journal of Quantitative History and Cultural Evolution', count=1),
#  Row(Journal='Centre for Computing and Language Studies, Trinity College, University of Dublin. Bachelor of Arts (Moderatorship) in Computer Science, Linguistics and a Language. Final Project Dissertation', count=1),
#  Row(Journal='Poster presented at the memories for life colloquium', count=1),
#  Row(Journal='Technological Forecasting and Social Change', count=1),
#  Row(Journal='Value in Health', count=2),
#  Row(Journal='FALCON Project EU FP7. Available at: http://falcon-project. eu/wp-content/uploads/2015/11/FALCON-D4. 3_Submit. pdf [accessed 12 March 2016]. Assessing user interface needs', count=1),
#  Row(Journal='poster session, European Conference on Networks and Communications', count=1),
#  Row(Journal='arXiv preprint arXiv:2009.09158', count=1),
#  Row(Journal='Computers & Education', count=2),
#  Row(Journal='International Journal of Soft Computing and Its Applications', count=1),
#  Row(Journal='Information Technology & People', count=1),
#  Row(Journal='PROCEEDINGS (NON FINAL DRAFT VERSION)', count=1),
#  Row(Journal='IJCOL: The Italian Journal of Computation Linguistics Vol', count=1),
#  Row(Journal='Proceedings of the First Conference on Machine Translation: Volume 2, Shared Task Papers', count=1),
#  Row(Journal='SenseCam 2012', count=1),
#  Row(Journal='London: Scholio Educational Research & Publishing', count=1),
#  Row(Journal='European Geriatric Medicine', count=1),
#  Row(Journal='Proceedings of the International Conference on Artificial Intelligence and Statistics', count=1),
#  Row(Journal='Lecture notes in computer science', count=2),
#  Row(Journal='arXiv preprint arXiv:1909.09150', count=1),
#  Row(Journal='Tehnicki Vjesnik (Technical Gazette)', count=1),
#  Row(Journal='International Conference on Language Resources and Evaluation, Reykjavik, Iceland', count=1),
#  Row(Journal='Treebanks: Building and Using Parsed Corpora', count=1),
#  Row(Journal='Working Notes for the CLEF 2009 Workshop, Corfu, Greece', count=1),
#  Row(Journal='日本物理学会講演概要集', count=1),
#  Row(Journal='Experimental IR Meets Multilinguality, Multimodality, and Interaction', count=1),
#  Row(Journal='Technology, Pedagogy and Education', count=1),
#  Row(Journal='arXiv preprint arXiv:1804.06506', count=1),
#  Row(Journal='arXiv preprint arXiv:1909.12016', count=1),
#  Row(Journal='Proceedings of China Workshop on Machine Translation CWMT', count=1),
#  Row(Journal='Journal of Information Science', count=3),
#  Row(Journal='TREC Video Retrieval Evaluation Online Proc', count=1),
#  Row(Journal='In: CIICT: Symposium on Energy Efficiency and ICT, 5-6 July 2012, Dublin, Ireland.', count=1),
#  Row(Journal='Simulation', count=1),
#  Row(Journal='URL: http://eprints. nuim. ie/1445/. Accessed', count=1),
#  Row(Journal='New Frontiers in Mining Complex Patterns: 8th International Workshop, NFMCP 2019, Held in Conjunction with ECML-PKDD 2019, Würzburg, Germany, September 16, 2019, Revised Selected Papers', count=1),
#  Row(Journal='WWW2006 Workshop, Scotland', count=1),
#  Row(Journal='Challenges in Machine Learning: Gaming and Education (CiML-NIPS 2016 workshop)', count=1),
#  Row(Journal='Conference proceedings CLEF', count=1),
#  Row(Journal='Frontiers in Psychology', count=1),
#  Row(Journal='IEEE transactions on audio, speech, and language processing', count=1),
#  Row(Journal='J. Univers. Comput. Sci.', count=1)]

# %%
df_art.groupBy('Publisher').count().collect()
# Out:
# [Row(Publisher='ACM Press', count=2),
#  Row(Publisher='European Languages Resources Association (ELRA)', count=1),
#  Row(Publisher='MMM', count=1),
#  Row(Publisher='Springer.', count=1),
#  Row(Publisher='NLP Association of India (NLPAI)', count=1),
#  Row(Publisher='In Press', count=1),
#  Row(Publisher='IJSER', count=1),
#  Row(Publisher='Cyan Publishing Projects', count=1),
#  Row(Publisher='ACM IEEE', count=1),
#  Row(Publisher='Elsevier Science BV', count=1),
#  Row(Publisher='Lecture Notes in Computer Science (LNCS), Springer', count=1),
#  Row(Publisher="Le Centre de Hautes Etudes Internationales D'Informatique Documentaire", count=1),
#  Row(Publisher='http://ceur-ws.org/Vol-2670/', count=1),
#  Row(Publisher='Institute of Information Scientists', count=1),
#  Row(Publisher='SciTePress', count=3),
#  Row(Publisher='AAAI Press', count=1),
#  Row(Publisher='Taylor Graham', count=2),
#  Row(Publisher='The Institution of Engineering and Technology', count=1),
#  Row(Publisher='Universitat Politècnica de Catalunya', count=1),
#  Row(Publisher='University of Skövde', count=2),
#  Row(Publisher='Localisation Focus-The International Journal of Localisation;', count=1),
#  Row(Publisher='BioMed Central', count=10),
#  Row(Publisher='Springer-Verlag Berlin Heidelberg', count=5),
#  Row(Publisher='Springer Berlin/Heidelberg, ISBN 978-3-540-27858-0', count=1),
#  Row(Publisher='Technical Report No. ISG-02-03, Dublin City University', count=1),
#  Row(Publisher='Asian Federation of Natural Language Processing}', count=1),
#  Row(Publisher='http://eprints.dkit.ie/400', count=1),
#  Row(Publisher='Maltepe Üniversitesi', count=1),
#  Row(Publisher='John Wiley & Sons, Ltd', count=1),
#  Row(Publisher='Episciences. org', count=1),
#  Row(Publisher='AMTA', count=2),
#  Row(Publisher='Universal Dependencies Consortium', count=1),
#  Row(Publisher='Centre for Telematics and Information Technology, Enschede, The Netherlands', count=1),
#  Row(Publisher='Now Publishers', count=1),
#  Row(Publisher='Palgrave Macmillan, Cham', count=2),
#  Row(Publisher='Scitepress', count=6),
#  Row(Publisher='Springer, Cham, https://doi.org/10.1007/978-3-030-78468-3_34', count=1),
#  Row(Publisher='Working paper CA-0595, School of Computer Applications, Dublin City University, Dublin, Ireland', count=1),
#  Row(Publisher='Blackwell Publishing Ltd', count=3),
#  Row(Publisher='Academy Publish', count=1),
#  Row(Publisher='PDCS', count=1),
#  Row(Publisher='Cambridge University Press', count=15),
#  Row(Publisher='BMJ Publishing Group Ltd', count=1),
#  Row(Publisher='Linguistic Association of Canada and the United States', count=1),
#  Row(Publisher='EAMT', count=1),
#  Row(Publisher='Springer Berlin Heidelberg', count=38),
#  Row(Publisher='Innovative Information Science and Technology Research Group', count=1),
#  Row(Publisher='New York, NY: The Association, c1991-', count=1),
#  Row(Publisher='Infonomics Society', count=1),
#  Row(Publisher='Technical report, Dublin City Univ', count=2),
#  Row(Publisher='Academic Press', count=21),
#  Row(Publisher='Assoc Computing Machinery', count=1),
#  Row(Publisher='Public Library of Science', count=12),
#  Row(Publisher='AUSTRALIAN PSYCHOLOGICAL SOC', count=1),
#  Row(Publisher='Association for Computational Linguistics and DCU', count=1),
#  Row(Publisher='Asia-Pacific Association for Machine Translation', count=2),
#  Row(Publisher='Association for Computing Machinery, Inc', count=1),
#  Row(Publisher='IEEE COMPUTER SOC', count=1),
#  Row(Publisher='University of Nevada', count=1),
#  Row(Publisher='Coling 2016 conference committee', count=1),
#  Row(Publisher='School of Computer Applications, Dublin City University.[Online]. Available: http://www. compapp. dcu. ie/~ asmeaton/pubs/VirtLectCase. html [28th August 2003]', count=1),
#  Row(Publisher='NIST', count=32),
#  Row(Publisher='Association for Machine Translation in the Americas (AMTA)', count=1),
#  Row(Publisher='Springer Science & Business Media', count=11),
#  Row(Publisher='University of Wolverhamptom UK and The Society for Modeling and Simulation International (SCS Europe BVBA)', count=1),
#  Row(Publisher='Sociedad Española para el Procesamiento del Lenguaje Natural', count=3),
#  Row(Publisher='Tampere International Center for Signal Processing', count=2),
#  Row(Publisher='Complex Systems Society', count=1),
#  Row(Publisher='UNIVERSITY OF WALLONGONG', count=1),
#  Row(Publisher='IEEE DoI 10.1109/CBMI50038.2021.9461903', count=1),
#  Row(Publisher='Roskilde University', count=1),
#  Row(Publisher='Springer International Publishing Switzerland', count=1),
#  Row(Publisher='Dublin City University Dublin Ireland', count=1),
#  Row(Publisher='Rheinisch-Westfaelische Technische Hochschule Aachen', count=1),
#  Row(Publisher='CSLI Publications', count=13),
#  Row(Publisher='Sage Publications', count=4),
#  Row(Publisher='THE BRITISH COMPUTER SOCIETY', count=1),
#  Row(Publisher='SpringerOpen', count=1),
#  Row(Publisher='Springer, New York, NY', count=6),
#  Row(Publisher='Springer Vienna', count=1),
#  Row(Publisher='Inst Engineering Technology-IET', count=1),
#  Row(Publisher='NATIONAL INSTIUTE OF STANDARDS & TECHNOLOGY', count=2),
#  Row(Publisher='COLIPS', count=1),
#  Row(Publisher='EasyChair', count=1),
#  Row(Publisher='British Computer Society; The Ergonomics Society;', count=1),
#  Row(Publisher='Scitepress–Science and Technology Publications', count=2),
#  Row(Publisher='22-25 September 2020', count=1),
#  Row(Publisher='Bentham Science Publisher', count=1),
#  Row(Publisher='Information Science Publishing', count=1),
#  Row(Publisher='American Physical Society', count=2),
#  Row(Publisher='Elsevier', count=81),
#  Row(Publisher='The Institute of Engineering and Technology', count=3),
#  Row(Publisher='Kluwer Academic Publishers-Plenum Publishers', count=2),
#  Row(Publisher='European Research Consortium for Informatics and Mathematics (ERCIM)', count=1),
#  Row(Publisher='SAE International', count=1),
#  Row(Publisher='Springer London Ltd.', count=2),
#  Row(Publisher='University of Wolverhampton UK and The Society for Modeling and Simulation International and EUROSIS', count=1),
#  Row(Publisher='WILEY‐VCH Verlag', count=4),
#  Row(Publisher='MCB UP Ltd', count=3),
#  Row(Publisher='Oxford University Press, USA', count=1),
#  Row(Publisher='Charles University, Prague', count=1),
#  Row(Publisher='Inderscience Publishers Ltd', count=2),
#  Row(Publisher='ERCIM Sophia Antipolis, France', count=1),
#  Row(Publisher='Bentham Science Publishers', count=1),
#  Row(Publisher='Institute of Electrical and Electronics Engineers (IEEE)', count=1),
#  Row(Publisher='IGI Global', count=34),
#  Row(Publisher='IACSIT Press', count=1),
#  Row(Publisher='Elsevier Masson', count=2),
#  Row(Publisher='Schloss Dagstuhl-Leibniz-Zentrum für Informatik', count=1),
#  Row(Publisher='Springer Milan', count=1),
#  Row(Publisher='John Benjamins', count=2),
#  Row(Publisher='European Language Resources Association', count=3),
#  Row(Publisher='OUP', count=1),
#  Row(Publisher='Springer International Publishing LNCS', count=1),
#  Row(Publisher='The Royal Society of Chemistry.', count=1),
#  Row(Publisher='The COLING 2016 Organizing Committee', count=1),
#  Row(Publisher='META 2012', count=1),
#  Row(Publisher='Science Publishing Group', count=2),
#  Row(Publisher='School of Computer Science, Queens University Belfast', count=1),
#  Row(Publisher='Cham: Springer International Publishing: Imprint: Springer, 2016.', count=1),
#  Row(Publisher='Goberna América Latina', count=1),
#  Row(Publisher='Oxford University Press', count=16),
#  Row(Publisher='Emerald Publishing Limited', count=6),
#  Row(Publisher='SCITEPRESS', count=4),
#  Row(Publisher='Association for Computational Linguistics (ACL)', count=17),
#  Row(Publisher='BUTTERWORTH-HEINEMANN LTD', count=1),
#  Row(Publisher='World Scientific Publishing Company', count=18),
#  Row(Publisher='American Association for the Advancement of Science', count=1),
#  Row(Publisher='IEEE Computer Society Press', count=1),
#  Row(Publisher='Süleyman Demirel Üniversitesi Fen Bilimleri Enstitüsü', count=1),
#  Row(Publisher='Springer Netherlands', count=47),
#  Row(Publisher='CID Paris', count=4),
#  Row(Publisher='Emerald', count=1),
#  Row(Publisher='John Wiley & Sons, Inc.', count=2),
#  Row(Publisher='University of Queensland', count=1),
#  Row(Publisher='Schattauer GmbH', count=2),
#  Row(Publisher='Academy & Industry Research Collaboration Center (AIRCC)', count=1),
#  Row(Publisher='Edimema', count=1),
#  Row(Publisher='CLEF', count=1),
#  Row(Publisher='LREC: Language Resources and Evaluation Conference', count=1),
#  Row(Publisher='Frontiers Media SA', count=1),
#  Row(Publisher='European Language Resource Association', count=3),
#  Row(Publisher='The Institute of Electronics, Information and Communication Engineers', count=2),
#  Row(Publisher='American Institute of Physics', count=2),
#  Row(Publisher='Institute of Mathematics and Informatics', count=1),
#  Row(Publisher='Springer Nature', count=13),
#  Row(Publisher='IET', count=22),
#  Row(Publisher='Information Today, Incorporated', count=1),
#  Row(Publisher='Global WordNet Association', count=1),
#  Row(Publisher='Hrvatsko društvo za jezične tehnologije', count=1),
#  Row(Publisher='Copernicus Meetings', count=1),
#  Row(Publisher='Springer, Berlin, Heidelberg', count=257),
#  Row(Publisher='Berlin: Springer. Lecture notes in computer science', count=1),
#  Row(Publisher='ERCIM', count=2),
#  Row(Publisher='Springer-Verlag New York Inc', count=1),
#  Row(Publisher='Science and Information Organization', count=1),
#  Row(Publisher='National Institute of Informatics', count=7),
#  Row(Publisher='ACM, Association for Computing Machinery', count=1),
#  Row(Publisher='20th European Meeting on Cybernetics and System Research', count=1),
#  Row(Publisher='Toronto: CB Media, 1977-', count=1),
#  Row(Publisher='Cambridge University Computer Laboratory', count=1),
#  Row(Publisher='CRC Press', count=1),
#  Row(Publisher='proceedings from MuTra-Audiovisual Translation Scenarios Conference.[In Press]', count=1),
#  Row(Publisher='The Alliance of Digital Humanities Organizations', count=1),
#  Row(Publisher='Engineers Ireland (http://www.engineersjournal.ie/medical-device-software-development-towards-a-single-best-practice)', count=1),
#  Row(Publisher='Springer Singapore', count=1),
#  Row(Publisher='Dove Press', count=1),
#  Row(Publisher='Academic Conferences International Limited', count=1),
#  Row(Publisher='NUI Maynooth', count=2),
#  Row(Publisher='National Academies Press', count=1),
#  Row(Publisher='Euro SPI', count=1),
#  Row(Publisher='Springer International Publishing, LNCS 8237', count=1),
#  Row(Publisher='Engineers Ireland', count=1),
#  Row(Publisher='Systemics and Informatics World Network', count=1),
#  Row(Publisher='EdUEMA', count=1),
#  Row(Publisher='Oscar Corcho, Manfred Hauswirth, Manolis Koubarakis (editors of the proceedings)', count=1),
#  Row(Publisher='The AALIANCE: The European Ambient Assisted Living Innovation Alliance', count=1),
#  Row(Publisher='Technical Report TR95-13, Department of Computer Science, University of Keele, Staffordshire, ST5 5BG, UK', count=1),
#  Row(Publisher='MIT Press', count=7),
#  Row(Publisher='Taylor & Francis Group', count=8),
#  Row(Publisher='National Institute of Standards and Technology (NIST)', count=2),
#  Row(Publisher='Unknown', count=2191),
#  Row(Publisher='California State University, Northridge.', count=2),
#  Row(Publisher='Meta2010', count=2),
#  Row(Publisher='ECAL', count=1),
#  Row(Publisher='Asian Federation of Natural Language Processing', count=3),
#  Row(Publisher='ACM', count=140),
#  Row(Publisher='Centro de Investigación en computación, IPN', count=1),
#  Row(Publisher='27-28 November 2014', count=1),
#  Row(Publisher='IOS-INTERNATIONAL ORGANIZATIONS SERVICES BV', count=1),
#  Row(Publisher='Springer International Publishing', count=28),
#  Row(Publisher='日経 BP 社', count=1),
#  Row(Publisher='International Conference on Logic Programming (ICLP)', count=1),
#  Row(Publisher='IASTED', count=1),
#  Row(Publisher='INRIA', count=1),
#  Row(Publisher='Springer Berlin/Heidelberg.', count=2),
#  Row(Publisher='National Institute for Standards and Technology', count=1),
#  Row(Publisher='Human Kinetics, Inc.', count=1),
#  Row(Publisher='American Thoracic Society', count=1),
#  Row(Publisher='Joseph D. Cautilli', count=1),
#  Row(Publisher='Bloomsbury Academic', count=1),
#  Row(Publisher='International Academy of Technology, Education and Development (IATED)', count=1),
#  Row(Publisher='Sheffield', count=2),
#  Row(Publisher='The International Association for Information, Culture, Human and Industry Technology', count=1),
#  Row(Publisher='Schattauer', count=1),
#  Row(Publisher='ACL Anthology', count=2),
#  Row(Publisher='Scientific Research Publishing', count=1),
#  Row(Publisher='Hornbeam Press', count=1),
#  Row(Publisher='North-Holland', count=49),
#  Row(Publisher='CEUR Workshop Proceedings', count=6),
#  Row(Publisher='IATED', count=1),
#  Row(Publisher='De Gruyter Open', count=4),
#  Row(Publisher='PsyArXiv', count=1),
#  Row(Publisher='Graz Univ Technolgoy', count=1),
#  Row(Publisher='Kluwer Academic Publishers', count=12),
#  Row(Publisher='Irish Pattern Recognition & Classification Society', count=2),
#  Row(Publisher='Accademia University Press', count=3),
#  Row(Publisher='Walter de Gruyter', count=1),
#  Row(Publisher='Hindawi', count=5),
#  Row(Publisher='Springer-Verlag, Communications in Computer and Information Science series', count=1),
#  Row(Publisher='MTS/IEEE', count=1),
#  Row(Publisher='IET Digital Library', count=30),
#  Row(Publisher='British Medical Journal Publishing Group', count=1),
#  Row(Publisher='European Association for Machine Translation', count=23),
#  Row(Publisher='University of Hawaii National Foreign Language Resource Center', count=1),
#  Row(Publisher='Universidad de AlmerÃa', count=1),
#  Row(Publisher='OPEN PUBL ASSOC', count=1),
#  Row(Publisher='National Institute of Informatics (NII)', count=2),
#  Row(Publisher='Dublin City University. School of Computer Applications', count=2),
#  Row(Publisher='De Gruyter Open Access', count=3),
#  Row(Publisher='Springer,', count=1),
#  Row(Publisher='Springer, Dordrecht', count=7),
#  Row(Publisher='Springer Berlin', count=2),
#  Row(Publisher='Cham: Springer International Publishing: Imprint: Springer, 2017.', count=1),
#  Row(Publisher='UKAIS', count=1),
#  Row(Publisher='Pisa University Press', count=2),
#  Row(Publisher='Latvijas Universitate', count=1),
#  Row(Publisher='University of Cambridge, Computer Laboratory', count=4),
#  Row(Publisher='University of Sheffield, UK', count=1),
#  Row(Publisher='Association of Occupational Therapists of Ireland', count=1),
#  Row(Publisher='PMLR', count=2),
#  Row(Publisher='Schloss Dagstuhl-Leibniz-Zentrum fuer Informatik', count=1),
#  Row(Publisher='International Speech Communication Association', count=1),
#  Row(Publisher='CEUR-WS. org', count=11),
#  Row(Publisher='Working paper CA-0801, School of Computer Applications, Dublin City University. http://www. compapp. dcu. ie/CA Working Papers/wp01. html', count=1),
#  Row(Publisher='Digital Information Research Foundation', count=1),
#  Row(Publisher='CUER-WS', count=1),
#  Row(Publisher='IOS Press', count=19),
#  Row(Publisher='De Gruyter Poland', count=2),
#  Row(Publisher='ECMS', count=1),
#  Row(Publisher='Inderscience Publishers (IEL)', count=1),
#  Row(Publisher='INST ENGINEERING TECHNOLOGY-IET', count=2),
#  Row(Publisher='arXiv preprint arXiv:2106.13512', count=2),
#  Row(Publisher='IACSIT Press, Singapore', count=3),
#  Row(Publisher='DUBLIN CITY UNIV (IRELAND)', count=2),
#  Row(Publisher='The Physical Society of Japan', count=1),
#  Row(Publisher='IARIA', count=1),
#  Row(Publisher='Society of Photo Optical', count=1),
#  Row(Publisher='in: Journal of Chemical Physics', count=1),
#  Row(Publisher='SWETS ZEITLINGER PUBLISHERS', count=2),
#  Row(Publisher='ELSEVIER SCIENCE BV', count=1),
#  Row(Publisher='The Science and Information Organization', count=1),
#  Row(Publisher='European Space Agency', count=1),
#  Row(Publisher='Chichester: John Wiley & Sons', count=1),
#  Row(Publisher='InTech', count=2),
#  Row(Publisher='BDVA/DAIRO; BDVA/DAIRO Website', count=1),
#  Row(Publisher='LNCS', count=1),
#  Row(Publisher="Alzheimer's Association", count=1),
#  Row(Publisher='Pergamon Press', count=1),
#  Row(Publisher='Hindawi Publishing Corp.', count=1),
#  Row(Publisher='AICIT (Advanced Institute of Convergence Information Technology)', count=1),
#  Row(Publisher='Springer US', count=19),
#  Row(Publisher='OXFORD UNIV PRESS', count=1),
#  Row(Publisher='The Institution of Engineering & Technology', count=1),
#  Row(Publisher='University of Zurich', count=1),
#  Row(Publisher='Academy of Management', count=1),
#  Row(Publisher='Trans Tech Publications Ltd', count=1),
#  Row(Publisher='Working Paper CA-0601, School of Computer Applications, Dublin City University. http://www. compapp. dcu. ie/CA_Working_Papers/wp01. html', count=1),
#  Row(Publisher='Snowbird', count=1),
#  Row(Publisher="Ecole des Mines d'Alès", count=1),
#  Row(Publisher='IEEE', count=421),
#  Row(Publisher='National Insititute of Standards and Technology', count=4),
#  Row(Publisher='Education Matters', count=1),
#  Row(Publisher='Springer Verlag Berlin (In Press)', count=1),
#  Row(Publisher='SSAISB Publications Officer', count=1),
#  Row(Publisher='Kluwer Academic Publishers Norwell, MA, USA', count=1),
#  Row(Publisher='University of Limerick', count=1),
#  Row(Publisher='SAGE Publications', count=4),
#  Row(Publisher='Eurosis', count=1),
#  Row(Publisher='Royal Irish Academy', count=2),
#  Row(Publisher='FRUCT Oy', count=1),
#  Row(Publisher='International Parallel and Distributed Processing Symposium', count=1),
#  Row(Publisher='Localisation Research Centre', count=1),
#  Row(Publisher='SPRINGER', count=1),
#  Row(Publisher='Abu-MaTran project', count=1),
#  Row(Publisher='[Sl]: CEUR', count=3),
#  Row(Publisher='Association for Machine Translation in the Americas', count=9),
#  Row(Publisher='Springer-Verlag', count=29),
#  Row(Publisher='ACTA Press', count=1),
#  Row(Publisher='Wiley', count=3),
#  Row(Publisher='Graz University of Technology', count=1),
#  Row(Publisher='Logos Verlag', count=1),
#  Row(Publisher='Gaithersburg: NIST', count=1),
#  Row(Publisher='Health Products Regulatory Authority', count=1),
#  Row(Publisher='The Institute of Image Information and Television Engineers', count=1),
#  Row(Publisher='Multicon Verlag', count=1),
#  Row(Publisher='Association for Computational Linguistics', count=29),
#  Row(Publisher='Universidad de Alicante. Área de Educación Física y Deporte', count=1),
#  Row(Publisher='JEP-TALN-RECITAL 2016', count=1),
#  Row(Publisher='一般社団法人 映像情報メディア学会', count=1),
#  Row(Publisher='24-27 April 2016, Dublin, Ireland', count=1),
#  Row(Publisher='iSchools', count=3),
#  Row(Publisher='CRC', count=1),
#  Row(Publisher='Bentham Science Publishers, eISBN: 978-1-60805-215-8', count=1),
#  Row(Publisher='Springer Berlin/Heidelberg', count=31),
#  Row(Publisher='InTech: Rijeka, Croatia', count=1),
#  Row(Publisher='Barcelona, Spain', count=1),
#  Row(Publisher='European Language Resources Association (ELRA)', count=1),
#  Row(Publisher='Telecommunication Society of Australia Ltd.', count=1),
#  Row(Publisher='Berlin, Heidelberg: Springer', count=1),
#  Row(Publisher='LOT, Netherlands Graduate School of Linguistics', count=1),
#  Row(Publisher='ICEIS', count=1),
#  Row(Publisher='Ivyspring International Publisher', count=1),
#  Row(Publisher='Technical report, University of Sheffield', count=1),
#  Row(Publisher='Department of Computer Science, Keele University', count=1),
#  Row(Publisher='ERCIM EEIG', count=2),
#  Row(Publisher='Frontiers', count=6),
#  Row(Publisher='ASQ', count=1),
#  Row(Publisher='arXiv preprint arXiv:2106.10090', count=1),
#  Row(Publisher='SAGE PUBLICATIONS LTD', count=1),
#  Row(Publisher='Preprints', count=1),
#  Row(Publisher='Project Euromath', count=1),
#  Row(Publisher='Springer, London', count=12),
#  Row(Publisher='sn', count=1),
#  Row(Publisher='CEUR-WS', count=30),
#  Row(Publisher='European Research Consortium for Informatics and Mathematics', count=4),
#  Row(Publisher='[Sl]: CEUR-WS. org', count=1),
#  Row(Publisher='International Joint Conferences on Artificial Intelligence Organization', count=1),
#  Row(Publisher='Association for Computing Machinery', count=6),
#  Row(Publisher='Société Française de Physique', count=1),
#  Row(Publisher='National University of Ireland, Galway', count=2),
#  Row(Publisher='Optical Society of America', count=1),
#  Row(Publisher='Deliverable', count=1),
#  Row(Publisher='Springer London', count=4),
#  Row(Publisher='NUIM', count=1),
#  Row(Publisher='Springer, Cham', count=238),
#  Row(Publisher='Nature Publishing Group', count=5),
#  Row(Publisher='Association for the Advancement of Computing in Education (AACE)', count=8),
#  Row(Publisher='Association for Computing Machinery (ACM)', count=5),
#  Row(Publisher='IOS Press BV', count=1),
#  Row(Publisher='NII', count=2),
#  Row(Publisher='[IEEE]', count=1),
#  Row(Publisher='Institute of Electrical and Electronics Engineers', count=1),
#  Row(Publisher='http://www.aiucd2018.uniba.it/content/AIUCD2018-BoA.pdf', count=1),
#  Row(Publisher='Centre for Telematics and Information Technology (CTIT)', count=1),
#  Row(Publisher='AAAI Publications', count=1),
#  Row(Publisher="Institut d'Estudis Catalans", count=1),
#  Row(Publisher='Technische Universitaet Graz* Institut fuer Informationssysteme und Computer Medien', count=1),
#  Row(Publisher='Equinox Publishing Ltd.', count=1),
#  Row(Publisher='Facet Publishing', count=1),
#  Row(Publisher='International Organization for Medical Physics', count=1),
#  Row(Publisher='IEEE Computer Society', count=4),
#  Row(Publisher='Royal Society of Chemistry', count=2),
#  Row(Publisher='Aarhus Universitet', count=1),
#  Row(Publisher='ERCIM EEIG, BP 93, F-06902 Sophia-Antipolis Cedex, France', count=1),
#  Row(Publisher='Institution of Electrical Engineers', count=1),
#  Row(Publisher='Pamukkale Üniversitesi, Mühendislik Fakültesi', count=1),
#  Row(Publisher='Portorož, Slovenia: European Language Resources Association', count=1),
#  Row(Publisher='International Center for Scientific Research and Studies', count=1),
#  Row(Publisher='Asociación de Técnicos de Informática, ATI', count=1),
#  Row(Publisher='CEUR-Workshop Proceedings', count=4),
#  Row(Publisher='Research-publishing. net. La Grange des Noyes, 25110 Voillans, France', count=2),
#  Row(Publisher='Springer, Tokyo', count=4),
#  Row(Publisher='一般社団法人 日本物理学会', count=1),
#  Row(Publisher='[Long Beach, Calif.]: IEEE Computer Society, 1970-', count=1),
#  Row(Publisher='Editorial Universitat Politècnica de València', count=3),
#  Row(Publisher='CEUR Workshop Proceedings at CEUR-WS. org/Vol-1043/', count=1),
#  Row(Publisher='Wiley Subscription Services, Inc., A Wiley Company', count=5),
#  Row(Publisher='Univerzita Karlova v Praze', count=1),
#  Row(Publisher='Springer', count=43),
#  Row(Publisher='Innovative Information Science & Technology Research Group (ISYOU)', count=1),
#  Row(Publisher='15-18 September 2014', count=1),
#  Row(Publisher='Research-publishing. net', count=1),
#  Row(Publisher='arXiv preprint arXiv:2106.13504', count=2),
#  Row(Publisher='ESM-Eurosis', count=3),
#  Row(Publisher='CEUR', count=3),
#  Row(Publisher='Austrian Computer Society (OCG)', count=1),
#  Row(Publisher='ISBNPA', count=1),
#  Row(Publisher='AAMT', count=1),
#  Row(Publisher='Verlag der Zeitschrift für Naturforschung', count=1),
#  Row(Publisher='Institute for Business & Finance Research', count=1),
#  Row(Publisher='CRC Press 20152015', count=1),
#  Row(Publisher='IntechOpen', count=3),
#  Row(Publisher='American Psychological Association', count=1),
#  Row(Publisher='Springer-Verlag London Limited', count=1),
#  Row(Publisher='British Computer Society', count=12),
#  Row(Publisher='Queens University, Belfast, Northern Ir', count=1),
#  Row(Publisher='Physica-Verlag HD', count=1),
#  Row(Publisher='Dublin City University', count=23),
#  Row(Publisher='Logos Verlag Berlin', count=1),
#  Row(Publisher='PUB27', count=1),
#  Row(Publisher='Centre for Digital Video Processing & CLARITY, Dublin City University, Ireland. Retrieved from http://www. uxtv2008. org/program/social-tv-workshop-papers/ferguson. pdf', count=2),
#  Row(Publisher='Binary Information Press', count=1),
#  Row(Publisher='CEUR Proceedings of the MediaEval 2011 Workshop', count=1),
#  Row(Publisher='VERLAG HOPPENSTEDT & CO', count=1),
#  Row(Publisher='World Scientific', count=2),
#  Row(Publisher='IOP Publishing', count=5),
#  Row(Publisher='LWW', count=9),
#  Row(Publisher='JMIR', count=1),
#  Row(Publisher='Wiley‐Blackwell', count=1),
#  Row(Publisher='International Society for Optics and Photonics', count=19),
#  Row(Publisher='F1000 Research Limited', count=1),
#  Row(Publisher='NOW', count=1),
#  Row(Publisher='No longer published by Elsevier', count=2),
#  Row(Publisher='Springer Berlin/Heidelberg, ISBN 978-3-540-41023-2', count=1),
#  Row(Publisher='European Association for Machine Translation (EAMT)', count=3),
#  Row(Publisher='Academic Conferences and Publishing International', count=1),
#  Row(Publisher='American Society for Quality', count=1),
#  Row(Publisher='Semantic Scholar', count=1),
#  Row(Publisher='University of Exeter', count=1),
#  Row(Publisher='Emerald Group Publishing, Limited', count=1),
#  Row(Publisher='ICSOFT', count=1),
#  Row(Publisher='Taylor & Francis', count=13),
#  Row(Publisher='CEUR. WS', count=1),
#  Row(Publisher='Molecular Diversity Preservation International', count=5),
#  Row(Publisher='Institute of Physics and IOP Publishing Limited', count=1),
#  Row(Publisher='Springer, Boston, MA', count=2),
#  Row(Publisher='Société française de physique', count=1),
#  Row(Publisher='AIRCC Publishing Corporation', count=1),
#  Row(Publisher='Routledge', count=11),
#  Row(Publisher='Multidisciplinary Digital Publishing Institute', count=22),
#  Row(Publisher='Department, Univ.', count=1),
#  Row(Publisher='EUROPEAN RESEARCH CONSORTIUM INFORMATICS & MATHEMATICS', count=1),
#  Row(Publisher='Asociación de Análisis del Comportamiento', count=1),
#  Row(Publisher='Dept. of Sports Medicine, Medical Faculty of Uludag University', count=1),
#  Row(Publisher='Technische Universität Graz', count=2),
#  Row(Publisher='Meta 2012', count=1),
#  Row(Publisher='The University of Edinburgh', count=1),
#  Row(Publisher="LE CENTRE DE HAUTES ETUDES INTERNATIONALES D'INFORMATIQUE DOCUMENTAIRE", count=2),
#  Row(Publisher='American Society for Quality (ASQ)', count=1),
#  Row(Publisher='Noldus Information Technology', count=1),
#  Row(Publisher='Inderscience Publishers', count=1),
#  Row(Publisher='European Center for Living Technology', count=1),
#  Row(Publisher='International Society for Optical Engineering; 1999', count=2),
#  Row(Publisher='http://ceur-ws.org/Vol-2259/', count=1),
#  Row(Publisher='University of Essex. Department of Language and Linguistics', count=2),
#  Row(Publisher='ACM SIG Proceedings (In Press)', count=2),
#  Row(Publisher='Berlin: Springer-Verlag, 1973-', count=22),
#  Row(Publisher='Springer, Singapore', count=5),
#  Row(Publisher='NTCIR', count=2),
#  Row(Publisher='Cham: Springer', count=1),
#  Row(Publisher='NRCIR', count=2),
#  Row(Publisher='Linköping University Electronic Press', count=1),
#  Row(Publisher='IWSLT', count=1),
#  Row(Publisher='ESA-European Space Agency', count=1),
#  Row(Publisher='Co located with 31st European Conference on Object-Oriented Programming, ECOOP 2017 (Barcelona, Spain, Jun 2017)', count=1),
#  Row(Publisher='The Southern African Institute of Mining and Metallurgy', count=1),
#  Row(Publisher='Mary Ann Liebert, Inc.', count=1),
#  Row(Publisher='Department of Computer Science, KU Leuven; Leuven, Belgium', count=1),
#  Row(Publisher='The Royal Society', count=1),
#  Row(Publisher='Pergamon', count=22),
#  Row(Publisher='Royal Geographical Society (with the Institute of British Geographers), Wiley', count=1),
#  Row(Publisher='PBML', count=1),
#  Row(Publisher='Pergamon Press, Inc.', count=2),
#  Row(Publisher='Springer Verlag', count=5),
#  Row(Publisher='Hindawi Publishing Corporation', count=1),
#  Row(Publisher='https://ieeexplore.ieee.org/document/8790173', count=1),
#  Row(Publisher='JMIR Publications Inc., Toronto, Canada', count=3),
#  Row(Publisher='University of Bergen', count=1),
#  Row(Publisher='Springer Link', count=1)]

# %%
df_art = df_art.filter((df_art.Publisher != 'ä¸€èˆ¬ç¤¾å›£æ³•äºº æ—¥æœ¬ç‰©ç\x90†å\xad¦ä¼š') & (df_art.Publisher != 'æ—¥çµŒ BP ç¤¾'))

# %% [markdown]
# # Let's try find the author with the most amount of citations attached to their work

# %%
df_grp = df_art.filter(df_art.Citation != 'Unknown')

# %%
df_grp.printSchema()
# Out:
# root
#  |-- Title: string (nullable = true)
#  |-- Citation: string (nullable = true)
#  |-- Conference: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#  |-- Journal: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Authors: string (nullable = true)
#  |-- AuthorDCU: string (nullable = true)

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import *
df_grp1 = df_grp.withColumn("Citation", col("Citation").cast(IntegerType()))

# %%
df_grp1.printSchema()
# Out:
# root
#  |-- Title: string (nullable = true)
#  |-- Citation: integer (nullable = true)
#  |-- Conference: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#  |-- Journal: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Authors: string (nullable = true)
#  |-- AuthorDCU: string (nullable = true)

# %%
df_grp1.toPandas()
# Out:
#                                                   Title  Citation  \
# 0       Efficient cube construction for smart city data      10.0
# 1             Generating cubes from smart city web data       7.0
# 2     Automating Data Mart Construction from Semi-st...       6.0
# 3          Predicting customer churn for insurance data       4.0
# 4     Attention Based Video Summaries of Live Online...       3.0
# ...                                                 ...       ...
# 3584  Translating DVD Subtitles Using Example-Based ...       1.0
# 3585                            Classroom of the Future       1.0
# 3586  GF-DOP: Grammatical Feature Data-Oriented Parsing       1.0
# 3587  Lexicalisation of Long Distance Dependencies i...       1.0
# 3588  LFG-DOT: a probabilistic, constraint-based mod...       1.0
#
#                                              Conference  \
# 0                                               Unknown
# 1     Proceedings of the Australasian Computer Scien...
# 2                                               Unknown
# 3     International Conference on Big Data Analytics...
# 4     "AAAI-2021 Workshop on AI Education: ""Imagini...
# ...                                                 ...
# 3584                                            Unknown
# 3585                                            Unknown
# 3586                                            Unknown
# 3587                                            Unknown
# 3588  Proceedings of the Fifth International Worksho...
#
#                                               Publisher  \
# 0                                          CEUR-WS. org
# 1                                                   ACM
# 2                               Oxford University Press
# 3                                        Springer, Cham
# 4                                               Unknown
# ...                                                 ...
# 3584  proceedings from MuTra-Audiovisual Translation...
# 3585                                            Unknown
# 3586                                  CSLI Publications
# 3587                                            Unknown
# 3588                                            Unknown
#
#                                                 Journal  Date  \
# 0                                               Unknown  2016
# 1                                               Unknown  2017
# 2                                  The Computer Journal  2018
# 3                                               Unknown  2020
# 4                                               Unknown  2021
# ...                                                 ...   ...
# 3584                                            Unknown  2006
# 3585                                            Unknown  2006
# 3586                                            Unknown  2006
# 3587  Proceedings of the Eighth International Confer...  2003
# 3588                                            Unknown  2000
#
#                                                 Authors        AuthorDCU
# 0                        Michael Scriney, Mark Roantree  Michael Scriney
# 1     Michael Scriney, Martin F O'Connor, Mark Roantree  Michael Scriney
# 2     Michael Scriney, Suzanne McCarthy, Andrew McCa...  Michael Scriney
# 3           Michael Scriney, Dongyun Nie, Mark Roantree  Michael Scriney
# 4     Hyowon Lee, Mingming Liu, Hamza Riaz, Navaneet...  Michael Scriney
# ...                                                 ...              ...
# 3584  Stephen Armstrong, Colm Caffrey, Marian Flanag...         Andy Way
# 3585                            Gerard Cleary, Andy Way         Andy Way
# 3586  Riona Finn, Mary Hearne, Andy Way, Josef van G...         Andy Way
# 3587  Aoife Cahill, Mairead McCarthy, Ruth O'Donovan...         Andy Way
# 3588                                           Andy Way         Andy Way
#
# [3589 rows x 8 columns]

# %%
x = df_grp1.groupBy("AuthorDCU").sum("Citation").orderBy("sum(Citation)", ascending=False)

# %%
x.show()
# Out:
# +-------------------+-------------+
# |          AuthorDCU|sum(Citation)|
# +-------------------+-------------+
# |     Alan F Smeaton|        20641|
# |       Gareth Jones|         8823|
# |           Andy Way|         7495|
# |         Tomas Ward|         5552|
# |      Cathal Gurrin|         5033|
# |  Heather J. Ruskin|         4021|
# |      Yvette Graham|         3214|
# |    Jennifer Foster|         2567|
# |Alistair Sutherland|         2372|
# |      Paul M.Clarke|         1797|
# |       Martin Crane|         1710|
# |   Alessandra Mileo|         1656|
# |     Suzanne Little|         1317|
# |        Rob Brennan|         1187|
# |        Brian Davis|         1122|
# |      Mark Roantree|         1073|
# |       Murat Yilmaz|         1032|
# |     Geoff Hamilton|          616|
# |    Annalina Caputo|          591|
# |         Long Cheng|          569|
# +-------------------+-------------+
# only showing top 20 rows

# %% [markdown]
# Alan Smeaton has the largest number of citations by some distance. Although he was involved in the most papers (797) there was still a lot of authors who had similarly large number of works with their name attached to them published but did not have near the same amount of publications. We will now try to look at the average number of citations per paper for each author.

# %%
from pyspark.sql import functions as F
y = df_grp1.groupBy("AuthorDCU").agg(F.mean('Citation'))

# %%
y.orderBy("avg(Citation)", ascending=False).show()
# Out:
# +-------------------+------------------+
# |          AuthorDCU|     avg(Citation)|
# +-------------------+------------------+
# |      Yvette Graham| 55.41379310344828|
# |Alistair Sutherland| 35.40298507462686|
# |     Alan F Smeaton| 34.63255033557047|
# |    Jennifer Foster|29.848837209302324|
# |  Heather J. Ruskin| 27.35374149659864|
# |         Tomas Ward|26.312796208530806|
# |       Charlie Daly| 25.58823529411765|
# |   Alessandra Mileo|22.684931506849313|
# |      Paul M.Clarke|           22.4625|
# |       Martin Crane|20.853658536585368|
# | Dimitar Shterionov| 19.14814814814815|
# |       Gareth Jones|18.974193548387095|
# |           Andy Way|18.370098039215687|
# |     Suzanne Little| 17.32894736842105|
# |      Cathal Gurrin|16.889261744966444|
# |          Irina Tal|16.428571428571427|
# |       Murat Yilmaz|14.535211267605634|
# |        Brian Davis|13.851851851851851|
# |        Rob Brennan|12.112244897959183|
# |       John McKenna|              12.0|
# +-------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# This is certainly an interesting result and completely changes how we see our results from earlier regarding number of citations related to an author. It is interesting to note that Alan Smeaton and Gareth Jones appear much lower in relative terms of average citations than they did in terms of total citations. Yvette Graham for example appeared in less than a tenth of the total of papers published related to Alan Smeaton but has on average roughly 20 more citations.

# %% [markdown]
# # Doras PySpark Analysis

# %%
df_doras = spark.read.csv("data/doras/combined_csv.csv", header=True)

# %%
df_doras.toPandas().shape
# Out:
# (1998, 29)

# %% [markdown]
# Let's run similar analysis on our doras data. Let's check for missing/unusual values and let's look at authors citations also.

# %%
cols = df_doras.columns
for i in range(len(cols)):
    print(str(cols[i]) + " has this number of null values: " + str(df_doras.filter(df_doras[cols[i]].isNull()).count()))
# Out:
# Research name has this number of null values: 0
# Publication Title has this number of null values: 129
# Author List has this number of null values: 321
# Conf/Journal Details has this number of null values: 355
# Year has this number of null values: 339
# Full name has this number of null values: 343
# Authors and Orcid has this number of null values: 482
# Authors without a orcid has this number of null values: 801
# ISBN has this number of null values: 1443
# ISSN has this number of null values: 1546
# Item Type has this number of null values: 408
# Event Type has this number of null values: 730
# Refereed has this number of null values: 576
# Date of Award has this number of null values: 1986
# Supervisor(s) has this number of null values: 1893
# Uncontrolled Keywords has this number of null values: 851
# Subject has this number of null values: 508
# DCU Faculties and Centres has this number of null values: 528
# Use License has this number of null values: 668
# ID Code has this number of null values: 504
# Deposited On has this number of null values: 562
# Published in has this number of null values: 1179
# Publisher has this number of null values: 931
# Official URL has this number of null values: 872
# Copyright Information has this number of null values: 963
# Funders has this number of null values: 1112
# Additional Information has this number of null values: 1885
# Tweets has this number of null values: 1994
# Mendeley Readers has this number of null values: 1996

# %% [markdown]
# This certainly appears slightly more messy than before. We will try filter our data down a bit more. We will filter out papers with a missing title as this is too important of information to be missing before we analyse our data.

# %%
df_doras = df_doras.filter(df_doras['Publication Title'].isNotNull())

# %%
df_doras.groupBy('Research Name').count().collect()
# Out:
# [Row(Research Name='using neural networks."', count=1),
#  Row(Research Name='exploration in virtual reality."', count=1),
#  Row(Research Name='Algorithm; Multi-Criteria Decision Analysis."', count=1),
#  Row(Research Name='Monica Ward', count=3),
#  Row(Research Name='The original publication is available at www.springerlink.com"', count=31),
#  Row(Research Name='user-generated spoken content retrieval."', count=1),
#  Row(Research Name='retrieval targeting patient information needs."', count=1),
#  Row(Research Name='to digital libraries."', count=1),
#  Row(Research Name='development."', count=2),
#  Row(Research Name='supervised relation extraction."', count=1),
#  Row(Research Name='of user-generated content."', count=1),
#  Row(Research Name='using data selection methods."', count=1),
#  Row(Research Name='conditional context in interactive neural machine translation."', count=1),
#  Row(Research Name='a case study on Hindi texts."', count=1),
#  Row(Research Name='knowledge from slack chat channels."', count=1),
#  Row(Research Name='information retrieval applications."', count=1),
#  Row(Research Name='task extraction."', count=1),
#  Row(Research Name='search results clustering."', count=1),
#  Row(Research Name='evaluation."', count=1),
#  Row(Research Name='medical endoscopic videos."', count=1),
#  Row(Research Name='software usable for blind translators?"', count=1),
#  Row(Research Name='(IW3C2)"', count=1),
#  Row(Research Name='reminiscence."', count=1),
#  Row(Research Name='parsing; Irish; dependency treebank; universal dependencies; mapping; labels"', count=1),
#  Row(Research Name='microblog track."', count=1),
#  Row(Research Name='            Time-Series Sensor Data."', count=2),
#  Row(Research Name='stacking and joint modelling."', count=1),
#  Row(Research Name='recognition to promote behavioural change."', count=1),
#  Row(Research Name='. Personal use of this material is permitted. Permission from IEEE must be obtained for all other users', count=1),
#  Row(Research Name='statistical machine translation"', count=1),
#  Row(Research Name='feedback: a positive computing perspective."', count=1),
#  Row(Research Name='Interaction; Social Signal Processing; Public Speaking."', count=1),
#  Row(Research Name='and retrieval"', count=1),
#  Row(Research Name='Metadata; FAIR Principles; Data Governance"', count=2),
#  Row(Research Name='Suzanne Little', count=42),
#  Row(Research Name='information archives."', count=1),
#  Row(Research Name='models: cellular automata and Monte Carlo methods."', count=3),
#  Row(Research Name='Sınıflandırılması (Classification of Participants Profiles in MOOCs Using Neural Networks [in Turkish])."', count=1),
#  Row(Research Name='translation."', count=2),
#  Row(Research Name='machine translation."', count=1),
#  Row(Research Name='automatic machine translation metrics."', count=2),
#  Row(Research Name='wearable devices"', count=1),
#  Row(Research Name='Translation."', count=1),
#  Row(Research Name='Commons 4.0 licence."', count=2),
#  Row(Research Name='collection; multimodal dataset"', count=1),
#  Row(Research Name='educational data mining"', count=2),
#  Row(Research Name='3.0 International Licence."', count=1),
#  Row(Research Name='Personality Assessment; Industrial Case Study"', count=1),
#  Row(Research Name='Internet of Things; Ambient Assisted Living"', count=1),
#  Row(Research Name='Component Analysis (PCA); Random Matrix Theory (RMT); Educational Data Mining"', count=2),
#  Row(Research Name='service"', count=1),
#  Row(Research Name='SMT: a Case study using the Trommons platform."', count=1),
#  Row(Research Name='of novice software engineers."', count=2),
#  Row(Research Name='using internet of things technologies."', count=1),
#  Row(Research Name='techniques for patent retrieval."', count=1),
#  Row(Research Name='Geoff Hamilton', count=3),
#  Row(Research Name='Briggs Type Indicator (MBTI); Questionnaire Validation"', count=2),
#  Row(Research Name='Support"', count=1),
#  Row(Research Name='learning; Empirical evaluation; Machine Translation"', count=2),
#  Row(Research Name='Long Cheng', count=10),
#  Row(Research Name='Intelligence"', count=1),
#  Row(Research Name='lists', count=4),
#  Row(Research Name='David Sinclair', count=1),
#  Row(Research Name='Europe; Autonomous vehicles"', count=1),
#  Row(Research Name='Alan F. Smeaton', count=319),
#  Row(Research Name='of human parity in neural machine translation."', count=1),
#  Row(Research Name='of academic presentations."', count=1),
#  Row(Research Name='management; high performance analytics"', count=1),
#  Row(Research Name='University."', count=4),
#  Row(Research Name='Andy Way', count=215),
#  Row(Research Name='I am the administrator of DORAS - the non-commercial open access Institutional Repository at Dublin City University', count=1),
#  Row(Research Name='incrementally retrained post-editing-based SMT."', count=1),
#  Row(Research Name='engineering lifelog solutions."', count=1),
#  Row(Research Name='Dementia; Camera"', count=3),
#  Row(Research Name='and genre tagging task."', count=1),
#  Row(Research Name='Networks."', count=1),
#  Row(Research Name='accompanied audio categories."', count=1),
#  Row(Research Name='in sports video based on SIFT point matching."', count=2),
#  Row(Research Name='Digital Diary"', count=1),
#  Row(Research Name='company: exploratory industrial case study."', count=1),
#  Row(Research Name='Media; Streaming media"', count=1),
#  Row(Research Name='Jennifer Foster', count=48),
#  Row(Research Name='psycho-demographic correlates."', count=1),
#  Row(Research Name='a case study on E-commerce listing titles."', count=1),
#  Row(Research Name='Microspheres; Drug Dissolution"', count=3),
#  Row(Research Name='language user-generated content (UGC)."', count=1),
#  Row(Research Name='historical documents."', count=1),
#  Row(Research Name='Machine learning; Peer learning; Educational data mining"', count=1),
#  Row(Research Name='(CC BY) license (http://creativecommons.org/licenses/by/4.0/)."', count=1),
#  Row(Research Name='content."', count=1),
#  Row(Research Name='Yvette Graham', count=25),
#  Row(Research Name='Brian Davis', count=2),
#  Row(Research Name='from personal lifelogs for reflection."', count=1),
#  Row(Research Name='open vocabulary querying; automatic annotation"', count=1),
#  Row(Research Name='translation; State-of-the-art in Automatic Post-editing"', count=2),
#  Row(Research Name='classification approach for customer feedback analysis task."', count=1),
#  Row(Research Name='information retrieval."', count=1),
#  Row(Research Name='for cross-lingual Arabic-to-English user-generated speech search."', count=4),
#  Row(Research Name='translation-based cross-lingual information."', count=1),
#  Row(Research Name='Supérieure d’Informatique', count=1),
#  Row(Research Name='where is the user in the age of deep learning?"', count=1),
#  Row(Research Name='Rob Brennan', count=44),
#  Row(Research Name='experiences from Ordnance Survey Ireland (OSi)."', count=1),
#  Row(Research Name='Data Mining; Predictive Modelling; Behavioral Analytics"', count=1),
#  Row(Research Name='syntactic supertags."', count=1),
#  Row(Research Name='quality prediction"', count=1),
#  Row(Research Name='alignment entropy."', count=1),
#  Row(Research Name='databases."', count=2),
#  Row(Research Name='derivative works', count=1),
#  Row(Research Name='FoSSaCS 2019: Foundations of Software Science and Computation Structures pp 80-97 as part of Lecture Notes in Computer Science', count=1),
#  Row(Research Name='communication; asynchronous communication; spacial data mining; superspeedup"', count=1),
#  Row(Research Name='development; software development lifecycle"', count=2),
#  Row(Research Name='computer interaction"', count=1),
#  Row(Research Name='network model inference."', count=2),
#  Row(Research Name='CloudSim."', count=1),
#  Row(Research Name='personal lifelogs."', count=1),
#  Row(Research Name='for digital libraries."', count=1),
#  Row(Research Name='Michael Scriney', count=13),
#  Row(Research Name='narrative presentation; card-sorting; montage;"', count=1),
#  Row(Research Name='Silvana Togneri Mac Mahon', count=1),
#  Row(Research Name='of a task to understand the task."', count=1),
#  Row(Research Name='anomaly detection in network traffic."', count=1),
#  Row(Research Name='Marija Bezbradica', count=34),
#  Row(Research Name='language."', count=1),
#  Row(Research Name='Andrew McCarren', count=31),
#  Row(Research Name='Development Roles; Specialised Communication; Terminology; Ontology"', count=2),
#  Row(Research Name='directions."', count=3),
#  Row(Research Name='Emotion Space."', count=1),
#  Row(Research Name='Functional Grammar"', count=1),
#  Row(Research Name='Learner Experience; Telecommunication"', count=1),
#  Row(Research Name='Jane Kernan', count=1),
#  Row(Research Name='translation: the search for systematic differences."', count=1),
#  Row(Research Name='in image search and retrieval."', count=1),
#  Row(Research Name='Malika Bendechache', count=24),
#  Row(Research Name='dimensions."', count=1),
#  Row(Research Name='Matching; Sports Video"', count=2),
#  Row(Research Name='for all other users', count=4),
#  Row(Research Name='software processes."', count=1),
#  Row(Research Name='The published version is available electronically on SpringerLink at http://www.springerlink.com/openurl.asp?genre=article&id=doi:10.1007/s00799-012-0102-3"', count=1),
#  Row(Research Name='Commons 4.0 licence', count=1),
#  Row(Research Name='statistical machine translation."', count=1),
#  Row(Research Name='Evaluation"', count=2),
#  Row(Research Name='morphologically rich languages."', count=1),
#  Row(Research Name='A. It’s complicated!"', count=1),
#  Row(Research Name='Manuals; Indexing; TV"', count=1),
#  Row(Research Name='Tweets."', count=1),
#  Row(Research Name='Heather J. Ruskin', count=29),
#  Row(Research Name='process adaptive capability and organisational performance."', count=2),
#  Row(Research Name='maturity model."', count=1),
#  Row(Research Name='reordering models."', count=1),
#  Row(Research Name='for Chinese–English SMT."', count=1),
#  Row(Research Name='for quantifying the value of data assets."', count=1),
#  Row(Research Name='More information on Author Rights can be found here: http://www.worldscinet.com/authors/authorrights.shtml"', count=1),
#  Row(Research Name='Ray Walshe', count=2),
#  Row(Research Name='Motion; Optical Flow"', count=1),
#  Row(Research Name='Tomas Ward', count=23),
#  Row(Research Name='electroencephalography (EEG);event-related potentials (ERPs); spatial filtering"', count=3),
#  Row(Research Name='Alistair Sutherland', count=16),
#  Row(Research Name='NMT using professional translators."', count=1),
#  Row(Research Name='Kullanılarak İncelenmesi]."', count=1),
#  Row(Research Name='correction."', count=1),
#  Row(Research Name='Arabic User-Generated content"', count=1),
#  Row(Research Name='using constrained word lattice."', count=1),
#  Row(Research Name='the DCU system for NEWS 2009."', count=1),
#  Row(Research Name='Dónal Fitzpatrick', count=2),
#  Row(Research Name='information."', count=1),
#  Row(Research Name='demo system using Furhat robots."', count=1),
#  Row(Research Name='data challenge."', count=1),
#  Row(Research Name='systems."', count=1),
#  Row(Research Name='Coronaviruses"', count=3),
#  Row(Research Name='(ICDAR 2019', count=1),
#  Row(Research Name='with automatic post-editing."', count=1),
#  Row(Research Name='Cathal Gurrin', count=221),
#  Row(Research Name='spoken query spoken content retrieval."', count=1),
#  Row(Research Name='topic-based feeds for dual language audio-visual content."', count=1),
#  Row(Research Name='templates in task-oriented dialogue."', count=1),
#  Row(Research Name='Mark Roantree', count=43),
#  Row(Research Name='management"', count=1),
#  Row(Research Name='the software development process."', count=2),
#  Row(Research Name='E-commerce product listings."', count=1),
#  Row(Research Name='Graham Healy', count=37),
#  Row(Research Name='Personal use of this material is permitted. Permission from IEEE must be obtained for all other users', count=1),
#  Row(Research Name='cardiorespiratory fitness"', count=1),
#  Row(Research Name='variable retrieval effectiveness"', count=1),
#  Row(Research Name='automated image captioning"', count=1),
#  Row(Research Name='wikipedia."', count=1),
#  Row(Research Name='components of this work owned by others than ACM must be honored. Abstracting with credit is permitted"', count=1),
#  Row(Research Name='social media."', count=1),
#  Row(Research Name='detection for binary image matching and retrieval."', count=1),
#  Row(Research Name='Annalina Caputo', count=9),
#  Row(Research Name='controls community group (DPVCG)."', count=1),
#  Row(Research Name='Due to the COVID-19 pandemic', count=1),
#  Row(Research Name='Martin Crane', count=40),
#  Row(Research Name='a case Study on hotel booking."', count=1),
#  Row(Research Name='using the RECAP DES simulator."', count=1),
#  Row(Research Name='architecture."', count=1),
#  Row(Research Name='Relevance Feedback"', count=2),
#  Row(Research Name='Alessandra Mileo', count=11),
#  Row(Research Name='SMT outputs."', count=1),
#  Row(Research Name='content: An initial investigation."', count=1),
#  Row(Research Name='Dongyun Nie', count=2),
#  Row(Research Name='Translation; CBMT"', count=1),
#  Row(Research Name='Data Analytics"', count=1),
#  Row(Research Name='Paul M. Clarke', count=57),
#  Row(Research Name='similarity; comparable corpora"', count=1),
#  Row(Research Name='Intelligence (www.aaai.org)."', count=1),
#  Row(Research Name='Clustering; Parallel clustering; DBSCAN; Dynamic K-means"', count=1),
#  Row(Research Name='series; received total wideband power"', count=2),
#  Row(Research Name='information for crisis response."', count=1),
#  Row(Research Name='relaxed design constrain; fault tolerance"', count=1),
#  Row(Research Name='real-world Elastic Search application."', count=1),
#  Row(Research Name='a tree kernel approach."', count=1),
#  Row(Research Name='lifelogging with mobile devices."', count=2),
#  Row(Research Name='This is an open access article distributed under the Creative Commons Attribution License which permits unrestricted use', count=1),
#  Row(Research Name='dialogue; reflective practice"', count=1),
#  Row(Research Name='promotional purposes', count=4),
#  Row(Research Name='translation task."', count=2),
#  Row(Research Name='cross-lingual tweets."', count=1),
#  Row(Research Name='Estimation"', count=1),
#  Row(Research Name='corpora."', count=2),
#  Row(Research Name='Gareth Jones', count=190),
#  Row(Research Name='information retrieval lab (PIR-CLEF 2018)."', count=1),
#  Row(Research Name='Narrative peaks; documentaries"', count=1),
#  Row(Research Name='a web collection of an aligned multimodal and multilingual corpus."', count=1),
#  Row(Research Name='storytelling; narrative; reflection; sharing"', count=1),
#  Row(Research Name='opportunities."', count=2),
#  Row(Research Name='Usability"', count=1),
#  Row(Research Name='Murat YILMAZ', count=47),
#  Row(Research Name='content analysis."', count=1),
#  Row(Research Name='clustering."', count=2),
#  Row(Research Name='from close counterparts."', count=1),
#  Row(Research Name='using mixed embeddings."', count=1),
#  Row(Research Name='authoring/post-editing tools."', count=1),
#  Row(Research Name='Interaction; Positive Computing; Public Speaking"', count=1),
#  Row(Research Name='Yazılım Yönetiminde İşe Alıştırma Süreçlerinin İyileştirilmesi İçin Düşünülmüş Bir Endüstriyel Vaka Çalışması."', count=2),
#  Row(Research Name='learning models with large scale healthcare data."', count=1),
#  Row(Research Name='helpful or harmful?"', count=1),
#  Row(Research Name='data value assessment and measurement integration."', count=1),
#  Row(Research Name="Darragh O'Brien", count=9),
#  Row(Research Name='Dimitar Shterionov', count=11),
#  Row(Research Name='information for neural machine translation."', count=1),
#  Row(Research Name='Irina Tal', count=10),
#  Row(Research Name='personalised search."', count=1)]

# %% [markdown]
# There is a lot of incorrect values in this column in our PySpark dataframe. To get a more conclusive analysis we need to remove these values such as "helpful or harmful?" from the data. We will do this with our earlier data.

# %%
lst = df_dcu.toPandas()

# %%
lst = lst['Researcher']
lst = lst.tolist()

# %%
df_doras = df_doras.filter(F.col("Research Name").isin(lst))

# %%
df_doras.toPandas().shape
# Out:
# (1243, 29)

# %% [markdown]
# Let's check for the author who occurs the most now.

# %%
author_count = df_doras.groupby('Research Name').count()
author_count.orderBy('count', ascending=False).show()
# Out:
# +-------------------+-----+
# |      Research Name|count|
# +-------------------+-----+
# |    Alan F. Smeaton|  319|
# |      Cathal Gurrin|  221|
# |           Andy Way|  215|
# |    Jennifer Foster|   48|
# |        Rob Brennan|   44|
# |      Mark Roantree|   43|
# |     Suzanne Little|   42|
# |       Martin Crane|   40|
# |       Graham Healy|   37|
# |  Marija Bezbradica|   34|
# |    Andrew McCarren|   31|
# |      Yvette Graham|   25|
# | Malika Bendechache|   24|
# |         Tomas Ward|   23|
# |Alistair Sutherland|   16|
# |    Michael Scriney|   13|
# | Dimitar Shterionov|   11|
# |   Alessandra Mileo|   11|
# |         Long Cheng|   10|
# |          Irina Tal|   10|
# +-------------------+-----+
# only showing top 20 rows

# %% [markdown]
# These are very similar results to our google scholar analysis earlier. Alan F.Smeaton, Cathal Gurrin and Andy Way all have a large number of papers

# %%
df_dcu
# Out:
# DataFrame[Researcher: string, Position: string]

# %%
df_dcu.toPandas()
# Out:
#                   Researcher  \
# 0            Michael Scriney
# 1         Malika Bendechache
# 2          Marija Bezbradica
# 3                Rob Brennan
# 4            Annalina Caputo
# 5                 Long Cheng
# 6                Paul Clarke
# 7               Martin Crane
# 8               Charlie Daly
# 9                Brian Davis
# 10         Donal Fitzpatrick
# 11           Jennifer Foster
# 12             Yvette Graham
# 13             Cathal Gurrin
# 14         Geoffrey Hamilton
# 15              Graham Healy
# 16            Musfira Jilani
# 17        Gareth J. F. Jones
# 18            Suzanne Little
# 19  Silvana Togneri MacMahon
# 20           Andrew McCarren
# 21              John McKenna
# 22          Alessandra Mileo
# 23           Darragh O'Brien
# 24             Mark Roantree
# 25            Heather Ruskin
# 26        Dimitar Shterionov
# 27            David Sinclair
# 28           Alan F. Smeaton
# 29       Alistair Sutherland
# 30                 Irina Tal
# 31   Jagadeeswaran Thangaraj
# 32                Ray Walshe
# 33               Monica Ward
# 34                Tomas Ward
# 35                  Andy Way
# 36              Murat Yilmaz
#
#                                              Position
# 0                   Insight Centre for Data Analytics
# 1   School of Computing, Dublin City University (DCU)
# 2   Lecturer, School of Computing, Dublin City Uni...
# 3   Assistant Professor, School of Computing, Dubl...
# 4   Assistant Professor, Dublin City University, A...
# 5    Professor, North China Electric Power University
# 6   Associate Professor at Dublin City University ...
# 7         School of Computing, Dublin City University
# 8                        Lecturer in Computer Science
# 9   Assistant Professor, School of Computing, Dubl...
# 10  Lecturer, School of Computing, Dublin City Uni...
# 11        School of Computing, Dublin City University
# 12        Assistant Professor, Trinity College Dublin
# 13  School of Computing, Dublin City University & ...
# 14        Associate Professor, Dublin City University
# 15        Assistant Professor, Dublin City University
# 16  School of Computer Science, Dublin City Univer...
# 17                             Dublin City University
# 18        School of Computing, Dublin City University
# 19                             Dublin City University
# 20  School of Computer Science, Dublin City Univer...
# 21        School of Computing, Dublin City University
# 22                             Dublin City University
# 23                             Dublin City University
# 24        School of Computing, Dublin City University
# 25  Dublin City University Professor Emeritus Comp...
# 26                                 Tilburg University
# 27  School of Computing, Lero, Dublin City University
# 28  Prof of Computing / Founding Director, Insight...
# 29        School of Computing, Dublin City University
# 30                             Dublin City University
# 31            Dublin City University, Dublin, Ireland
# 32                             Dublin City University
# 33                             Dublin City University
# 34  Insight SFI Research Centre for Data Analytics...
# 35               ADAPT Centre, Dublin City University
# 36  Associate Professor, Dept. of Computer Enginee...
