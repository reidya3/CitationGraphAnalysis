# %%
import pandas as pd
import numpy as np
import wget

from webdriver_manager.chrome import ChromeDriverManager

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.remote.webelement import WebElement
import selenium.webdriver.support.ui as ui
import selenium.webdriver.support.expected_conditions as EC
import time
import os
import random
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST chromedriver version for 95.0.4638 google-chrome
# Driver [C:\Users\user\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# <ipython-input-1-4b3d3866c4df>:20: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
sx = ['https://scholar.google.com/citations?user=VexgHMQAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=032sCkEAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=37nnKncAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=5W07oMIAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=FWR33eAAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=aI-bwLgAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=gZ4MTA8AAAAJ&hl=en&oi=sra',
'https://scholar.google.com/citations?user=VwafmG0AAAAJ&hl=en&oi=ao#',
'https://scholar.google.com/citations?user=UhNLg7kAAAAJ&hl=en&oi=sra',
'https://scholar.google.com/citations?user=Y6TTxycAAAAJ&hl=en&oi=ao',]

# %%
scholars=[
'https://scholar.google.com/citations?user=qYxtpJcAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=SC2xBNwAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?hl=en&user=_iRbvFYAAAAJ',
'https://scholar.google.com/citations?hl=en&user=NSm2hJMAAAAJ',
'https://scholar.google.com/citations?hl=en&user=0NAvG3UAAAAJ',
'https://scholar.google.com/citations?hl=en&user=Iv3WtrsAAAAJ',
'https://scholar.google.com/citations?user=r59BzegAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=YJuN_H8AAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?hl=en&user=IjXu9IwAAAAJ',
'https://scholar.google.com/citations?hl=en&user=Nt3luwkAAAAJ',
'https://scholar.google.com/citations?hl=en&user=XmvJNG8AAAAJ',
'https://scholar.google.com/citations?hl=en&user=L6sxj4cAAAAJ',
'https://scholar.google.com/citations?user=ZkQuEgMAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=GegQbH4AAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=MI_tlpIAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=Ootl1HQAAAAJ&hl=en&oi=sra',
'https://scholar.google.com/citations?hl=en&user=5BagDNgAAAAJ',
'https://scholar.google.com/citations?hl=en&user=_oD5KVgAAAAJ',
'https://scholar.google.com/citations?hl=en&user=o7xnW2MAAAAJ',
'https://scholar.google.com/citations?user=yjTWSAEAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=d-G6EqsAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?hl=en&user=kT3yQwoAAAAJ',
'https://scholar.google.com/citations?user=ToA74GEAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=DXgY_xYAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=dL7lCKUAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=YLwnsbUAAAAJ&hl=en&oi=ao',
'https://scholar.google.com/citations?user=S7J_GYAAAAAJ&hl=en&oi=ao',
]

# %%
names = []
pos = []

# %%
for i in range(len(scholars)):    
    link = scholars[i]
    #print(link)
    driver.get(link)
    time.sleep(4 + random.uniform(0,10))
    name = driver.find_elements_by_xpath('//div[@id="gsc_prf_in"]')
    position = driver.find_elements_by_xpath('//div[@class="gsc_prf_il"]')
    #est = driver.find_elements_by_xpath('//span[@class="hp-datum__value"]')

    for s in range(len(name)):
        names.append(name[s].text)
        pos.append(position[s].text)

    #for s in range(len(position)):
        #pos.append(position[s].text)

#    for s in range(len(est)):
#        estimate.append(est[s].text)
# Out:
# <ipython-input-4-fa8b26d2dabe>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath('//div[@id="gsc_prf_in"]')
# <ipython-input-4-fa8b26d2dabe>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   position = driver.find_elements_by_xpath('//div[@class="gsc_prf_il"]')

# %%
df = pd.DataFrame()
df['Researcher'] = names
df['Position'] = pos

# %%
df.replace({'Researcher':{'Alan F. Smeaton MRIA FIEEE':'Alan F. Smeaton', 'Murat YILMAZ': 'Murat Yilmaz'}}, inplace = True)

# %%
df
# Out:
#                   Researcher  \
# 0            Michael Scriney
# 1         Malika Bendechache
# 2          Marija Bezbradica
# 3                Rob Brennan
# 4            Annalina Caputo
# 5                 Long Cheng
# 6                Paul Clarke
# 7               Martin Crane
# 8               Charlie Daly
# 9                Brian Davis
# 10         Donal Fitzpatrick
# 11           Jennifer Foster
# 12             Yvette Graham
# 13             Cathal Gurrin
# 14         Geoffrey Hamilton
# 15              Graham Healy
# 16            Musfira Jilani
# 17        Gareth J. F. Jones
# 18            Suzanne Little
# 19  Silvana Togneri MacMahon
# 20           Andrew McCarren
# 21              John McKenna
# 22          Alessandra Mileo
# 23           Darragh O'Brien
# 24             Mark Roantree
# 25            Heather Ruskin
# 26        Dimitar Shterionov
# 27            David Sinclair
# 28           Alan F. Smeaton
# 29       Alistair Sutherland
# 30                 Irina Tal
# 31   Jagadeeswaran Thangaraj
# 32                Ray Walshe
# 33               Monica Ward
# 34                Tomas Ward
# 35                  Andy Way
# 36              Murat Yilmaz
#
#                                              Position
# 0                   Insight Centre for Data Analytics
# 1   School of Computing, Dublin City University (DCU)
# 2   Lecturer, School of Computing, Dublin City Uni...
# 3   Assistant Professor, School of Computing, Dubl...
# 4   Assistant Professor, Dublin City University, A...
# 5    Professor, North China Electric Power University
# 6   Associate Professor at Dublin City University ...
# 7         School of Computing, Dublin City University
# 8                        Lecturer in Computer Science
# 9   Assistant Professor, School of Computing, Dubl...
# 10  Lecturer, School of Computing, Dublin City Uni...
# 11        School of Computing, Dublin City University
# 12        Assistant Professor, Trinity College Dublin
# 13  School of Computing, Dublin City University & ...
# 14        Associate Professor, Dublin City University
# 15        Assistant Professor, Dublin City University
# 16  School of Computer Science, Dublin City Univer...
# 17                             Dublin City University
# 18        School of Computing, Dublin City University
# 19                             Dublin City University
# 20  School of Computer Science, Dublin City Univer...
# 21        School of Computing, Dublin City University
# 22                             Dublin City University
# 23                             Dublin City University
# 24        School of Computing, Dublin City University
# 25  Dublin City University Professor Emeritus Comp...
# 26                                 Tilburg University
# 27  School of Computing, Lero, Dublin City University
# 28  Prof of Computing / Founding Director, Insight...
# 29        School of Computing, Dublin City University
# 30                             Dublin City University
# 31            Dublin City University, Dublin, Ireland
# 32                             Dublin City University
# 33                             Dublin City University
# 34  Insight SFI Research Centre for Data Analytics...
# 35               ADAPT Centre, Dublin City University
# 36  Associate Professor, Dept. of Computer Enginee...

# %%
paper_title = []
authors = []
date = []
conference = []
publisher = []
abstract = []
citation = []
journal = []

# %%
from selenium.common.exceptions import NoSuchElementException
def mark_complete(self):
    mark_complete = self.find_element_by_xpath('//button[@id="gsc_bpf_more"]')
    prop = mark_complete.get_property('disabled')
    while prop != True:
        try:
            mark_complete.click()
            time.sleep(2 + random.uniform(0,3))
            prop = mark_complete.get_property('disabled')
            #print(prop)
        except NoSuchElementException:
            break

# %%
for j in range(len(scholars)):
    link = scholars[j]
    driver.get(link)

    mark_complete(driver)

    results_list = driver.find_elements_by_xpath("//a[@class='gsc_a_at']")
    #results_list[0].click()
    #print(len(results_list))
    #assert len(results_list) > 0
    #print(len(results_list))

    for x in range(len(results_list)):

        # have to call this again due to same problem with dom elements being deleted
        mark_complete(driver)
        # reassign result_list as after first page the dom element is deleted
        results_list = driver.find_elements_by_xpath("//a[@class='gsc_a_at']")
        
        page = results_list[x]
        #print(x)
        time.sleep(5)

        page.click()

        time.sleep(2)
        
        try:    
            titlelink = driver.find_element_by_xpath('//a[@class="gsc_oci_title_link"]')
        except:
            titlelink = driver.find_element_by_xpath('//div[@id="gsc_oci_title"]')
        
        paper_title.append(titlelink.text)

        a = driver.find_elements_by_xpath('//td[@class="gsc_a_c"]')

        table_id = driver.find_element(By.ID, 'gsc_oci_table')
        rows = table_id.find_elements(By.CLASS_NAME, "gs_scl") # get all of the rows in the table
        test = []
        for row in range(len(rows)):       
            col = driver.find_elements(By.CLASS_NAME, "gsc_oci_value")[row].text
            heading = driver.find_elements(By.CLASS_NAME, "gsc_oci_field")[row].text

            #print(heading)
            test.append(heading)
            if heading == 'Authors':
                authors.append(col)
            elif heading == 'Publication date':
                #y = col.split('/')
                date.append(col[0:4])
            elif heading == 'Conference':
                conference.append(col)
            elif heading == 'Journal':
                journal.append(col)
            elif heading == 'Publisher':
                publisher.append(col)
            elif heading == 'Description':
                abstract.append(col)
            elif heading == 'Total citations':
                tot = col.split()
                citation.append(tot[2])

            #print(col.text)       
            #driver.find_element(By.ID, "gs_hdr_bck").click()
        if 'Authors' not in test:
            authors.append('Unknown')
        
        if 'Publisher' not in test:
            publisher.append('Unknown')

        if 'Conference' not in test:
            conference.append('Unknown')

        if 'Publication date' not in test:
            date.append('Unknown')

        if 'Journal' not in test:
            journal.append('Unknown')
            
        if 'Description' not in test:
            abstract.append('Unknown')
            
        if 'Total citations' not in test:
            citation.append('Unknown')

        #print(test)
        driver.back()
        #button.click()
        #print("Element is visible? " + str(button.is_displayed()))
# Out:
# <ipython-input-9-e3e7c7d10d88>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   mark_complete = self.find_element_by_xpath('//button[@id="gsc_bpf_more"]')
# <ipython-input-36-9994b9ea84bc>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   results_list = driver.find_elements_by_xpath("//a[@class='gsc_a_at']")
# <ipython-input-36-9994b9ea84bc>:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   results_list = driver.find_elements_by_xpath("//a[@class='gsc_a_at']")
# <ipython-input-36-9994b9ea84bc>:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   titlelink = driver.find_element_by_xpath('//a[@class="gsc_oci_title_link"]')
# <ipython-input-36-9994b9ea84bc>:35: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   a = driver.find_elements_by_xpath('//td[@class="gsc_a_c"]')
# <ipython-input-36-9994b9ea84bc>:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   titlelink = driver.find_element_by_xpath('//div[@id="gsc_oci_title"]')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-9994b9ea84bc> in <module>
#      18         results_list = driver.find_elements_by_xpath("//a[@class='gsc_a_at']")
#      19
# ---> 20         page = results_list[x]
#      21         #print(x)
#      22         time.sleep(5)
#
# IndexError: list index out of range

# %%
#table_id = driver.find_element(By.ID, 'gsc_oci_table')
#rows = table_id.find_elements(By.CLASS_NAME, "gs_scl") # get all of the rows in the table
#    for row in rows:
#    # Get the columns (all the column 2)        
#    col = row.find_elements(By.CLASS_NAME, "gsc_oci_value")[row] #note: index start from 0, 1 is col 2
#    print col.text

# %%
paper_title
# Out:
# ['Efficient cube construction for smart city data',
#  'Generating cubes from smart city web data',
#  'Automating Data Mart Construction from Semi-structured Data Sources',
#  'Predicting customer churn for insurance data',
#  'Attention Based Video Summaries of Live Online Zoom Classes',
#  'Constructing data marts from web sources using a graph common model',
#  'Integrating online data for smart city data marts',
#  'Identification of movement categories and associated velocity thresholds for elite Gaelic football and hurling referees',
#  'Representative Sample Extraction from Web Data Streams',
#  'Using Artificial Intelligence to Automate Meat Cut Identification from the Semimembranosus Muscle on Beef Boning Lines',
#  'The L2L System for Second Language Learning Using Visualised Zoom Calls Among Students',
#  'Usage-based Summaries of Learning Videos',
#  'Machine learning-based tools for water digitalisation',
#  'CASIE–Computing affect and social intelligence for healthcare in an ethical and trustworthy manner',
#  'Supporting an effective review of telecollaboration for second language learning by visualising the participation and engagement at Dublin City University',
#  'A Methodology for Validating Diversity in Synthetic Time Series Generation',
#  'Identifying extra-terrestrial intelligence using machine learning',
#  'Integrating online data for smart city data marts',
#  'Simulating fog and edge computing scenarios: An overview and research challenges',
#  'Distributed clustering algorithm for spatial data mining',
#  'Efficient large scale clustering based on data partitioning',
#  'Parallel and distributed clustering framework for big spatial data mining',
#  'Hierarchical aggregation approach for distributed clustering of spatial datasets',
#  'Lung infection segmentation for COVID-19 Pneumonia based on a cascade convolutional network from CT images',
#  'Simulating resource management across the cloud-to-thing continuum: A survey and future directions',
#  'Modelling and simulation of ElasticSearch using cloudsim',
#  'Detecting human activities based on a multimodal sensor data set using a bidirectional long short-term memory model: a case study',
#  'Brain tumor segmentation based on deep learning and an attention mechanism using MRI multi-modalities brain images',
#  'A review of current machine learning approaches for anomaly detection in network traffic',
#  'Towards simulation and optimization of cache placement on large virtual content distribution networks',
#  'Study of distributed dynamic clustering framework for spatial data mining',
#  'Performance evaluation of a distributed clustering approach for spatial datasets',
#  'An extended approach to predict retinopathy in diabetic patients using the genetic algorithm and fuzzy C-means',
#  'TPCNN: Two-path convolutional neural network for tumor and liver segmentation in CT images using a novel encoding approach',
#  'Application of blockchain technology to 5G-enabled vehicular networks: survey and future directions',
#  'Simulating Across the Cloud-to-Edge Continuum',
#  'Orchestration from the Cloud to the Edge',
#  'Irish attitudes toward COVID tracker app & privacy: sentiment analysis on Twitter and survey data',
#  'AI in My Life: AI, Ethics & Privacy Workshops for 15-16-Year-Olds',
#  'Simulating and Evaluating a Real-World ElasticSearch System Using the RECAP DES Simulator',
#  'Towards an automatic data value analysis method for relational databases',
#  'Analysing dependability and performance of a real-world Elastic Search application',
#  'Osteolysis: A Literature Review of Basic Science and Potential Computer-Based Image Processing Detection Methods',
#  'Public attitudes towards privacy in COVID-19 times in the Republic of Ireland: A pilot study',
#  'Privacy in times of COVID-19: a pilot study in the Republic of Ireland',
#  'Privacy in a Time of COVID-19: How Concerned Are You?',
#  'PRIVATT-a closer look at people’s data privacy attitudes in times of COVID-19',
#  'Incorporating User Preferences in Multi-objective Feature Selection in Software Product Lines Using Multi-Criteria Decision Analysis',
#  'AUDD: Audio Urdu Digits Dataset for Automatic Audio Urdu Digit Recognition',
#  '首页» 文章» 文章详细信息',
#  'Urban enterprise: a review of smart city frameworks from an enterprise architecture perspective',
#  'Cities as enterprises: a comparison of smart city frameworks based on enterprise architecture requirements',
#  'A requirements framework for the design of smart city reference architectures',
#  'Parallelisation strategies for large scale cellular automata frameworks in pharmaceutical modelling',
#  'Bitcoin currency fluctuation',
#  'Scenario-based requirements elicitation for user-centric explainable ai',
#  'Day ahead forecasting of FAANG stocks using ARIMA, LSTM networks and wavelets.',
#  'The role of user emotions for content personalization in e-commerce: literature review',
#  'Performance analysis of the quality of service-aware networking scheme for smart internet of things gateways',
#  'Urban Enterprise Principles development approach: a case from a European City',
#  'Customer purchase behavior prediction in e-commerce: A conceptual framework and research agenda',
#  'Modelling drug coatings: A parallel cellular automata model of ethylcellulose-coated microspheres',
#  'The Shift from financial to non-financial measures during transition into digital retail–a systematic literature review',
#  'Applications of High Performance Algorithms to Large Scale Cellular Automata Frameworks Used in Pharmaceutical Modelling.',
#  'Predicting students’ academic performance and main behavioral features using data mining techniques',
#  'Towards preprocessing guidelines for neural network embedding of customer behavior in digital retail',
#  'Types of IT architectures in smart cities–a review from a business model and enterprise architecture perspective',
#  'Comparative analysis of asynchronous cellular automata in stochastic pharmaceutical modelling',
#  'Understanding urban mobility and pedestrian movement',
#  'An overview of user-level usage monitoring in cloud environment',
#  'A usage-based data extraction framework for cloud-based application-an human-computer interaction approach',
#  'Customer Purchase Behavior Prediction in E-commerce: Current Tasks, Applications and Methodologies',
#  'Modelling impact of morphological urban structure and cognitive behaviour on pedestrian flows',
#  'AI cloud-based smart manufacturing and 3D printing techniques for future in-house production',
#  'Generic Refactoring Methodology for Cloud Migration-Position Paper',
#  'Probabilistic pharmaceutical modelling: a comparison between synchronous and asynchronous cellular automata',
#  'Stochastic computational modelling of complex drug delivery systems',
#  'High-performance computing for data analytics',
#  'Probabilistic models for dissolution of ethylcellulose coated microsphere',
#  'Generating and Analyzing Chatbot Responses using Natural Language Processing',
#  'Learning behaviours data in programming education: Community analysis and outcome prediction with cleaned data',
#  'Student behaviours in using learning resources in higher education: How do behaviours reflect success in programming education?',
#  'Towards Refactoring in Cloud-Centric Internet of Things for Smart Cities',
#  'Towards Design Principles for User-Centric Explainable AI in Fraud Detection',
#  "Education as a complex system: using physic methods for the analysis of students' learning behaviours in the context of programming education.",
#  'Explainable Sentiment Analysis Application for Social Media Crisis Management in Retail',
#  'Retail Strategy in the Age of Retail Apocalypse–Exploring the Role of Customer Experience Orientation on Retail Performance',
#  'Who Wants to Use an Augmented Reality Shopping Assistant Application?',
#  'Scenario-Based Requirements Elicitation for User-Centric Explainable AI',
#  'Release modelling of nanoencapsulated food ingredients by probabilistic models: Cellular Automata and Monte Carlo Methods',
#  'Received Total Wideband Power Data Analysis: Multiscale wavelet analysis of RTWP data in a 3G network',
#  'A usage analytics model for analysing user behaviour in IBM academic cloud',
#  'Usage Analytics: A Process to Extract and Analyse Usage Data to Understand User Behaviour in Cloud',
#  'Proposing Design Principles for User-Centric Explainable AI in Fraud Detection⋆',
#  'This file was downloaded from: http://eprints. qut. edu. au/82681',
#  'Probabilistic Pharmaceutical Modelling: A Comparison Between Synchronous and Asynchronous Cellular...',
#  'Seshat: The global history databank',
#  'Cross-lingual ontology mapping–an investigation of the impact of machine translation',
#  'SCTP congestion control: Initial simulation studies',
#  'Cross-lingual ontology mapping and its use on the multilingual semantic web',
#  'A configurable translation-based cross-lingual ontology mapping system to adjust mapping outcome',
#  'FIPA-compliant agents for real-time control of intelligent network traffic',
#  'Improving curated web-data quality with structured harvesting and assessment',
#  'Evolutionary trends in intelligent networks',
#  'Challenges for federated, autonomic network management in the future internet',
#  'Experimental studies of SCTP multi-homing',
#  'The Celtic Gandalf framework',
#  'A macroscope for global history: Seshat Global History Databank, a methodological overview',
#  'Creating a vocabulary for data privacy',
#  'User evaluation study of a tagging approach to semantic mapping',
#  'Enabling decentralised management through federation',
#  'Policy-based integration of multiprovider digital home services',
#  'Making ontologies talk: knowledge interoperability in the semantic web',
#  'An evaluation of uplift mapping languages',
#  'Ontology Mapping Representations: A Pragmatic Evaluation.',
#  'Open framework middleware for intelligent WSN topology adaption in smart buildings',
#  'An automatically composable OWL reasoner for resource constrained devices',
#  'Bayes-recce: A bayesian model for detecting restriction class correspondences in linked open data knowledge bases',
#  'A trust model for capability delegation in federated policy systems',
#  'Multilingual ontology mapping: Challenges and a proposed framework',
#  'Management of data value chains, a value monitoring capability maturity model',
#  'DELTA-LD: A change detection approach for linked datasets',
#  'FunUL: a method to incorporate functions into uplift mapping languages',
#  'Towards a framework to support novice users in understanding and monitoring of Home Area Networks',
#  'Using pseudo feedback to improve cross-lingual ontology mapping',
#  'Evaluation of ontology mapping representation',
#  'Supporting composite smart home services with semantic fault management',
#  'Design of the CORBA/TC Inter-working Gateway',
#  'Design challenges for GDPR RegTech',
#  'A semantic data value vocabulary supporting data value assessment and measurement integration',
#  'Integration of qos metrics, rules and semantic uplift for advanced iptv monitoring',
#  'Ontology Consistency and Instance Checking for Real World Linked Data.',
#  'Multidomain IT architectures for next-generation communications service providers [Next-Generation Telco IT Architectures]',
#  'Implementing the draft W3C semantic sensor network ontology',
#  'Challenges in value-driven data governance',
#  'Dacura: A new solution to data harvesting and knowledge extraction for the historical sciences',
#  'Linked data schemata: fixing unsound foundations',
#  'Publishing social sciences datasets as linked data: a political violence case study',
#  'Using the OM2R meta-data model for ontology mapping reuse for the ontology alignment challenge-a case study.',
#  'P.: deepTrust Management Application for Discovery, Selection, and Composition of Trustworthy Services',
#  'Validating interlinks between linked data datasets with the SUMMR methodology',
#  'Enabling combined Software and Data engineering at Web-scale: The ALIGNED suite of Ontologies',
#  'Building the seshat ontology for a global history databank',
#  'MooM--a prototype framework for management of ontology mappings',
#  'Consumer-managed federated homes',
#  'Exploring data value assessment: a survey method and investigation of the perceived relative importance of data value dimensions',
#  'The SimCon generator: an interactive context simulator for rapid evaluation of smart building applications using virtual reality',
#  'Understanding information professionals: a survey on the quality of linked data sources for digital libraries',
#  'Managed semantic interoperability for federations',
#  'Federation lifecycle management incorporating coordination of bio-inspired self-management processes',
#  'Federating autonomic network management systems for flexible control of end-to-end communications services',
#  'Pervasive knowledge-based networking for maintenance inspection in smart buildings.',
#  'Is the LOD cloud at risk of becoming a museum for datasets? Looking ahead towards a fully collaborative and sustainable LOD cloud',
#  'Assessing the quality of geospatial linked data–experiences from Ordnance Survey Ireland (OSi)',
#  'Challenges for Value-driven Semantic Data Quality Management.',
#  'Describing Reasoning Results with RVO, the Reasoning Violations Ontology.',
#  'Global Intelligent Content: Active Curation of Language Resources using Linked Data.',
#  'Mapping Representation based on Meta-data and SPIN for Localization Workflows.',
#  'Explicit federal relationship management to support semantic integration',
#  'Modelling Autonomic Communication Environments',
#  'Autonomic replication of management data evaluation of a market-based approach',
#  'Publishing authoritative geospatial data to support interlinking of building information models',
#  'LinkedDataOps: linked data operations based on quality process cycle',
#  'Automatic Extraction of Data Governance Knowledge from Slack Chat Channels',
#  'Milan: automatic generation of R2RML mappings',
#  'The ALIGNED Project-Aligned, Quality-centric Software and Data Engineering Driven by Semantics',
#  'SPARQL based mapping management',
#  'Secure federated monitoring of heterogeneous networks',
#  'A comparison of complex correspondence detection techniques.',
#  'Modelling data access for a distributed network management system',
#  'An intelligent linked data quality dashboard',
#  'Semantic data ingestion for intelligent, value-driven big data analytics',
#  'Building High Usability Consumer-oriented Linked Data Mobile Apps.',
#  'Correspondence pattern attribute selection for consumption of federated data sources',
#  'An architecture for affective management of systems of adaptive systems',
#  'Implementation Experience with the OMG IN/CORBA Interworking Specification',
#  'Signalling System No. 7 as an agent platform message transport protocol',
#  'Irish attitudes toward COVID tracker app & privacy: sentiment analysis on Twitter and survey data',
#  'AI in My Life: AI, Ethics & Privacy Workshops for 15-16-Year-Olds',
#  'GDPR Compliance tools: best practice from RegTech',
#  'ARK-Virus: An ARK Platform Extension for Mindful Risk Governance of Personal Protective Equipment Use in Healthcare',
#  'A common semantic model of the GDPR register of processing activities',
#  'Towards an automatic data value analysis method for relational databases',
#  'Quality metrics to measure the standards conformance of geospatial linked data',
#  'DaVe: A Semantic Data Value Vocabulary to Enable Data Value Characterisation',
#  'License and Template Access Control for Geospatial Linked Data.',
#  'Interlinking Ireland’s authoritative geospatial information on buildings with central statistics office data',
#  'Extension of the M-Gov ontology mapping framework for increased traceability.',
#  'D7. 12-Data Management Plan',
#  'Using Semantic Mappings to Manage Heterogeneity in XLIFF Interoperability',
#  'Manageable Dataset Curation for Linked Data',
#  'Towards grid-based NMS data management in 3G networks and beyond',
#  'On the Application of Paired Comparison to Trust',
#  'Intelligent networks: a discussion of current developments',
#  'FAIR Ontologies for Transparent and Accountable AI: A Hospital Adverse Incidents Vocabulary Case Study',
#  'Public attitudes towards privacy in COVID-19 times in the Republic of Ireland: A pilot study',
#  'Privacy in times of COVID-19: a pilot study in the Republic of Ireland',
#  'Privacy in a Time of COVID-19: How Concerned Are You?',
#  'TIKD: A Trusted Integrated Knowledge Dataspace For Sensitive Healthcare Data Sharing',
#  'PRIVATT-a closer look at people’s data privacy attitudes in times of COVID-19',
#  'The data quality index: improving data quality in Irish healthcare records',
#  'Spatial Linked Data in Europe: Report from Spatial Linked Data Session at Knowledge Graph in Action',
#  'Building a Data Processing Activities Catalog: Representing Heterogeneous Compliance-Related Information for GDPR Using DCAT-AP and DPV',
#  'Irish attitudes to privacy in COVID-19 times: sentiment analysis on Twitter and survey data',
#  'A SKOS taxonomy of the UN global geospatial information management data theme',
#  'Demonstrating GDPR accountability with CSM-ROPA: extensions to the data privacy vocabulary',
#  'Standards Conformance Metrics for Geospatial Linked Data',
#  'The ARK platform: enabling risk management through semantic web technologies',
#  'Towards a Semantic Model of the GDPR Register of Processing Activities',
#  'Geoff: a linked data vocabulary for describing the form and function of spatial objects',
#  'A risk governance framework for healthcare decision support systems based on socio-technical analysis',
#  'Saffron: a data value assessment tool for quantifying the value of data assets',
#  'Towards a knowledge driven framework for bridging the gap between software and data engineering',
#  'A framework for generating aviation risk information mobile user interfaces from knowledge graphs',
#  'Detecting Restriction Class Correspondences in Linked Data: The Bayes-ReCCE Bayesian Model Approach',
#  'Automated Monitoring of Data Quality in Linked Data Systems',
#  'Enabling Combined Software and Data Engineering: the ALIGNED Suite of Ontologies.',
#  'Acknowledgment to Reviewers',
#  'D7. 11-Data Management Plan–Phase 2',
#  'Proceedings of the 1st International Workshop on Computational History 2014, Dublin, Ireland, June 27th, 2014',
#  'Generalizing ITS as an Interoperable Annotation Technique for Global Intelligent Content',
#  'ACKNOWLEDGMENT TO REVIEWERS',
#  'Federated autonomic management of HAN services',
#  'An Interactive Context Simulator for Rapid Evaluation of Smart Building Applications using Virtual Reality',
#  'Managing Ubiquitous Communications and Services 2011. Eighth International Workshop, MUCS 2011, Proceedings',
#  'An Interactive Context Simulator for Rapid Evaluation of Smart Building Applications using Virtual Reality',
#  'SERVICE PROVIDERS MULTIDOMAIN IT ARCHITECTURES FOR NEXT-GENERATION COMMUNICATIONS The authors describe a general layered model for describing interdomain relationships and a …',
#  'Bringing the Semantic Sensor Web to Smart Buildings.',
#  'Introduction to the Track B',
#  'A Distributed Intelligent Network based on CORBA and SCTP',
#  'Dacura: A New Solution to Data Harvesting and Knowledge Extraction for Archaeology',
#  'Preface: The 26th AIAI Irish Conference on Artificial Intelligence and Cognitive Science (AICS 2018)',
#  'Ontology Consistency and Instance Checking',
#  'Evaluation of a Semantic-Oriented Approach to Cross-Lingual Ontology Mapping',
#  'IFIP/IEEE IM 2011 Committees',
#  'MUCS 2011: 8th IEEE International Workshop on Managing Ubiquitous Communications and Services-committees and welcome',
#  'An enhanced lesk word sense disambiguation algorithm through a distributional semantic model',
#  'Concept-based item representations for a cross-lingual content-based recommendation process',
#  'DIACR-Ita@ EVALITA2020: overview of the EVALITA2020 DiachronicLexical semantics (DIACR-Ita) task',
#  'Analysing word meaning over time by exploiting temporal random indexing',
#  'Diachronic Analysis of the Italian Language exploiting Google Ngram.',
#  'Overview of the EVALITA 2016 named entity recognition and linking in Italian tweets (NEEL-IT) task',
#  'Exploiting distributional semantic models in question answering',
#  'SABRE: A sentiment aspect-based retrieval engine',
#  'Enhancing Semantic Search using N-Levels Document Representation',
#  'Temporal random indexing: A system for analysing word meaning over time',
#  'Overview of the EVALITA 2016 question answering for frequently asked questions (QA4FAQ) task',
#  'Encoding syntactic dependencies by vector permutation',
#  'Boosting a semantic search engine by named entities',
#  'UNIBA: Exploiting a Distributional Semantic Model for Disambiguating and Linking Entities in Tweets.',
#  'Negation for document re-ranking in ad-hoc retrieval',
#  'An Automatic Procedure for Generating Datasets for Conversational Recommender Systems',
#  'Learning to rank entity relatedness through embedding-based features',
#  'Extending an Information Retrieval System through Time Event Extraction.',
#  'A Query Algebra for Quantum Information Retrieval.',
#  'Integrating sense discrimination in a semantic information retrieval system',
#  'UNIBA-SENSE at CLEF 2008: SEmantic N-levels Search Engine.',
#  'Kronos-it: a Dataset for the Italian Semantic Change Detection Task.',
#  'Modeling Short-Term Preferences in Time-Aware Recommender Systems.',
#  'SENSE: semantic N-levels search engine at CLEF2008 ad hoc robust-WSD track',
#  'Entity linking for tweets',
#  'Semantic Vectors: an Information Retrieval Scenario',
#  'A Factored Relevance Model for Contextual Point-of-Interest Recommendation',
#  'Entity Attribute Ranking Using Learning to Rank',
#  'Temporal Random Indexing: a Tool for Analysing Word Meaning Variations in News.',
#  'Entity linking for italian tweets',
#  'UNIBA: combining distributional semantic models and sense distribution for multilingual all-words sense disambiguation and entity linking',
#  'A study on compositional semantics of words in distributional spaces',
#  'UNIBA-SENSE@ CLEF 2009: Robust WSD Task',
#  'A diachronic Italian corpus based on “L’Unita”',
#  'Exploiting disambiguation and discrimination in information retrieval systems',
#  'Improving ranked keyword search with SENSE: SEmantic N-levels Search Engine',
#  'A Probabilistic Approach to Personalize Type-Based Facet Ranking for POI Suggestion',
#  'CoRE: a cold-start resistant and extensible recommender system',
#  'Modeling concepts and their relationships for corpus-based query auto-completion',
#  'UNIBA: Distributional semantics for textual similarity',
#  'From fusion to re-ranking: a semantic approach',
#  'Personalizing type-based facet ranking using BERT embeddings',
#  'GM-CTSC at SemEval-2020 Task 1: Gaussian Mixtures Cross Temporal Similarity Clustering',
#  'Diachronic Analysis of Entities by Exploiting Wikipedia Page revisions',
#  'Temporal Entity Random Indexing',
#  'SEPIR: a semantic and personalised information retrieval tool for the public administration based on distributional semantics',
#  'Time Event Extraction to Boost an Information Retrieval System',
#  "LifeSeeker 3.0: An Interactive Lifelog Search Engine for LSC'21",
#  'Kernel Density Estimation based Factored Relevance Model for Multi-Contextual Point-of-Interest Recommendation',
#  'TRI: a tool for the diachronic analysis of large corpora and social media',
#  'Entity Linking for the Semantic Annotation of Italian Tweets',
#  'Temporal Random Indexing: A System for Analysing Word Meaning over Time',
#  'Encoding Syntactic Dependencies using Random Indexing and Wikipedia as a Corpus.',
#  'Integrating Named Entities in a Semantic Search Engine.',
#  'Improving Retrieval Experience Exploiting Semantic Representation of Documents.',
#  'FAIR Ontologies for Transparent and Accountable AI: A Hospital Adverse Incidents Vocabulary Case Study',
#  'Dataset Creation Framework for Personalized Type-Based Facet Ranking Tasks Evaluation',
#  'The Corpora They Are a-Changing: a Case Study in Italian Newspapers',
#  'A VR Interface for Browsing Visual Spaces at VBS2021',
#  'Temporal word embeddings for dynamic user profiling in Twitter',
#  'Linking historical sources to established knowledge bases in order to inform entity linkers in cultural heritage.',
#  'Triple Scoring Using Paragraph Vector - The Gailan Triple Scorer at WSDM Cup 2017',
#  'Proceedings of the Second Italian Conference on Computational Linguistics CLiC-it 2015: 3-4 December 2015, Trento',
#  'UNIBA: Combining Distributional Semantic Models and Word Sense Disambiguation for Textual Similarity',
#  'Combining distributional semantic models and sense distribution for effective Italian word sense disambiguation',
#  'Supervised Learning and Distributional Semantic Models for Super-Sense Tagging',
#  'UNIBA-CORE: Combining Strategies for Semantic Textual Similarity',
#  'Distributional Semantics for Answer Re-ranking in Question Answering.',
#  'Orthogonal Negation for Document Re-ranking.',
#  'From Terms to Concepts: A Revisited Approach to Local Context Analysis.',
#  'Semantic Re-ranking in Ad-hoc Robust Retrieval.',
#  'DIACR-Ita at EVALITA 2020: Task Guidelines',
#  'A woa-based optimization approach for task scheduling in cloud computing systems',
#  'Robust and skew-resistant parallel joins in shared-nothing systems',
#  'A Low-Cost Multi-Failure Resilient Replication Scheme for High-Data Availability in Cloud Storage',
#  'Design and evaluation of small–large outer joins in cloud computing environments',
#  'Robust and efficient large-large table outer joins on distributed infrastructures.',
#  'FlowCon: Elastic Flow Configuration for Containerized Deep Learning Applications',
#  'Scale-Out Processing of Large RDF Datasets',
#  'Efficient data redistribution to speedup big data analytics in large systems',
#  'Efficiently handling skew in outer joins on distributed systems.',
#  'Target-based Resource Allocation for Deep Learning Applications in a Multi-tenancy System',
#  'Business Process Comparison: A Methodology and Case Study',
#  'Scalable Discovery of Hybrid Process Models in a Cloud Computing Environment',
#  'Efficient Parallel Dictionary Encoding for RDF Data.',
#  'Resource management schemes for cloud-native platforms with computing containers of docker and kubernetes',
#  'Efficient Skew Handling for Outer Joins in a Cloud Computing Environment',
#  'Efficient event correlation over distributed systems',
#  'QbDJ: A novel framework for handling skew in parallel join processing on distributed memory',
#  'A coflow-based co-optimization framework for high-performance data analytics',
#  'Deep reinforcement learning for communication flow control in wireless mesh networks',
#  'Privacy-preserving behavioral correctness verification of cross-organizational workflow with task synchronization patterns',
#  'Speculative container scheduling for deep learning applications in a kubernetes cluster',
#  'Deep Reinforcement Learning for IoT Network Dynamic Clustering in Edge Computing',
#  'Improving the robustness and performance of parallel joins over distributed systems',
#  'Fast Compression of Large Semantic Web Data using X10',
#  'Sampling business process event logs using graph‐based ranking model',
#  'Resilient neural network training for accelerators with computing errors',
#  'Efficient large outer joins over mapreduce',
#  'Design and evaluation of parallel hashing over large-scale data',
#  'Massively parallel reasoning under the well-founded semantics using X10',
#  'Measuring Similarity for Data-Aware Business Processes',
#  'Cluster-based flow control in hybrid software-defined wireless sensor networks',
#  'Rethinking Defeasible Reasoning: A Scalable Approach',
#  'Load-balancing distributed outer joins through operator decomposition',
#  'Cluflow: Cluster-based flow management in software-defined wireless sensor networks',
#  'High throughput indexing for large-scale semantic web data',
#  'Scalable RDF data compression using X10',
#  'Runtime characterisation of triple stores: An initial investigation',
#  'Network-Aware Locality Scheduling for Distributed Data Operators in Data Centers',
#  'Minimizing network traffic for distributed joins using lightweight locality-aware scheduling',
#  'Runtime characterization of triple stores',
#  'A QoS-QoR aware CNN accelerator design approach',
#  'A two-tier index architecture for fast processing large RDF data over distributed memory',
#  'A Fully Parallel Framework for Analyzing RDF Data',
#  'SwiftS: a dependency-aware and resource efficient scheduling for high throughput in clouds',
#  'MPC-CSAS: Multi-Party Computation for Real-Time Privacy-Preserving Speed Advisory Systems',
#  'Differentiate Quality of Experience Scheduling for Deep Learning Applications with Docker Containers in the Cloud',
#  'Learning Process Models in IoT Edge',
#  'Investigating distributed approaches to efficiently extract textual evidences for biomedical ontologies',
#  'Cost-aware job scheduling for cloud instances using deep reinforcement learning',
#  'Deep Reinforcement Learning for Load-Balancing Aware Network Control in IoT Edge Systems',
#  'An improved Wolf pack algorithm for optimization problems: Design and evaluation',
#  'TEBC-Net: An Effective Relation Extraction Approach for Simple Question Answering over Knowledge Graphs',
#  'R2F: A Remote Retraining Framework for AIoT Processors With Computing Errors',
#  'CAP: Communication-aware Automated Parallelization for Deep Learning Inference on CMP Architectures',
#  'CDetector: Extracting Textual Features of Financial Social Media to Detect Cyber Attacks',
#  'A Fast Precision Tuning Solution for Always-On DNN Accelerators',
#  'An Edge 3D CNN Accelerator for Low Power Activity Recognition',
#  'DeepDive: Examining Determinants of Health Disparities in COVID-19 for Improving Pandemic Health Care',
#  'SpeCon: Speculative Container Scheduling for Deep Learning Applications in a Kubernetes Cluster',
#  'Nonnegative Residual Matrix Factorization for Community Detection',
#  '基于 Petri 网的分层业务过程挖掘方法',
#  'Network-aware Optimization for Query Executions in Large Systems',
#  'A scalable analysis framework for large-scale RDF data',
#  'The situational factors that affect the software development process: Towards a comprehensive reference framework',
#  'An examination of personality traits and how they impact on software development teams',
#  'Continuous software engineering—A microservices architecture perspective',
#  'Software Engineering Education and Games: A Systematic Literature Review',
#  'Software Engineering Education and Games: A Systematic Literature Review',
#  'The influence of SPI on business success in software SMEs: An empirical study',
#  'A Complexity Theory viewpoint on the Software Development Process and Situational Context',
#  'Exploring the Relationship between Software Process Adaptive Capability and Organisational Performance.',
#  'An empirical examination of the extent of software process improvement in software SMEs',
#  'Harmonizing Software Development Processes with Software Development Settings – A Systematic Approach',
#  'Teaching ISO/IEC 12207 software lifecycle processes: A serious game approach',
#  'A systematic examination of knowledge loss in open source software projects',
#  'Exploring the impact of situational context: A case study of a software development process for a microservices architecture',
#  'A systematic approach to the comparison of roles in the software development processes',
#  'Harnessing ISO/IEC 12207 to Examine the Extent of SPI Activity in an Organisation',
#  'An Investigation of Software Development Process Terminology',
#  'Overcoming Public Speaking Anxiety of Software Engineers Using Virtual Reality Exposure Therapy',
#  'A Gamification Approach to Improve the Software Development Process by Exploring the Personality of Software Practitioners. CCIS 609',
#  'Untangling the Complexity of Connected Health Evaluations',
#  'Harnessing software development contexts to inform software process selection decisions',
#  'A 3D Virtual Environment for Training Soccer Referees',
#  'Changing situational contexts present a constant challenge to software developers',
#  'An approach to evaluating software process adaptation',
#  'Effective Social Productivity Measurements During Software Development: An Empirical Study',
#  'Software development roles: a multi-project empirical investigation',
#  'Development and benefits of MDevSPICE®, the medical device software process assessment framework',
#  'The meaning of success for software SMEs: an holistic scorecard based approach',
#  'In search of the origins and enduring impact of Agile software development',
#  'In Search of the Origins and Enduring Impact of Agile Software Development',
#  'A hierarchy of SPI activities for software SMEs: results from ISO/IEC 12207-based SPI assessments',
#  'A Systematic Investigation into the Use of Game Elements in the Context of Software Business Landscapes: A Systematic Literature Review',
#  'Do We Speak the Same Language? Terminology Strategies for (Software) Engineering Environments Based on the Elcat Model-Innovative Terminology e-Learning for the Automotive Industry',
#  'Refactoring Software Development Process Terminology Through the Use of Ontology',
#  'Refactoring Software Development Process Terminology through the use of Ontology',
#  'Business success in software SMEs: Recommendations for future SPI studies',
#  'Exploring Knowledge Loss in Open Source Software (OSS) Projects',
#  'The Impact of Situational Context on the Software Development Process–A Case Study of a Highly Innovative Start-up Organization',
#  'Software Process Reflexivity and Business Performance: Initial results from an empirical study',
#  'Interactive three-dimensional virtual environment to reduce the public speaking anxiety levels of novice software engineers',
#  'The Impact of Situational Context on Software Process: A Case Study of a Very Small-Sized Company in the Online Advertising Domain',
#  'Exploring Software Process Variation Arising from Differences in Situational Context',
#  'Development of a Process Assessment Model for Medical Device Software Development',
#  'Situational Factors in Safety Critical Software Development',
#  'Situational Factors in Safety Critical Software Development',
#  'Applying Blockchain to Improve the Integrity of the Software Development Process',
#  'Technology-Enabled Continuous Software Development',
#  'Development of MDevSPICE - the Medical Device Software Process Assessment Framework',
#  'Medical device software as a subsystem of an overall medical device: The MDevSPICE experience',
#  'Applying Blockchain to Improve the Integrity of the Software Development Process',
#  'Examining Reward Mechanisms for Effective Usage of Application Lifecycle Management Tools',
#  'Piloting MDevSPICE - the Medical Device Software Process Assessment Framework',
#  'An Exploration of Individual Personality Types in Software Development',
#  'Examining Unequal Gender Distribution in Software Engineering',
#  'Software Developer’s Journey',
#  "Software developer's journey a story-driven approach to support software practitioner",
#  'A Lightweight Assessment Method for Medical Device Software Processes',
#  'MDevSPICE-A Comprehensive Solution for Manufacturers and Assessors of Safety-Critical Medical Device Software',
#  'The Changing Role of the Software Engineer',
#  'An Auction-Based Serious Game for Bug Tracking',
#  'Safety Critical Software Process Assessment: How MDevSPICE Addresses the Challenge of Integrating Compliance and Capability',
#  'Towards the identification of the influence of SPI on the successful evolution of software SMEs',
#  'CENGO: A Web-Based Serious Game to Increase the Programming Knowledge Levels of Computer Engineering Students',
#  'Adopting virtual reality as a medium for software development process education',
#  'CENGO: A Web-Based Serious Game to Increase the Programming Knowledge Levels of Computer Engineering Students',
#  'A Multivocal Literature Review of Function-as-a-Service (FaaS) Infrastructures and Implications for Software Developers',
#  'Software Testing: A Changing Career',
#  'An ISO/IEC 12207 Perspective on Software Development Process Adaptation.',
#  'Bringing Medical Device Software Development Standards into a single model - MDevSPICE',
#  'Visualization, Monitoring and Control Techniques for Use in Scrum Software Development: An Analytic Hierarchy Process Approach',
#  'Systems, Software and Services Process Improvement: 27th European Conference, EuroSPI 2020, Düsseldorf, Germany, September 9-11, 2020, Proceedings',
#  'Guest Editorial: Gamification and Persuasive Games for Software Engineering',
#  'A Gamification Approach to Improve the Software Development Process by Exploring the Personality of Software Practitioners',
#  'Characteristics of a medical device software development framework',
#  'Investigating the relationship between software process improvement, situational change, and business success in software SMEs',
#  'PlaySAFe: Results from a Virtual Reality Study Using Digital Game-Based Learning for SAFe Agile Software Development',
#  'Agile Software Development–Do We Really Calculate the Costs? A Multivocal Literature Review',
#  'A mechanism to explore proactive knowledge retention in open source software communities',
#  'An Approach to Investigating Proactive Knowledge Retention in OSS Communities',
#  'Erratum to: Software Process Improvement and Capability Determination',
#  'Yazılım Yönetiminde İşe Alıştırma Süreçlerinin İyileştirilmesi İçin Düşünülmüş Bir Endüstriyel Vaka Çalışması',
#  'A Professional Career with Autism: Findings from a Literature Review in the Software Engineering Domain',
#  'To Work from Home (WFH) or Not to Work from Home? Lessons Learned by Software Engineers During the COVID-19 Pandemic',
#  'Digital Transformation and the Role of Dynamic Tooling in Extracting Microservices from Existing Software Systems',
#  'What Makes Agile Software Development Agile',
#  'Applying virtual reality to teach the software development process to novice software engineers',
#  'Summary of the 1st ICSSP-ICGSE Joint Event',
#  'Proceedings 27th European Conference, EuroSPI 2020, Düsseldorf, Germany, September 9–11, 2020,',
#  'Assessing Application Lifecycle Management (ALM) Potentials from an Industrial Perspective',
#  'Proceedings ACM/IEEE International Conference on System and Software Processes (ICSSP) 2020',
#  'Summary of the 2019 International Conference on Software and System Processes (ICSSP 2019)',
#  '2019 IEEE/ACM International Conference on Software and System Processes',
#  'A 3D virtual environment for training soccer referees',
#  'Adopting Augmented Reality for the Purpose of Software Development Process Training and Improvement: An Exploration',
#  'Interactive three-dimensional virtual environment to reduce the public speaking anxiety levels of novice software engineers',
#  'Adopting Augmented Reality for the Purpose of Software Development Process Training and Improvement: An Exploration',
#  'An interactive 3D virtual environment to reduce the public speaking anxiety levels of novice software engineers',
#  'The Impact of Situational Context on Software Process: A Case Study of a Very Small-Sized Company in the Online Advertising Domain',
#  'The demands of safety-critical medical device software development',
#  'Software Process Improvement and Capability Determination Conference 2016',
#  'Reducing Knowledge Loss in Open Source Software',
#  'Software Process Improvement and Capability Determination Conference 2016',
#  'Proceedings of the 16th International Conference on Software Process Improvement and Capability Determination (SPICE 2016), Dublin, Ireland, June 9-10, 2016',
#  'Software Process Improvement and Capability Determination',
#  "Software Developer's Journey A Story-Driven Approach to Support Software Practitioners",
#  'Software Process Improvement and Capability Determination [electronic resource]: 16th International Conference, SPICE 2016, Dublin, Ireland, June 9-10, 2016, Proceedings/edited …',
#  'An Investigation of Software Development Process Terminology',
#  'MDevSpice is a one-stop shop for medical-device manufacturers',
#  'Characteristics of medical device software development',
#  'Medical device software development: towards a single best practice framework',
#  'A robust approach to examining business success in software development companies',
#  'An Holistic Scorecard Based Approach to Examining the Meaning of Success for Software SMEs',
#  'Steering Committee ICSSP 2021',
#  'An analysis of Function-as-a-Service (FaaS): vendors, challenges and implications for software developers',
#  'Agile Software Development–Do We Really Calculate the Costs? A Multivocal',
#  'Software Process Improvement and Capability Determination',
#  'Database constraints, such as" patients with the same symptoms get the same therapies", may be modeled by means of functional dependencies (FD). They have been extended to …',
#  'A. Ibáñez Moreno, A. Vermeulen',
#  'Wisdom of crowds for robust gene network inference (As part of the DREAM5 consortium)',
#  'Techniques for clustering gene expression data',
#  'Random matrix theory for portfolio optimization: a stability approach',
#  'RNA-Seq vs dual-and single-channel microarray data: sensitivity analysis for differential expression and clustering',
#  'Time and scale Hurst exponent analysis for financial markets',
#  'Cross-correlation dynamics in financial time series',
#  'Comparison of evolutionary algorithms in gene regulatory network model inference',
#  'Random matrix theory and fund of funds portfolio optimisation',
#  'Random matrix theory filters in portfolio optimisation: A stability and risk assessment',
#  'Wavelet multiscale analysis for hedge funds: Scaling and strategies',
#  'Interrelationships among international stock market indices: Europe, Asia and the Americas',
#  'The reaction of stock markets to crashes and events: A comparison study between emerging and mature markets using wavelet transforms',
#  'Probabilistic models for drug dissolution. Part 1. Review of Monte Carlo and stochastic cellular automata approaches',
#  'Probabilistic methods for drug dissolution. Part 2. Modelling a soluble binary drug delivery system dissolving in vitro',
#  'Quantitative multi-agent models for simulating protein release from PLGA bioerodible nano-and microspheres',
#  'Comparison of microarray preprocessing methods',
#  'The effect of a meteorological tower on its top-mounted anemometer',
#  'Cross-platform microarray data normalisation for regulatory network inference',
#  'An agent-based approach to immune modelling',
#  'Simulation of the USP drug delivery problem using CFD: experimental, numerical and mathematical aspects',
#  'Optimisation and parallelisation strategies for Monte Carlo simulation of HIV infection',
#  'Stages of gene regulatory network inference: the evolutionary algorithm role',
#  'Multiscaled Cross-Correlation Dynamics in Financial Time-Series',
#  'Multi scale cross correlation dynamics in Financial Time Series',
#  'Seizure characterisation using frequency-dependent multivariate dynamics',
#  'HIV models for treatment interruption: Adaptation and comparison',
#  'Parallelisation strategies for large scale cellular automata frameworks in pharmaceutical modelling',
#  'Model refinement through high-performance computing: an agent-based HIV example',
#  'Bitcoin currency fluctuation',
#  'Automatically Detecting ‘‘Significant Events’’ on SenseCam',
#  'Random matrix theory filters and currency portfolio optimisation',
#  'Finding motifs in large personal lifelogs',
#  'Interdependence between emerging and major markets',
#  'Design challenges for GDPR RegTech',
#  'Day ahead forecasting of FAANG stocks using ARIMA, LSTM networks and wavelets.',
#  'Integrating heterogeneous gene expression data for gene regulatory network modelling',
#  'An agent-based approach to immune modelling: priming individual response',
#  'A Pohlhausen solution for the mass flux from a multi-layered compact in the USP drug dissolution apparatus',
#  '3D Multi-agent models for protein release from PLGA spherical particles with complex inner morphologies',
#  'Multiscaled Cross-Correlation Dynamics on SenseCam Lifelogged Images',
#  'Modelling drug coatings: A parallel cellular automata model of ethylcellulose-coated microspheres',
#  'Edge-weighting of gene expression graphs',
#  'Epigenetic modelling',
#  'Cross-Correlation Dynamics and Community Structures of Cryptocurrencies',
#  'Applications of High Performance Algorithms to Large Scale Cellular Automata Frameworks Used in Pharmaceutical Modelling.',
#  'Assessing the impact of HIV treatment interruptions using stochastic cellular Automata',
#  'Employee turnover prediction using machine learning',
#  'A Computational Lymph Tissue Model for Long Term HIV Infection Progression and Immune Fitness.',
#  'Comparative analysis of asynchronous cellular automata in stochastic pharmaceutical modelling',
#  'In silico biology: Making the most of parallel computing',
#  'HIV modelling-parallel implementation strategies',
#  'Financial Time Series: Motif Discovery and Analysis Using VALMOD',
#  'Data integration for microarrays: Enhanced inference for gene regulatory networks',
#  'Application of statistical physics for the identification of important events in visual lifelogs',
#  'The importance of boundary conditions in the simulation of dissolution in the USP dissolution apparatus',
#  'Epochs in Market Sector Index Data—Empirical or Optimistic?',
#  'The Mechanics of Drug Dissolution',
#  'Considerations on privacy in the era of digitally logged lives',
#  'NTCIR-12 lifelog data analytics',
#  'Random matrix ensembles of time correlation matrices to analyze visual lifelogs',
#  'EGIA–evolutionary optimisation of gene regulatory networks, an integrative approach',
#  'Regulatory network modelling: Correlation for structure and parameter optimisation',
#  'Test for Long-Range Dependence in stock Market: Using Wavelet Transforms',
#  'AI cloud-based smart manufacturing and 3D printing techniques for future in-house production',
#  'Computer-based approach to detect wrinkles and suggest facial fillers',
#  'Vielens, an interactive search engine for lsc2019',
#  'Probabilistic pharmaceutical modelling: a comparison between synchronous and asynchronous cellular automata',
#  'High-performance computing for data analytics',
#  'Visual experience for recognising human activities',
#  'Probabilistic models for dissolution of ethylcellulose coated microsphere',
#  'Correlation of worldwide markets’ entropies',
#  'Apples and Oranges: the difference between the Reaction of the Emerging and Mature Markets to Crashes',
#  'Learning behaviours data in programming education: Community analysis and outcome prediction with cleaned data',
#  'GDPR Compliance tools: best practice from RegTech',
#  'Student behaviours in using learning resources in higher education: How do behaviours reflect success in programming education?',
#  'Efficient Computational Models for assessment of Spatial Infection Features',
#  'Analysis of Cryptocurrency Commodities with Motifs and LSTM.',
#  'Data mining in agri warehouses using modwt wavelet analysis',
#  'A Wavelet-Based Method to Measure Stock Market Development',
#  'ON THE VOLUME OF FLUID METHOD FOR MULTIPHASE FLUID FLOW SIMULATION',
#  'Can random matrix filters be used for trading in the foreign exchange market?-A comparison of foreign exchange and stock portfolio filtering',
#  'A numerical model of a drug particle dissolving in a dissolution test apparatus',
#  'Pattern discovery in gene expression data',
#  "Correlation of worldwide markets' entropies: time-scale approach",
#  'Community Detection in Cryptocurrencies with Potential Applications to Portfolio Diversification',
#  "Education as a complex system: using physic methods for the analysis of students' learning behaviours in the context of programming education.",
#  'Financial Time Series: Market Analysis Techniques Based on Matrix Profiles',
#  'Release modelling of nanoencapsulated food ingredients by probabilistic models: Cellular Automata and Monte Carlo Methods',
#  'Received Total Wideband Power Data Analysis: Multiscale wavelet analysis of RTWP data in a 3G network',
#  'Improving Confidence in Simulations through the Application of Multiple Updating Strategies',
#  'Motif Discovery and Evaluation: Focus on Finance',
#  'New dimensions–modelling interrupted antiretroviral treatment using cellular automata',
#  'Evaluating the Volatility Behaviour in Irish ISEQ Overall Index Using GARCH Models',
#  'Applying random matrix theory filters on SenseCam images',
#  'A Study of Correlation and Entropy for Multiple Time Series',
#  'Drug Dissolution Modelling',
#  'Modelling Gene Regulatory Networks - An Integrative Approach',
#  'Wavelets for analysis of time series gene expression data',
#  'Evolutionary algorithms in genetic regulatory network modelling with microarray data,',
#  'Increasing biological accuracy in models of HIV progression while minimising complexity',
#  'On the development of Object Oriented Parallel Pentadiagonal Preconditioned Krylov Subspace (K-S) Solvers',
#  "Correspondence: Response to the comments by Bernaschi et al. on'Optimisation and parallelisation strategies for Monte Carlo simulation of HIV infection'",
#  'Long-term memory in the Irish market (ISEQ): evidence from wavelet analysis',
#  'A sequence-focused parallelisation of EMBOSS on a cluster of workstations',
#  'ег ддаф йм дан й к кл ек мкаф афал д е фл ф д как',
#  'This file was downloaded from: http://eprints. qut. edu. au/82681',
#  'Probabilistic Pharmaceutical Modelling: A Comparison Between Synchronous and Asynchronous Cellular...',
#  'Generalising a Pohlhausen-Type Solution for Dissolution from Multi-Layer Drug Compacts',
#  'Modelling the in vitro Dissolution of Soluble Binary Drug Delivery Systems using Direct Monte Carlo techniques',
#  'Stock Market Behaviour for Different Time Intervals with Different Volatility Levels.',
#  'Vaso-occlusive delivery device with kink resistant, flexible distal end',
#  'Assessing the assessment of programming ability',
#  'RoboProf and an introductory computer programming course',
#  'An automated learning system for Java programming',
#  'Platform independent dynamic java virtual machine analysis: the java grande forum benchmark suite',
#  'Patterns of plagiarism',
#  'Mass production of individual feedback',
#  'A technique for detecting plagiarism in computer code',
#  'Heart rate awareness in patients with chronic stable heart failure. A multi-center observational study',
#  'Profiling the plagiarists: An examination of the factors that lead students to cheat',
#  'Prevalence, contributing factors, and management strategies for test and maths anxiety in first-year psychology students',
#  'Safety comes first: are doctors attentive enough to their initial clinical assessment notes?',
#  'Can risk stratification of transient ischaemic attacks improve patient care in the emergency department?',
#  'Comparison of factors influencing bytecode usage in the Java virtual machine',
#  'Using Moodle—An open source leaning management system in Australian Mining Engineering Education',
#  'Ambulatory postoperative ward-based epidural analgesia: a retrospective review of 1,147 cases',
#  "America's Dream Team: The Quest for Olympic Gold",
#  'Standing activity intervention and motor function in a young child with cerebral palsy: A case report',
#  'A Collaborative Approach to Mining Education in Australia.',
#  'Home-based circuit training program for an adolescent female with severe traumatic brain injury: a case report',
#  'Moving-eye figure.',
#  'Hygienic eating utensil.',
#  'Pilot Evaluation of a School-Based Programme Focused on Activity, Fitness, and Function among Children with Cerebral Palsy at GMFCS Level IV: Single-Subject Research Design',
#  'Enhanced Student Collaboration in Mining Engineering through Peer Review of Major Projects.',
#  'Introductory programming, problem solving and computerbased assessment',
#  'Fuzzy logic methods for image motion detection and analysis',
#  'My patient has no blood pressure: are they empty or full? Point-of-care ultrasound of the inferior vena cava in the hypotensive emergency department patient',
#  'A technique for measuring plagiarism in automated & distance learning environments',
#  'Dynamic analysis of the Java virtual machine method invocation architecture',
#  'An evaluation of the effectiveness of teamwork, with an emphasis on peer assessment and peer review, in an introductory engineering course',
#  'Review of Hardware, Software Security and Testing',
#  'Work orientation as a function of sex, job level and marital status',
#  'Simulation: It’s the name of the game',
#  'Abstract book',
#  'Lichen sclerosus management-gynaecology versus dermatology and vulval specialty clinics',
#  'Clinical Case Poster session 2',
#  'Corrigendum to “Heart rate awareness in patients with chronic stable heart failure. A multi-center observational study”[Int. J. Cardiol. 2014. 177 (2): 380–4]',
#  'Poster session 6',
#  '124| The 100 Most Important Sporting Events in American History',
#  '9 Left atrial force as a precise haemodynamic monitor in patients with hereditary haemochromatosis pre and post venesection',
#  'Health and Safety Audit of a General Practice',
#  'Improving quality of colonoscopy: how can we push up the bar?',
#  'Minimally invasive Ivor-Lewis oesophagectomy following neoadjuvant chemoradiotherapy for the treatment of oesophageal cancer: first 30 consecutive unselected cases',
#  'IMPACT OF ADVERSE IN UTERO ENVIRONMENT AND POSTNATAL EXCESS ENERGY DIET ON OVARIAN FOLLICLE DEVELOPMENT',
#  'Head to head comparison of risk stratification scores HEART vs TIMI score for patients with undifferentiated chest pain and correlating with frequencies of in-hospital major …',
#  'Minimally Invasive Ivor-Lewis Oesophagectomy Following Neoadjuvant Chemoradiotherapy for the Treatment of Oesophageal Cancer: First 30 Consecutive Unselected Cases',
#  'Introduction of Microbubbles technique for pre-operative sentinel node assessment for breast cancer patients in a district general hospital: Cancer/Surgical Oncology I 0658',
#  'A project management approach to the undergraduate Mining Engineering thesis.',
#  'Poster Session 3: Friday 9 December 2011, 08: 30–12: 30 Location: Poster Area',
#  'P649Atrial and ventricular abnormalities on echocardiography in newly diagnosed untreated hereditary haemochromatosis.',
#  'Atrial and Ventricular Functional Changes on Echocardiography in Newly Diagnosed Untreated Hereditary Haemochromatosis',
#  'The ECCU Course: Emergency and Critical Care Ultrasound',
#  'Poster session II Thursday 9 December 2010, 14: 00-18: 00',
#  'Myocardial fibrosis in left ventricular hypertrophy and late-enhancement gadolinium with 3Tesla cardiac magnetic resonance imaging-does speckle-tracking echocardiography have a …',
#  "Enhancing students' engagement with psychology through the establishment of a peer support training program",
#  'Effects of context and associative information in the production of false memories',
#  'Stages of sleep: Investigating differences in dream content and memory sources',
#  'Semantic information is relevant in the irrelevant speech effect',
#  'Using on-line teaching in undergraduate psychology',
#  'Some measurements of Java-to-bytecode compiler performance in the Java Virtual Machine',
#  'Irish cardiac society',
#  'An approach for the motion planning of a mobile robot',
#  'The golden hour checklist: helping to optimise care of the newborn preterm infant',
#  'The golden hour checklist: optimise care of the newborn',
#  'Design, Development, and Evaluation of a Computer Based Learning Module in Pathology',
#  'Encrypted Speech with a Familiar User-Interface',
#  'Clone: Controlled language for ontology editing',
#  'Semeval-2017 task 5: Fine-grained sentiment analysis on financial microblogs and news',
#  'On controlled natural languages: Properties and prospects',
#  'The case for virtual register machines',
#  'Trust models for community aware identity management',
#  'Roundtrip ontology authoring',
#  'A twitter sentiment gold standard for the brexit referendum',
#  'Classifying Action Items for Semantic Email.',
#  'Infrastructure for dynamic knowledge integration—Automated biomedical ontology extension using textual resources',
#  'Semanta–semantic email made easy',
#  "Www'18 open challenge: financial opinion mining and question answering",
#  'Multilingual Verbalisation of Modular Ontologies Using GF and lemon',
#  'Improving email conversation efficiency through semantically enhanced email',
#  'A brief state of the art of CNLs for ontology authoring',
#  'A compositional-distributional semantic model for searching complex entity categories',
#  'Controlled language IE components version 2',
#  'LRE journal CNL introduction',
#  'Semantic relatedness for all (languages): A comparative analysis of multilingual semantic relatedness using machine translation',
#  'Indra: A word embedding and semantic relatedness server',
#  'SemR-11: A multi-lingual gold-standard for semantic similarity and relatedness for eleven languages',
#  'Human language technologies',
#  'Dinfra: A one stop shop for computing multilingual semantic relatedness',
#  'Social sentiment indices powered by X-scores',
#  'Search interface based on natural language query templates',
#  'The case for virtual register machines',
#  'In or Out? Real-Time Monitoring of BREXIT sentiment on Twitter.',
#  'Towards predicting academic impact from mainstream news and weblogs: A heterogeneous graph based approach',
#  'Social impact assessment of scientist from mainstream news and weblogs',
#  'Knowledge Engineering and Knowledge Management',
#  'Natural language generation from ontologies',
#  'Linguistically Light Lexical Extensions for Ontologies.',
#  'Evaluating the Ontology underlying sMail-the Conceptual Framework for Semantic Email Communication.',
#  'Trust models for community-aware identity management. Identity, Reference and the Web IRW2006',
#  'Squeezing lemon with GATE',
#  'Implicit and explicit aspect extraction in financial microblogs',
#  'Dublin City University and partners’ participation in the INS and VTT tracks at TRECVid 2016',
#  "Semantic indexing of wearable camera images: Kids' Cam concepts",
#  'Extracting semantic knowledge from unstructured text using embedded controlled language',
#  'Towards controlled natural language for semantic annotation',
#  'On designing controlled natural languages for semantic annotation',
#  'Semanta–Semantic Email in Action',
#  'Conceptual data structure tools',
#  'Further use of Controlled Natural Language for Semantic Annotation of Wikis.',
#  'A project in embedded systems design and development: a partnership with area high school scholars',
#  'A survey of optimisations for the java virtual machine',
#  'A Social Opinion Gold Standard for the Malta Government Budget 2018',
#  'Predicting citations from mainstream news, weblogs and discussion forums',
#  'The path towards semantic email: Summary and outlook',
#  'Semantic relation classification: task formalisation and refinement',
#  'FinSentiA: sentiment analysis in English financial microblogs',
#  'The SSIX corpora: three gold standard corpora for sentiment analysis in English, Spanish and German financial microblogs',
#  'Nostalgic sentiment analysis of youtube comments for chart hits of the 20th century',
#  'Controlled natural language for semantic annotation',
#  'Semantically Enhanced Passage Retrieval for Business Analysis Activity',
#  'Personalized question answering: a use case for business analysis',
#  'CoSACT: A collaborative tool for fine-grained sentiment annotation and consolidation of text',
#  'Multilingual semantic relatedness using lightweight machine translation',
#  'Erratum to: Controlled Natural Language',
#  'Linse: A distributional semantics entity search engine',
#  'On applying controlled natural languages for ontology authoring and semantic annotation',
#  'A linguistic light approach to multilingualism in lexical layers for ontologies',
#  'Another PASS: A reproduction study of the human evaluation of a football report generation system',
#  'Over a Decade of Social Opinion Mining',
#  'Engineering an aligned gold-standard corpus of human to machine oriented Controlled Natural Language',
#  'Controlled Natural Language: Proceedings of the Sixth International Workshop, CNL 2018, Maynooth, Co. Kildare, Ireland, August 27-28, 2018',
#  'Classification of composite semantic relations by a distributional-relational model',
#  'Composite semantic relation classification',
#  'Challenges and opportunities for detecting and measuring diffusion of scientific impact across heterogeneous altmetric sources',
#  'Engineering a controlled natural language into semantic mediawiki',
#  'On controlled natural language',
#  'Semanta Supporting E-mail Workflows in Business Processes',
#  'D2. 2.2 Report: Controlled Language IE Components version 2',
#  'Interactive semantic wikis. Deliverable D1. 1, NEPOMUK Consortium, Kaiserslautern',
#  'Sensemaking of complex sociotechnical systems: the case of governance dashboards',
#  'Rewriting simplified text into a controlled natural language',
#  'A Multilingual Test Collection for the Semantic Search of Entity Categories',
#  'From simplified text to knowledge representation using Controlled Natural Language',
#  'In or out? real-time monitoring of brexit sentiment on twitter',
#  'Embedded controlled language to facilitate information extraction from eGov policies',
#  'On developing extraction rules for mining informal scientific references from altmetric data sources',
#  'A Use Case for Controlled Languages as Interfaces to Semantic Web Applications.',
#  'Over a decade of social opinion mining: a systematic review',
#  'Enriching the E2E dataset',
#  'LUX (Linguistic aspects Under eXamination): Discourse Analysis for Automatic Fake News Classification',
#  'Implicit Aspect-Based Opinion Mining and Analysis of Airline Industry Based on User-Generated Reviews',
#  'Do city dashboards make sense? Conceptualising user experiences and challenges in using city dashboards. A case study',
#  'A Dataset of Multidimensional and Multilingual Social Opinions for Malta’s Annual Government Budget',
#  'CASIE–Computing affect and social intelligence for healthcare in an ethical and trustworthy manner',
#  'Proceedings of the 13th International Conference on Natural Language Generation',
#  'The outsider art project: a transdisciplinary framework',
#  'Towards the Ontologization of the Outsider Art Domain: Position Paper',
#  'Toward the Automatic Retrieval and Annotation of Outsider Art images: A Preliminary Statement',
#  'Proceedings of the Sixth International Workshop on Controlled Natural Language 2018']

# %%
'''
link = "https://scholar.google.com/citations?view_op=list_works&hl=en&hl=en&user=o7xnW2MAAAAJ"
driver.get(link)

mark_complete(driver)

#time.sleep(4 + random.uniform(0,5))
results_list = driver.find_elements_by_xpath("//a[@class='gsc_a_at']")
results_list[0].click()
driver.back()
results_list = driver.find_elements_by_xpath("//a[@class='gsc_a_at']")
time.sleep(20)
results_list[1].click()
print(len(results_list))
assert len(results_list) > 0
'''

# %%
df6 = pd.DataFrame()

# %%
df6['Title'] = paper_title
df6['Authors'] = authors
df6['Citation'] = citation
df6['Conference'] = conference
df6['Publisher'] = publisher
df6['Journal'] = journal
df6['Date'] = date

# %%
#df5.to_csv('scholars1.csv')

# %%
#len(authors)

# %%
#df6.to_csv('scholars2.csv')

# %%
#len(authors)
